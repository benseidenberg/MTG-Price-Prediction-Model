# %% [markdown]
# # MTG Price Predictor
#
# ## About/Goals:
#
# The idea of this project is to create an ML model that can take a card's data and return the value of the card should be, based on previous cards it has analysed. This requires NLP processing for the text box, and utilizes tensorflow to build the model.
#
# Cards are evaluated purely based on what a person looking at it for the first time can see - year, text, color, etc.. nothing about format legalities, special flags, or anythingn else of the sort. Also, price is based on standard, nonfoil variant only.

# %% [markdown]
# # Data Importation and Cleaning

# %% [markdown]
# #### All imports cell

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer
import tensorflow as tf
from tensorflow.keras.layers import TextVectorization
from sklearn.preprocessing import StandardScaler
import re
import os

# %%
def save(file):
    file.to_pickle('data/updated_data.pkl')

def load():
    df = pd.read_pickle('data/updated_data.pkl')
    return df # band-aid work-around

# %%
df = pd.read_json("data/default_cards_08_05_2025.json")

# %%
df.columns
# Out:
# Index(['object', 'id', 'oracle_id', 'multiverse_ids', 'mtgo_id', 'arena_id',
#        'tcgplayer_id', 'cardmarket_id', 'name', 'lang', 'released_at', 'uri',
#        'scryfall_uri', 'layout', 'highres_image', 'image_status', 'image_uris',
#        'mana_cost', 'cmc', 'type_line', 'oracle_text', 'colors',
#        'color_identity', 'keywords', 'produced_mana', 'legalities', 'games',
#        'reserved', 'game_changer', 'foil', 'nonfoil', 'finishes', 'oversized',
#        'promo', 'reprint', 'variation', 'set_id', 'set', 'set_name',
#        'set_type', 'set_uri', 'set_search_uri', 'scryfall_set_uri',
#        'rulings_uri', 'prints_search_uri', 'collector_number', 'digital',
#        'rarity', 'card_back_id', 'artist', 'artist_ids', 'illustration_id',
#        'border_color', 'frame', 'full_art', 'textless', 'booster',
#        'story_spotlight', 'prices', 'related_uris', 'purchase_uris',
#        'mtgo_foil_id', 'power', 'toughness', 'flavor_text', 'edhrec_rank',
#        'penny_rank', 'all_parts', 'promo_types', 'security_stamp',
#        'card_faces', 'preview', 'watermark', 'frame_effects', 'loyalty',
#        'printed_name', 'tcgplayer_etched_id', 'flavor_name',
#        'attraction_lights', 'color_indicator', 'printed_type_line',
#        'printed_text', 'variation_of', 'life_modifier', 'hand_modifier',
#        'content_warning', 'defense'],
#       dtype='object')

# %% [markdown]
# can drop so many of these columns, only need ones that are useful.

# %% [markdown]
# ### Column Cleaning

# %%
len(df)
# Out:
# 108955

# %%
df.value_counts("variation")
df.value_counts("oversized")
# Out:
# oversized
# False    108229
# True        726
# Name: count, dtype: int64

# %%
df = df[(df["variation"]==False) & (df["reprint"]==False) & (df["oversized"]==False) & (df["promo"]==False) & (df["full_art"]==False) & (df["textless"] == False) & (df["content_warning"]!=True)]

# %%
len(df) # Dropped about 40k entries
# Out:
# 41387

# %%
doubles = df["card_faces"].dropna()
doubles.iloc[0] ## this is gonna be tough to work with
# Out:
# [{'object': 'card_face',
#   'name': "Obyra's Attendants",
#   'mana_cost': '{4}{U}',
#   'type_line': 'Creature — Faerie Wizard',
#   'oracle_text': 'Flying',
#   'power': '3',
#   'toughness': '4',
#   'flavor_text': "Obyra's devoted servants shrieked as their sleeping mistress slashed at them, unseeing.",
#   'artist': 'Andreas Zafiratos',
#   'artist_id': 'e2f13a9a-57c5-40de-81d4-3b0723899cdf',
#   'illustration_id': 'd1ea5321-62e2-4894-a79f-03b792daf2c8'},
#  {'object': 'card_face',
#   'name': 'Desperate Parry',
#   'mana_cost': '{1}{U}',
#   'type_line': 'Instant — Adventure',
#   'oracle_text': 'Target creature gets -4/-0 until end of turn. (Then exile this card. You may cast the creature later from exile.)',
#   'artist': 'Andreas Zafiratos',
#   'artist_id': 'e2f13a9a-57c5-40de-81d4-3b0723899cdf'}]

# %% [markdown]
# For first iteration of model, will be removing the multi-faced cards

# %%
df = df[df["card_faces"].isna()]

# %%
def is_legal(x):
    if 'legal' in x.values():
        return True
    else:
        return False

# %%
df["playable"] = df["legalities"].apply(is_legal)

# %%
df = df[df["playable"] == True] # remove unnplayable cards

# %%
unneeded = ['object', 'id', 'oracle_id', 'multiverse_ids', 'mtgo_id', 'arena_id',
       'tcgplayer_id', 'cardmarket_id', #'name',
         'lang', 'uri',
       'scryfall_uri', 'layout', 'highres_image', 'image_status', 'image_uris', 'legalities', 'games',
       'reserved', 'game_changer', 'finishes', 'oversized',
       'promo', 'reprint', 'variation', 'set_id', 'set', 'set_name',
       'set_type', 'set_uri', 'set_search_uri', 'scryfall_set_uri',
       'rulings_uri', 'prints_search_uri', 'collector_number', 'digital', 'card_back_id', 'artist', 'artist_ids', 'illustration_id',
       'border_color', 'frame', 'full_art', 'textless', 'booster',
       'story_spotlight', 'related_uris', 'purchase_uris',
       'mtgo_foil_id', 'flavor_text', 'edhrec_rank',
       'penny_rank', 'all_parts', 'promo_types', 'security_stamp', 'preview', 'watermark', 'frame_effects', 'loyalty',
       'printed_name', 'tcgplayer_etched_id', 'flavor_name',
       'attraction_lights', 'color_indicator', 'printed_type_line',
       'printed_text', 'variation_of', 'life_modifier', 'hand_modifier',
       'content_warning', 'defense', 'card_faces', 'foil', 'nonfoil'
       , 'playable', 'color_identity']
df = df.drop(unneeded, axis=1)

# %% [markdown]
# now that I've cleaned out cards and columns that aren't needed, I need to figure out the best way to transform this data into something that the ML model can actually use.
#
# For instance, the "type_line" column will have to be split up into various super and subtypes, probably using categorical encoding.

# %% [markdown]
# ### Type Labeling + Encoding

# %%
df["type_line"].describe() # has 4246 unique types currently
# Out:
# count       35098
# unique       3120
# top       Instant
# freq         3592
# Name: type_line, dtype: object

# %%
"""
df["creature_type"] = df["type_line"].apply(lambda x: x[10:] if "Creature" in x else "NaN")
df["planeswalker_type"] = df["type_line"].apply(lambda x: x[24:] if "Planeswalker" in x else "NaN")
df["kindred_type"] = df["type_line"].apply(lambda x: x.split()[-1] if "Kindred" in x or "Tribal" in x else "NaN")"""
# Found a better way!
# Out:
# '\ndf["creature_type"] = df["type_line"].apply(lambda x: x[10:] if "Creature" in x else "NaN")\ndf["planeswalker_type"] = df["type_line"].apply(lambda x: x[24:] if "Planeswalker" in x else "NaN")\ndf["kindred_type"] = df["type_line"].apply(lambda x: x.split()[-1] if "Kindred" in x or "Tribal" in x else "NaN")'

# %%
def filter_subtype(x):
    if "—" in x:
        ind = x.index("—")
        types = x[ind+1:].split()
        return types
    else:
        return []

# %%
def filter_maintype(x):
    types = ["Artifact", "Land", "Battle", "Creature", "Enchantment", "Planeswalker", "Instant", "Sorcery"]
    cur = []
    for type in types:
        if type in x:
            cur.append(type)
    return cur

# %%
df = df[~df['type_line'].str.contains('Basic')] # remove basic lands

# %%
df["legendary"] = df["type_line"].apply(lambda x: 1 if "Legendary" in x else 0)
df["subtype"] = df["type_line"].apply(filter_subtype)
df["main_type"]=df["type_line"].apply(filter_maintype)

# %%
df["price"] = df["prices"].str["usd"].astype(float) 
df = df.drop("prices", axis=1)

# %%
df = df.dropna(subset=["price"])
df = df[df["main_type"].map(len)>0]  # had to filter out bad cards with other types such as conspiracies and stickers

# %%
le = LabelEncoder()
le.fit(["Artifact", "Land", "Battle", "Creature", "Enchantment", "Planeswalker", "Instant", "Sorcery"])
# Out:
# LabelEncoder()

# %%
df["main_type"] = df["main_type"].apply(lambda x: le.transform(x))

# %%
le2 = LabelEncoder()

# %%
df["subtype"].values
# Out:
# array([list(['Sliver']), list(['Kor', 'Soldier']),
#        list(['Siren', 'Pirate']), ..., list([]),
#        list(['Faerie', 'Rogue']), list(['Vampire', 'Soldier'])],
#       dtype=object)

# %%
subtypes = []
for unique in df["subtype"].values:
    if unique != []:
        for val in unique:
            if val not in subtypes:
                subtypes.append(val)

le2.fit(subtypes)
# Out:
# LabelEncoder()

# %%
df["subtype"] = df["subtype"].apply(lambda x: le2.transform(x)) # slow, probably better way to do this

# %%
df = df.drop("type_line", axis=1)

# %% [markdown]
# ### Date -> Year

# %%
df["year"] = df["released_at"].apply(lambda x: x.year)
df = df.drop("released_at", axis=1)

# %% [markdown]
# ### Mana Cost Breakdown
#
# - Number of Pips
# - Is X spell?

# %%
df["is_x"] = df["mana_cost"].apply(lambda x: 1 if r"{X}" in x else 0)
#df.loc[df["is_x"] == 1]

# %%
#print("{1}{W/R}{G}{G}".replace("{", "").replace("}", " ").split())  ->  df

def pip_counter(x):
    new = x.replace("{", "").replace("}", " ").split()
    count = 0
    for x in new:
        if x.isdigit() == False and x != "X":
            count += 1

    return count

# %%
df["pip_count"] = df["mana_cost"].apply(pip_counter)
df = df.drop("mana_cost", axis=1)
#df.sort_values(by="pip_count", ascending=False)

# %% [markdown]
# ### Oracle Text Breakdown -> NLP ? Or can try a parsing method to turn text into columns
#
# - activated ability?
# - etb effect?

# %%
df["oracle_text"] = df["oracle_text"].apply(lambda x: x.lower().replace("\n", ". "))

# %% [markdown]
# #### Main Phrases

# %% [markdown]
# using vectorizer to figure out most common substrings

# %%
vectorizer = CountVectorizer(ngram_range=(4, 7), lowercase=True, stop_words=None)

# %%
X = vectorizer.fit_transform(df["oracle_text"])

# %%
sum_words = X.sum(axis=0)
word_freq = [(word, sum_words[0, idx]) for word, idx in vectorizer.vocabulary_.items()]
word_freq = sorted(word_freq, key=lambda x: x[1], reverse=True)

# %%
common_phrases = pd.DataFrame(word_freq, columns=['phrase', 'count'])
common_phrases.iloc[:10]
# Out:
#                        phrase  count
# 0           until end of turn   5990
# 1         at the beginning of   3261
# 2   when this creature enters   3049
# 3           gets until end of   2131
# 4      gets until end of turn   2130
# 5       the beginning of your   1869
# 6    at the beginning of your   1814
# 7    card from your graveyard   1593
# 8     creature gets until end   1570
# 9  creature gets until end of   1570

# %%
PHRASES = { # starter phrases
    r"when.*enters": "etb",
    r"until end of turn": "eot",
    r"beginning of .* upkeep": "b_o_u",
    r"search .* library": "tutor",
    r"without paying": "free",
    r"whenever .* attacks": "a_t",
    r"deals combat damage": "c_d_t",
    r"look at the tzo.*p": "s_s_t",
    r"return.*graveyard.*battlefield": "reanimate",
    r"when.*(this|a).*dies": "o_d_t",
    r"when.*(this|a).*leaves.": "l_b_t",
}

# %%
def canonicalize_text(str):
    for phr, rep in PHRASES.items():
        if re.search(phr, str) != None:
            str = re.sub(phr, rep, str)
    return str

# %%
df["oracle_text"] = df["oracle_text"].apply(canonicalize_text)

# %%
text_vectorizer = TextVectorization(
    max_tokens=1000,
    output_mode='tf-idf',
    ngrams = (2,6)
)

# %%
text_vectorizer.adapt(df["oracle_text"])

# %% [markdown]
# ### Rarity Encoding

# %%
rare_encoder = LabelEncoder()

# %%
df["rarity"].value_counts()
# Out:
# rarity
# rare        11445
# common       9878
# uncommon     8967
# mythic       1987
# special         2
# Name: count, dtype: int64

# %%
df["rarity"] = df["rarity"].apply(lambda x: "common" if x == "special" else x) # the two special cards have common rarity on scryfall

# %%
df["rarity"] = rare_encoder.fit_transform(df["rarity"])

# %% [markdown]
# ### Keyword Encoding

# %%
keywrd_encoder = LabelEncoder()

# %%
keywords = [] # taking code from earlier
for unique in df["keywords"].values:
    if unique != []:
        for val in unique:
            if val not in keywords:
                keywords.append(val)

keywrd_encoder.fit(keywords)
# Out:
# LabelEncoder()

# %%
len(keywords)
# Out:
# 604

# %%
df["keywords"] = df["keywords"].apply(lambda x: keywrd_encoder.transform(x))

# %% [markdown]
# ### Color Identity Encoding (one more time!)
#
# definitely could've done a for loop for each column i wanted to encode but oh well it's a little late for that

# %%
df
# Out:
#                        name  cmc  \
# 1               Fury Sliver  6.0
# 2             Kor Outfitter  2.0
# 4             Siren Lookout  3.0
# 7       Surge of Brilliance  2.0
# 9          Venerable Knight  1.0
# ...                     ...  ...
# 108944      Morkrut Banshee  5.0
# 108947   Deeproot Historian  4.0
# 108949  Aggressive Biomancy  2.0
# 108952  Faerie Bladecrafter  3.0
# 108953  Exultant Skymarcher  3.0
#
#                                               oracle_text  colors    keywords  \
# 1                all sliver creatures have double strike.     [R]          []
# 2       etb, you may attach target equipment you contr...     [W]          []
# 4       flying. etb, it explores. (reveal the top card...     [U]  [230, 198]
# 7       paradox — draw a card for each spell you've ca...     [U]  [390, 238]
# 9       o_d_t, put a +1/+1 counter on target knight yo...     [W]          []
# ...                                                   ...     ...         ...
# 108944  morbid — etb, if a creature died this turn, ta...     [B]       [366]
# 108947  merfolk and druid cards in your graveyard have...     [G]          []
# 108949  create x tokens that are copies of target crea...  [G, U]       [215]
# 108952  flying. o_d_t, each opponent loses x life and ...     [B]       [230]
# 108953                                             flying     [W]       [230]
#
#        produced_mana  rarity power toughness  legendary     subtype main_type  \
# 1                NaN       3     3         3          0       [310]       [2]
# 2                NaN       0     2         2          0  [183, 315]       [2]
# 4                NaN       0     1         2          0  [305, 259]       [2]
# 7                NaN       3   NaN       NaN          0          []       [4]
# 9                NaN       3     2         1          0  [157, 181]       [2]
# ...              ...     ...   ...       ...        ...         ...       ...
# 108944           NaN       3     4         4          0       [325]       [2]
# 108947           NaN       2     3         3          0   [204, 97]       [2]
# 108949           NaN       2   NaN       NaN          0          []       [7]
# 108952           NaN       2     2         2          0  [114, 280]       [2]
# 108953           NaN       0     2         3          0  [360, 315]       [2]
#
#         price  year  is_x  pip_count
# 1        0.30  2006     0          1
# 2        0.14  2009     0          2
# 4        0.08  2017     0          1
# 7        0.20  2023     0          1
# 9        0.14  2019     0          1
# ...       ...   ...   ...        ...
# 108944   0.09  2011     0          2
# 108947   0.15  2023     0          1
# 108949   0.19  2024     1          2
# 108952   1.29  2023     0          1
# 108953   0.06  2018     0          2
#
# [32279 rows x 16 columns]

# %%
c_i = LabelEncoder()

# %%
c_i.fit(["W", "G", "R", "B", "U"])
# Out:
# LabelEncoder()

# %%
c_i.transform(["W", "U"])
# Out:
# array([4, 3])

# %%
df["colors"] = df["colors"].apply(lambda x: c_i.transform(x))

# %% [markdown]
# ### Produced Mana
#
# changing this to binary value if it does(n't)

# %%
df["produced_mana"] = df["produced_mana"].replace(pd.NA, 0)

# %%
df["produced_mana"] = df["produced_mana"].apply(lambda x: 1 if x != 0 else x)

# %% [markdown]
# ### Final Step: Replace Power/Toughness NaN with -1

# %%
df["power"] = pd.to_numeric(df["power"], errors="coerce").fillna(-1)
df["toughness"] = pd.to_numeric(df["toughness"], errors="coerce").fillna(-1)

# %% [markdown]
# ### Final Data Filtering

# %%
df = df.loc[df["price"] <= 500]

# %%
df = df.loc[df["year"] >= 2000]

# %%
df.sort_values(by="price", ascending=False)
# Out:
#                                name  cmc  \
# 45968                      Mox Opal  0.0
# 11050   Liliana, Dreadhorde General  6.0
# 45216                    Chrome Mox  0.0
# 108758              The Great Henge  9.0
# 93570                  The One Ring  4.0
# ...                             ...  ...
# 76273              Constrictor Sage  5.0
# 13449             Flummoxed Cyclops  4.0
# 105586               Gruul Scrapper  4.0
# 57252           Shepherding Spirits  6.0
# 92024               Puncturing Blow  4.0
#
#                                               oracle_text colors  \
# 45968   metalcraft — {t}: add one mana of any color. a...     []
# 11050   o_d_t, draw a card.. +1: create a 2/2 black zo...    [0]
# 45216   imprint — etb, you may exile a nonartifact, no...     []
# 108758  this spell costs {x} less to cast, where x is ...    [1]
# 93570   indestructible. etb, if you cast it, you gain ...     []
# ...                                                   ...    ...
# 76273   etb, tap target creature an opponent controls ...    [3]
# 13449   reach. whenever two or more creatures your opp...    [2]
# 105586  etb, if {r} was spent to cast it, it gains has...    [1]
# 57252   flying. plainscycling {2} ({2}, discard this c...    [4]
# 92024   puncturing blow deals 5 damage to target creat...    [2]
#
#                          keywords  produced_mana  rarity  power  toughness  \
# 45968                       [356]              1       1   -1.0       -1.0
# 11050                          []              0       1   -1.0       -1.0
# 45216                       [293]              1       2   -1.0       -1.0
# 108758                         []              1       1   -1.0       -1.0
# 93570                       [296]              0       1   -1.0       -1.0
# ...                           ...            ...     ...    ...        ...
# 76273                          []              0       3    4.0        4.0
# 13449                       [435]              0       0    4.0        4.0
# 105586                         []              0       0    3.0        2.0
# 57252   [230, 402, 318, 570, 129]              0       0    4.0        5.0
# 92024                          []              0       0   -1.0       -1.0
#
#         legendary     subtype main_type   price  year  is_x  pip_count
# 45968           1          []       [0]  153.41  2010     0          0
# 11050           1       [194]       [6]  133.33  2019     0          2
# 45216           0          []       [0]   96.92  2003     0          0
# 108758          1          []       [0]   92.30  2019     0          2
# 93570           1          []       [0]   79.86  2023     0          0
# ...           ...         ...       ...     ...   ...   ...        ...
# 76273           0  [314, 378]       [2]    0.01  2025     0          1
# 13449           0        [73]       [2]    0.01  2020     0          1
# 105586          0   [157, 38]       [2]    0.01  2006     0          1
# 57252           0       [325]       [2]    0.01  2024     0          2
# 92024           0          []       [7]    0.01  2017     0          2
#
# [28076 rows x 16 columns]

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Numerical Data

# %%
numerical = df.drop(["name", "oracle_text", "colors", "keywords", "subtype", "main_type", "price"], axis=1)

# %%
numerical.columns
# Out:
# Index(['cmc', 'produced_mana', 'rarity', 'power', 'toughness', 'legendary',
#        'year', 'is_x', 'pip_count'],
#       dtype='object')

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(numerical)

# %%
number_inputs = keras.Input(shape=(9,), name="numerical")
normalized = keras.layers.Normalization()(number_inputs)

# %% [markdown]
# ### Array Data

# %% [markdown]
# describing code below:
# have to pad all the array inputs, tell keras the shape of the input, and create an embedding layer to vectorize said input
#
# input_dim is equal to number of unique ids

# %%
colors_padded = keras.preprocessing.sequence.pad_sequences(df['colors'])
colors_input = keras.Input(shape=(5,), dtype="int32", name="colors")
colors_embed = keras.layers.Embedding(input_dim=5, output_dim=4)(colors_input)
colors_pooled = keras.layers.GlobalAveragePooling1D()(colors_embed)

keywords_padded = keras.preprocessing.sequence.pad_sequences(df['keywords'])
keywords_input = keras.Input(shape=(10,), dtype="int32", name="keywords")
keywords_embed = keras.layers.Embedding(input_dim=604, output_dim=8)(keywords_input)
keywords_pooled = keras.layers.GlobalAveragePooling1D()(keywords_embed)

subtypes_padded = keras.preprocessing.sequence.pad_sequences(df['subtype'])
subtypes_input = keras.Input(shape=(4,), dtype="int32", name="subtypes")
subtypes_embed = keras.layers.Embedding(input_dim=393, output_dim=8)(subtypes_input)
subtypes_pooled = keras.layers.GlobalAveragePooling1D()(subtypes_embed)

main_type_padded = keras.preprocessing.sequence.pad_sequences(df['main_type'])
main_type_input = keras.Input(shape=(2,), dtype="int32", name="main_type")
main_type_embed = keras.layers.Embedding(input_dim=8, output_dim=4)(main_type_input)
main_type_pooled = keras.layers.GlobalAveragePooling1D()(main_type_embed)

# %% [markdown]
# ### Tokenized Data

# %%
text_input = keras.Input(shape=(1,), dtype=tf.string, name="oracle_text")
oracle_vector = text_vectorizer(text_input)
oracle_dense = keras.layers.Dense(64, activation="relu")(oracle_vector)

# %%
#oracle_array = text_vectorizer(df["oracle_text"].values).numpy()

# %% [markdown]
# ### Model Compiling

# %%
all_inputs = [
    number_inputs,
    text_input,
    colors_input,
    keywords_input,
    subtypes_input,
    main_type_input
]

all_features = keras.layers.concatenate([
    normalized,
    oracle_dense,
    colors_pooled,
    keywords_pooled,
    subtypes_pooled,
    main_type_pooled
])

# %%
x = keras.layers.Dense(128, activation="relu")(all_features)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.Dense(32, activation="relu")(x)
output = keras.layers.Dense(1, name="price")(x)

# %%
model = keras.Model(inputs=all_inputs, outputs=output)
model.compile(optimizer="adam", loss="mse", metrics=["mae"])

# %%
early_stopping_cb = keras.callbacks.EarlyStopping(patience=25, start_from_epoch=100, monitor="mae")
model_checkpoint_cb = keras.callbacks.ModelCheckpoint(f"best_model.keras", save_best_only=True)
run_index = 1 # increment every time you train the model
run_logdir = os.path.join(os.curdir, "logs", "run_{:03d}".format(run_index))
tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)
callbacks = [early_stopping_cb, model_checkpoint_cb, tensorboard_cb]

# %%
model.fit(
    {
        "numerical": scaled_data,
        "oracle_text": df["oracle_text"].values,
        "keywords": keywords_padded,
        "colors": colors_padded,
        "subtypes": subtypes_padded,
        "main_type": main_type_padded
    },
    y=df["price"],
    epochs=200, # long ahh runtime fr
    batch_size=32,
    validation_split=0.3,
    callbacks=callbacks
)
# Out:
# Epoch 1/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 10.2799 - mae: 1.4192 - val_loss: 15.6242 - val_mae: 1.3929
# Epoch 2/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 4.9964 - mae: 0.9943 - val_loss: 32.9474 - val_mae: 1.3751
# Epoch 3/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 4.0478 - mae: 0.8907 - val_loss: 28.4687 - val_mae: 1.2458
# Epoch 4/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 3.9068 - mae: 0.8320 - val_loss: 36.4728 - val_mae: 1.3401
# Epoch 5/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 3.1584 - mae: 0.7488 - val_loss: 66.9742 - val_mae: 1.3427
# Epoch 6/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 3.1306 - mae: 0.7291 - val_loss: 59.7086 - val_mae: 1.5267
# Epoch 7/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 2.7623 - mae: 0.6777 - val_loss: 64.2163 - val_mae: 1.2855
# Epoch 8/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 2.5072 - mae: 0.6445 - val_loss: 78.2742 - val_mae: 1.2042
# Epoch 9/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 2.5206 - mae: 0.6549 - val_loss: 92.6952 - val_mae: 1.2940
# Epoch 10/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 2.4806 - mae: 0.6297 - val_loss: 114.9305 - val_mae: 1.4276
# Epoch 11/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 2.3909 - mae: 0.6323 - val_loss: 50.2237 - val_mae: 1.3022
# Epoch 12/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.9963 - mae: 0.5857 - val_loss: 91.6134 - val_mae: 1.2543
# Epoch 13/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.9489 - mae: 0.5777 - val_loss: 91.5819 - val_mae: 1.2526
# Epoch 14/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.9584 - mae: 0.5769 - val_loss: 66.9989 - val_mae: 1.4810
# Epoch 15/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 2.0153 - mae: 0.5700 - val_loss: 41.6650 - val_mae: 1.2746
# Epoch 16/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.8528 - mae: 0.5596 - val_loss: 83.7973 - val_mae: 1.3435
# Epoch 17/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.7977 - mae: 0.5510 - val_loss: 56.6618 - val_mae: 1.1187
# Epoch 18/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.9333 - mae: 0.5532 - val_loss: 32.9238 - val_mae: 1.1696
# Epoch 19/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.9166 - mae: 0.5645 - val_loss: 40.3495 - val_mae: 1.1682
# Epoch 20/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.8552 - mae: 0.5598 - val_loss: 58.0418 - val_mae: 1.3225
# Epoch 21/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 2.1638 - mae: 0.5836 - val_loss: 145.8450 - val_mae: 1.4622
# Epoch 22/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.7466 - mae: 0.5450 - val_loss: 53.2087 - val_mae: 1.1511
# Epoch 23/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.6948 - mae: 0.5353 - val_loss: 120.5323 - val_mae: 1.3491
# Epoch 24/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.7020 - mae: 0.5360 - val_loss: 70.1108 - val_mae: 1.2246
# Epoch 25/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.7059 - mae: 0.5344 - val_loss: 102.2685 - val_mae: 1.3702
# Epoch 26/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.7220 - mae: 0.5316 - val_loss: 29.0766 - val_mae: 1.2039
# Epoch 27/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.4931 - mae: 0.5092 - val_loss: 126.8251 - val_mae: 1.4303
# Epoch 28/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.5962 - mae: 0.5108 - val_loss: 54.6215 - val_mae: 1.1409
# Epoch 29/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.5448 - mae: 0.5113 - val_loss: 81.0355 - val_mae: 1.2322
# Epoch 30/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.5099 - mae: 0.5069 - val_loss: 48.5516 - val_mae: 1.1814
# Epoch 31/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.5745 - mae: 0.5133 - val_loss: 61.4502 - val_mae: 1.3455
# Epoch 32/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.6486 - mae: 0.5203 - val_loss: 67.2805 - val_mae: 1.2556
# Epoch 33/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.4899 - mae: 0.5031 - val_loss: 40.7862 - val_mae: 1.1714
# Epoch 34/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.5579 - mae: 0.5118 - val_loss: 81.9174 - val_mae: 1.3417
# Epoch 35/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.7141 - mae: 0.5224 - val_loss: 122.4885 - val_mae: 1.2788
# Epoch 36/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.4644 - mae: 0.4953 - val_loss: 142.9225 - val_mae: 1.2641
# Epoch 37/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.3957 - mae: 0.4811 - val_loss: 47.7491 - val_mae: 1.1519
# Epoch 38/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.3691 - mae: 0.4819 - val_loss: 122.3619 - val_mae: 1.4351
# Epoch 39/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.4041 - mae: 0.4869 - val_loss: 59.0155 - val_mae: 1.2180
# Epoch 40/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.7921 - mae: 0.5228 - val_loss: 112.5136 - val_mae: 1.3714
# Epoch 41/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.3899 - mae: 0.4744 - val_loss: 105.9133 - val_mae: 1.1950
# Epoch 42/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.4888 - mae: 0.4973 - val_loss: 36.3353 - val_mae: 1.2560
# Epoch 43/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.4032 - mae: 0.4820 - val_loss: 71.0426 - val_mae: 1.3658
# Epoch 44/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.3742 - mae: 0.4746 - val_loss: 180.4033 - val_mae: 1.3807
# Epoch 45/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.3155 - mae: 0.4717 - val_loss: 119.0805 - val_mae: 1.2553
# Epoch 46/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.3432 - mae: 0.4766 - val_loss: 68.4623 - val_mae: 1.2269
# Epoch 47/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.3634 - mae: 0.4718 - val_loss: 183.0789 - val_mae: 1.4455
# Epoch 48/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.2867 - mae: 0.4689 - val_loss: 37.3842 - val_mae: 1.1280
# Epoch 49/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.4042 - mae: 0.4789 - val_loss: 170.0442 - val_mae: 1.2549
# Epoch 50/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.3930 - mae: 0.4722 - val_loss: 114.1834 - val_mae: 1.2257
# Epoch 51/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.3423 - mae: 0.4718 - val_loss: 21.6374 - val_mae: 1.0674
# Epoch 52/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.9388 - mae: 0.5215 - val_loss: 322.6662 - val_mae: 1.4994
# Epoch 53/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.4277 - mae: 0.4770 - val_loss: 139.5170 - val_mae: 1.3040
# Epoch 54/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.2875 - mae: 0.4652 - val_loss: 85.5375 - val_mae: 1.1612
# Epoch 55/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.2450 - mae: 0.4601 - val_loss: 237.7794 - val_mae: 1.3673
# Epoch 56/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.2733 - mae: 0.4524 - val_loss: 113.6246 - val_mae: 1.5164
# Epoch 57/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.4450 - mae: 0.4833 - val_loss: 213.4169 - val_mae: 1.3003
# Epoch 58/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.2419 - mae: 0.4528 - val_loss: 192.7826 - val_mae: 1.3106
# Epoch 59/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1346 - mae: 0.4427 - val_loss: 369.7101 - val_mae: 1.3624
# Epoch 60/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.2344 - mae: 0.4561 - val_loss: 151.0870 - val_mae: 1.4706
# Epoch 61/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.2120 - mae: 0.4525 - val_loss: 149.4828 - val_mae: 1.2429
# Epoch 62/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.2752 - mae: 0.4617 - val_loss: 179.4273 - val_mae: 1.2592
# Epoch 63/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1633 - mae: 0.4371 - val_loss: 228.1050 - val_mae: 1.2838
# Epoch 64/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1629 - mae: 0.4350 - val_loss: 146.3899 - val_mae: 1.3541
# Epoch 65/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1629 - mae: 0.4446 - val_loss: 145.0084 - val_mae: 1.3504
# Epoch 66/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1398 - mae: 0.4355 - val_loss: 133.9247 - val_mae: 1.2784
# Epoch 67/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.3965 - mae: 0.4616 - val_loss: 133.4896 - val_mae: 1.3561
# Epoch 68/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1609 - mae: 0.4330 - val_loss: 75.3658 - val_mae: 1.2747
# Epoch 69/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1937 - mae: 0.4476 - val_loss: 211.6999 - val_mae: 1.3582
# Epoch 70/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.2281 - mae: 0.4366 - val_loss: 151.7398 - val_mae: 1.3536
# Epoch 71/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1932 - mae: 0.4426 - val_loss: 281.2427 - val_mae: 1.3652
# Epoch 72/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.2386 - mae: 0.4492 - val_loss: 293.9037 - val_mae: 1.4289
# Epoch 73/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0891 - mae: 0.4205 - val_loss: 214.6104 - val_mae: 1.2830
# Epoch 74/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1185 - mae: 0.4320 - val_loss: 180.7555 - val_mae: 1.2780
# Epoch 75/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.2246 - mae: 0.4430 - val_loss: 347.0721 - val_mae: 1.4523
# Epoch 76/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1736 - mae: 0.4378 - val_loss: 213.0925 - val_mae: 1.3280
# Epoch 77/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0917 - mae: 0.4261 - val_loss: 138.7424 - val_mae: 1.2645
# Epoch 78/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1103 - mae: 0.4173 - val_loss: 50.7280 - val_mae: 1.2948
# Epoch 79/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.2306 - mae: 0.4359 - val_loss: 224.1775 - val_mae: 1.3537
# Epoch 80/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.2562 - mae: 0.4388 - val_loss: 35.6958 - val_mae: 1.0206
# Epoch 81/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.2786 - mae: 0.4474 - val_loss: 101.3167 - val_mae: 1.2646
# Epoch 82/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1032 - mae: 0.4253 - val_loss: 446.2821 - val_mae: 1.4343
# Epoch 83/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0681 - mae: 0.4097 - val_loss: 237.0077 - val_mae: 1.3510
# Epoch 84/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0383 - mae: 0.4157 - val_loss: 275.7477 - val_mae: 1.3961
# Epoch 85/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1018 - mae: 0.4178 - val_loss: 232.6037 - val_mae: 1.4281
# Epoch 86/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1548 - mae: 0.4294 - val_loss: 278.3885 - val_mae: 1.4790
# Epoch 87/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1985 - mae: 0.4377 - val_loss: 190.1842 - val_mae: 1.3257
# Epoch 88/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1670 - mae: 0.4310 - val_loss: 664.8320 - val_mae: 1.5520
# Epoch 89/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.2056 - mae: 0.4296 - val_loss: 759.3065 - val_mae: 1.5075
# Epoch 90/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1172 - mae: 0.4248 - val_loss: 434.3355 - val_mae: 1.3658
# Epoch 91/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1398 - mae: 0.4223 - val_loss: 694.2103 - val_mae: 1.5893
# Epoch 92/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0744 - mae: 0.4104 - val_loss: 396.6672 - val_mae: 1.3654
# Epoch 93/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0957 - mae: 0.4118 - val_loss: 549.4280 - val_mae: 1.3812
# Epoch 94/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0733 - mae: 0.4131 - val_loss: 333.3726 - val_mae: 1.5564
# Epoch 95/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1015 - mae: 0.4199 - val_loss: 390.0432 - val_mae: 1.4789
# Epoch 96/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0722 - mae: 0.4111 - val_loss: 352.1416 - val_mae: 1.3780
# Epoch 97/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0932 - mae: 0.4102 - val_loss: 387.2852 - val_mae: 1.4434
# Epoch 98/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1888 - mae: 0.4288 - val_loss: 153.2382 - val_mae: 1.2285
# Epoch 99/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0486 - mae: 0.4165 - val_loss: 391.3111 - val_mae: 1.4058
# Epoch 100/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0949 - mae: 0.4149 - val_loss: 200.6767 - val_mae: 1.2985
# Epoch 101/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1230 - mae: 0.4209 - val_loss: 207.4389 - val_mae: 1.3020
# Epoch 102/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0602 - mae: 0.4087 - val_loss: 160.9756 - val_mae: 1.2716
# Epoch 103/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.9966 - mae: 0.4013 - val_loss: 313.0553 - val_mae: 1.3519
# Epoch 104/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.9402 - mae: 0.3902 - val_loss: 332.4781 - val_mae: 1.3799
# Epoch 105/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1952 - mae: 0.4192 - val_loss: 198.3179 - val_mae: 1.3305
# Epoch 106/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0482 - mae: 0.4116 - val_loss: 218.4182 - val_mae: 1.3511
# Epoch 107/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.9965 - mae: 0.4012 - val_loss: 122.9155 - val_mae: 1.2960
# Epoch 108/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0260 - mae: 0.4068 - val_loss: 243.4212 - val_mae: 1.4677
# Epoch 109/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1299 - mae: 0.4215 - val_loss: 292.3493 - val_mae: 1.4244
# Epoch 110/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1278 - mae: 0.4177 - val_loss: 348.1270 - val_mae: 1.4730
# Epoch 111/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.9650 - mae: 0.3980 - val_loss: 95.4477 - val_mae: 1.1733
# Epoch 112/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0106 - mae: 0.3961 - val_loss: 72.5639 - val_mae: 1.3267
# Epoch 113/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0287 - mae: 0.4107 - val_loss: 154.0822 - val_mae: 1.2899
# Epoch 114/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0066 - mae: 0.4018 - val_loss: 164.8057 - val_mae: 1.3584
# Epoch 115/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.9648 - mae: 0.3898 - val_loss: 128.7336 - val_mae: 1.2610
# Epoch 116/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.2142 - mae: 0.4260 - val_loss: 92.8240 - val_mae: 1.2098
# Epoch 117/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0773 - mae: 0.4076 - val_loss: 70.6059 - val_mae: 1.2332
# Epoch 118/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0957 - mae: 0.4033 - val_loss: 141.5697 - val_mae: 1.3165
# Epoch 119/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0002 - mae: 0.3965 - val_loss: 210.3200 - val_mae: 1.3170
# Epoch 120/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.9098 - mae: 0.3825 - val_loss: 244.3678 - val_mae: 1.3028
# Epoch 121/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1187 - mae: 0.4171 - val_loss: 478.6357 - val_mae: 1.4238
# Epoch 122/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0165 - mae: 0.4143 - val_loss: 240.9720 - val_mae: 1.4805
# Epoch 123/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.9591 - mae: 0.3896 - val_loss: 486.9320 - val_mae: 1.5189
# Epoch 124/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1703 - mae: 0.4258 - val_loss: 116.8570 - val_mae: 1.2420
# Epoch 125/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.9922 - mae: 0.3923 - val_loss: 338.3428 - val_mae: 1.3872
# Epoch 126/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.9880 - mae: 0.3928 - val_loss: 174.5956 - val_mae: 1.3405
# Epoch 127/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.9465 - mae: 0.3891 - val_loss: 54.4218 - val_mae: 1.1955
# Epoch 128/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.9588 - mae: 0.3882 - val_loss: 342.6223 - val_mae: 1.3455
# Epoch 129/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0162 - mae: 0.3958 - val_loss: 43.9617 - val_mae: 1.1447
# Epoch 130/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0026 - mae: 0.3949 - val_loss: 83.2795 - val_mae: 1.3361
# Epoch 131/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.9891 - mae: 0.3968 - val_loss: 796.0645 - val_mae: 1.4911
# Epoch 132/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0459 - mae: 0.3951 - val_loss: 77.0680 - val_mae: 1.1599
# Epoch 133/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.9828 - mae: 0.3994 - val_loss: 233.5413 - val_mae: 1.4898
# Epoch 134/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0270 - mae: 0.3914 - val_loss: 449.0464 - val_mae: 1.5232
# Epoch 135/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.9104 - mae: 0.3807 - val_loss: 324.9482 - val_mae: 1.4153
# Epoch 136/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8870 - mae: 0.3749 - val_loss: 541.6133 - val_mae: 1.4034
# Epoch 137/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.9079 - mae: 0.3789 - val_loss: 498.4347 - val_mae: 1.5738
# Epoch 138/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8921 - mae: 0.3856 - val_loss: 318.5394 - val_mae: 1.4359
# Epoch 139/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.9610 - mae: 0.3960 - val_loss: 118.3251 - val_mae: 1.3462
# Epoch 140/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.9149 - mae: 0.3870 - val_loss: 125.7595 - val_mae: 1.2236
# Epoch 141/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0526 - mae: 0.3954 - val_loss: 408.8609 - val_mae: 1.4664
# Epoch 142/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.9929 - mae: 0.3856 - val_loss: 307.0647 - val_mae: 1.4233
# Epoch 143/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.9355 - mae: 0.3838 - val_loss: 90.4156 - val_mae: 1.1948
# Epoch 144/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.9373 - mae: 0.3873 - val_loss: 110.2777 - val_mae: 1.2888
# Epoch 145/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.9290 - mae: 0.3772 - val_loss: 70.3022 - val_mae: 1.2795
# Epoch 146/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8414 - mae: 0.3693 - val_loss: 352.2877 - val_mae: 1.4620
# Epoch 147/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.9789 - mae: 0.3879 - val_loss: 246.2626 - val_mae: 1.3897
# Epoch 148/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8655 - mae: 0.3661 - val_loss: 233.4025 - val_mae: 1.4058
# Epoch 149/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.9292 - mae: 0.3727 - val_loss: 207.7240 - val_mae: 1.4490
# Epoch 150/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.9590 - mae: 0.3819 - val_loss: 363.3766 - val_mae: 1.4899
# Epoch 151/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8932 - mae: 0.3770 - val_loss: 104.4035 - val_mae: 1.2424
# Epoch 152/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0431 - mae: 0.3966 - val_loss: 438.6462 - val_mae: 1.3514
# Epoch 153/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0420 - mae: 0.3940 - val_loss: 353.0407 - val_mae: 1.3859
# Epoch 154/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8451 - mae: 0.3727 - val_loss: 727.3293 - val_mae: 1.4137
# Epoch 155/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.9507 - mae: 0.3880 - val_loss: 297.5972 - val_mae: 1.3506
# Epoch 156/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8550 - mae: 0.3688 - val_loss: 422.2499 - val_mae: 1.3803
# Epoch 157/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0508 - mae: 0.3947 - val_loss: 401.8954 - val_mae: 1.4513
# Epoch 158/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.9555 - mae: 0.3765 - val_loss: 392.0692 - val_mae: 1.3637
# Epoch 159/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8352 - mae: 0.3661 - val_loss: 173.4825 - val_mae: 1.2606
# Epoch 160/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8543 - mae: 0.3576 - val_loss: 85.7050 - val_mae: 1.2557
# Epoch 161/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8437 - mae: 0.3621 - val_loss: 313.8262 - val_mae: 1.4468
# Epoch 162/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.9232 - mae: 0.3797 - val_loss: 112.3816 - val_mae: 1.1759
# Epoch 163/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8835 - mae: 0.3801 - val_loss: 385.1169 - val_mae: 1.3414
# Epoch 164/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.9240 - mae: 0.3727 - val_loss: 91.1269 - val_mae: 1.1409
# Epoch 165/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.9053 - mae: 0.3753 - val_loss: 210.5916 - val_mae: 1.2885
# Epoch 166/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8659 - mae: 0.3664 - val_loss: 239.1530 - val_mae: 1.3305
# Epoch 167/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8873 - mae: 0.3685 - val_loss: 703.1801 - val_mae: 1.4710
# Epoch 168/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.9106 - mae: 0.3628 - val_loss: 632.9223 - val_mae: 1.4085
# Epoch 169/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.8773 - mae: 0.3627 - val_loss: 196.2833 - val_mae: 1.1808
# Epoch 170/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.9516 - mae: 0.3650 - val_loss: 152.0838 - val_mae: 1.2682
# Epoch 171/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.8213 - mae: 0.3633 - val_loss: 936.6609 - val_mae: 1.4789
# Epoch 172/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.8551 - mae: 0.3666 - val_loss: 431.5814 - val_mae: 1.3992
# Epoch 173/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.8943 - mae: 0.3641 - val_loss: 350.5932 - val_mae: 1.6304
# Epoch 174/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.9072 - mae: 0.3719 - val_loss: 175.0587 - val_mae: 1.2708
# Epoch 175/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.8568 - mae: 0.3612 - val_loss: 632.8796 - val_mae: 1.5021
# Epoch 176/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.8295 - mae: 0.3662 - val_loss: 543.5923 - val_mae: 1.4373
# Epoch 177/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.8551 - mae: 0.3647 - val_loss: 204.7080 - val_mae: 1.2963
# Epoch 178/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.9182 - mae: 0.3695 - val_loss: 182.3015 - val_mae: 1.3111
# Epoch 179/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.8704 - mae: 0.3741 - val_loss: 120.4221 - val_mae: 1.2234
# Epoch 180/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.8445 - mae: 0.3622 - val_loss: 447.2978 - val_mae: 1.3466
# Epoch 181/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.7879 - mae: 0.3527 - val_loss: 100.4800 - val_mae: 1.2145
# Epoch 182/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.8759 - mae: 0.3632 - val_loss: 93.7567 - val_mae: 1.3638
# Epoch 183/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.0360 - mae: 0.3795 - val_loss: 487.0480 - val_mae: 1.5305
# Epoch 184/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.8406 - mae: 0.3675 - val_loss: 111.8009 - val_mae: 1.2341
# Epoch 185/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.8525 - mae: 0.3599 - val_loss: 61.6637 - val_mae: 1.2121
# Epoch 186/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.8600 - mae: 0.3595 - val_loss: 271.2886 - val_mae: 1.2929
# Epoch 187/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.8375 - mae: 0.3640 - val_loss: 669.9111 - val_mae: 1.4634
# Epoch 188/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.0174 - mae: 0.3737 - val_loss: 552.6625 - val_mae: 1.4146
# Epoch 189/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.9819 - mae: 0.3917 - val_loss: 128.1255 - val_mae: 1.2514
# Epoch 190/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.9294 - mae: 0.3751 - val_loss: 660.3664 - val_mae: 1.4316
# Epoch 191/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.8704 - mae: 0.3592 - val_loss: 180.0612 - val_mae: 1.2325
# Epoch 192/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.8368 - mae: 0.3613 - val_loss: 151.4983 - val_mae: 1.2925
# Epoch 193/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.7998 - mae: 0.3561 - val_loss: 221.9120 - val_mae: 1.2835
# Epoch 194/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.8622 - mae: 0.3678 - val_loss: 431.1399 - val_mae: 1.4328
# Epoch 195/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.9606 - mae: 0.3704 - val_loss: 569.7527 - val_mae: 1.4725
# Epoch 196/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.8486 - mae: 0.3602 - val_loss: 87.7748 - val_mae: 1.2456
# Epoch 197/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.8356 - mae: 0.3561 - val_loss: 1016.1624 - val_mae: 1.6296
# Epoch 198/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.8324 - mae: 0.3595 - val_loss: 1092.4076 - val_mae: 1.5629
# Epoch 199/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.7908 - mae: 0.3551 - val_loss: 295.1971 - val_mae: 1.3679
# Epoch 200/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.8175 - mae: 0.3605 - val_loss: 146.2861 - val_mae: 1.2572

# %% [markdown]
# #### Initial Results:
#
# MAE of 0.36 cents, loss of 0.81. Will try to optimize!

# %% [markdown]
# ## Model Improvement
