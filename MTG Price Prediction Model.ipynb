# %% [markdown]
# # MTG Price Predictor
#
# ## About/Goals:
#
# The idea of this project is to create an ML model that can take a card's data and return the value of the card should be, based on previous cards it has analysed. This requires NLP processing for the text box, and utilizes tensorflow to build the model.
#
# Cards are evaluated purely based on what a person looking at it for the first time can see - year, text, color, etc.. nothing about format legalities, special flags, or anythingn else of the sort. Also, price is based on standard, nonfoil variant only.

# %% [markdown]
# # Data Importation and Cleaning

# %% [markdown]
# #### All imports cell

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer
import tensorflow as tf
from tensorflow.keras.layers import TextVectorization
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
import re
import os
from sklearn.preprocessing import RobustScaler

# %%
def save(file):
    file.to_pickle('data/updated_data.pkl')

def load():
    df = pd.read_pickle('data/updated_data.pkl')
    return df # band-aid work-around

# %%
df = pd.read_json("data/default_cards_08_05_2025.json")

# %%
df.columns
# Out:
# Index(['object', 'id', 'oracle_id', 'multiverse_ids', 'mtgo_id', 'arena_id',
#        'tcgplayer_id', 'cardmarket_id', 'name', 'lang', 'released_at', 'uri',
#        'scryfall_uri', 'layout', 'highres_image', 'image_status', 'image_uris',
#        'mana_cost', 'cmc', 'type_line', 'oracle_text', 'colors',
#        'color_identity', 'keywords', 'produced_mana', 'legalities', 'games',
#        'reserved', 'game_changer', 'foil', 'nonfoil', 'finishes', 'oversized',
#        'promo', 'reprint', 'variation', 'set_id', 'set', 'set_name',
#        'set_type', 'set_uri', 'set_search_uri', 'scryfall_set_uri',
#        'rulings_uri', 'prints_search_uri', 'collector_number', 'digital',
#        'rarity', 'card_back_id', 'artist', 'artist_ids', 'illustration_id',
#        'border_color', 'frame', 'full_art', 'textless', 'booster',
#        'story_spotlight', 'prices', 'related_uris', 'purchase_uris',
#        'mtgo_foil_id', 'power', 'toughness', 'flavor_text', 'edhrec_rank',
#        'penny_rank', 'all_parts', 'promo_types', 'security_stamp',
#        'card_faces', 'preview', 'watermark', 'frame_effects', 'loyalty',
#        'printed_name', 'tcgplayer_etched_id', 'flavor_name',
#        'attraction_lights', 'color_indicator', 'printed_type_line',
#        'printed_text', 'variation_of', 'life_modifier', 'hand_modifier',
#        'content_warning', 'defense'],
#       dtype='object')

# %% [markdown]
# can drop so many of these columns, only need ones that are useful.

# %% [markdown]
# ### Column Cleaning

# %%
len(df)
# Out:
# 108955

# %%
df.value_counts("variation")
#df.value_counts("oversized")
# Out:
# variation
# False    108867
# True         88
# Name: count, dtype: int64

# %%
df = df[(df["variation"]==False) & (df["reprint"]==False) & (df["oversized"]==False) & (df["promo"]==False) & (df["full_art"]==False) & (df["textless"] == False) & (df["content_warning"]!=True)]

# %%
len(df) # Dropped about 40k entries
# Out:
# 41387

# %%
doubles = df["card_faces"].dropna()
doubles.iloc[0] ## this is gonna be tough to work with
# Out:
# [{'object': 'card_face',
#   'name': "Obyra's Attendants",
#   'mana_cost': '{4}{U}',
#   'type_line': 'Creature — Faerie Wizard',
#   'oracle_text': 'Flying',
#   'power': '3',
#   'toughness': '4',
#   'flavor_text': "Obyra's devoted servants shrieked as their sleeping mistress slashed at them, unseeing.",
#   'artist': 'Andreas Zafiratos',
#   'artist_id': 'e2f13a9a-57c5-40de-81d4-3b0723899cdf',
#   'illustration_id': 'd1ea5321-62e2-4894-a79f-03b792daf2c8'},
#  {'object': 'card_face',
#   'name': 'Desperate Parry',
#   'mana_cost': '{1}{U}',
#   'type_line': 'Instant — Adventure',
#   'oracle_text': 'Target creature gets -4/-0 until end of turn. (Then exile this card. You may cast the creature later from exile.)',
#   'artist': 'Andreas Zafiratos',
#   'artist_id': 'e2f13a9a-57c5-40de-81d4-3b0723899cdf'}]

# %% [markdown]
# For first iteration of model, will be removing the multi-faced cards

# %%
df = df[df["card_faces"].isna()]

# %%
def is_legal(x):
    if 'legal' in x.values():
        return True
    else:
        return False

# %%
df["playable"] = df["legalities"].apply(is_legal)

# %%
df = df[df["playable"] == True] # remove unnplayable cards

# %%
unneeded = ['object', 'id', 'oracle_id', 'multiverse_ids', 'mtgo_id', 'arena_id',
       'tcgplayer_id', 'cardmarket_id', #'name',
         'lang', 'uri',
       'scryfall_uri', 'layout', 'highres_image', 'image_status', 'image_uris', 'legalities', 'games',
       'reserved', 'game_changer', 'finishes', 'oversized',
       'promo', 'reprint', 'variation', 'set_id', 'set', 'set_name',
       'set_type', 'set_uri', 'set_search_uri', 'scryfall_set_uri',
       'rulings_uri', 'prints_search_uri', 'collector_number', 'digital', 'card_back_id', 'artist', 'artist_ids', 'illustration_id',
       'border_color', 'frame', 'full_art', 'textless', 'booster',
       'story_spotlight', 'related_uris', 'purchase_uris',
       'mtgo_foil_id', 'flavor_text', 'edhrec_rank',
       'penny_rank', 'all_parts', 'promo_types', 'security_stamp', 'preview', 'watermark', 'frame_effects', 'loyalty',
       'printed_name', 'tcgplayer_etched_id', 'flavor_name',
       'attraction_lights', 'color_indicator', 'printed_type_line',
       'printed_text', 'variation_of', 'life_modifier', 'hand_modifier',
       'content_warning', 'defense', 'card_faces', 'foil', 'nonfoil'
       , 'playable', 'color_identity']
df = df.drop(unneeded, axis=1)

# %% [markdown]
# now that I've cleaned out cards and columns that aren't needed, I need to figure out the best way to transform this data into something that the ML model can actually use.
#
# For instance, the "type_line" column will have to be split up into various super and subtypes, probably using categorical encoding.

# %% [markdown]
# ### Type Labeling + Encoding

# %%
df["type_line"].describe() # has 4246 unique types currently
# Out:
# count       35098
# unique       3120
# top       Instant
# freq         3592
# Name: type_line, dtype: object

# %%
"""
df["creature_type"] = df["type_line"].apply(lambda x: x[10:] if "Creature" in x else "NaN")
df["planeswalker_type"] = df["type_line"].apply(lambda x: x[24:] if "Planeswalker" in x else "NaN")
df["kindred_type"] = df["type_line"].apply(lambda x: x.split()[-1] if "Kindred" in x or "Tribal" in x else "NaN")"""
# Found a better way!
# Out:
# '\ndf["creature_type"] = df["type_line"].apply(lambda x: x[10:] if "Creature" in x else "NaN")\ndf["planeswalker_type"] = df["type_line"].apply(lambda x: x[24:] if "Planeswalker" in x else "NaN")\ndf["kindred_type"] = df["type_line"].apply(lambda x: x.split()[-1] if "Kindred" in x or "Tribal" in x else "NaN")'

# %%
def filter_subtype(x):
    if "—" in x:
        ind = x.index("—")
        types = x[ind+1:].split()
        return types
    else:
        return []

# %%
def filter_maintype(x):
    types = ["Artifact", "Land", 
             #"Battle", 
             "Creature", "Enchantment", "Planeswalker", "Instant", "Sorcery"]
    cur = []
    for type in types:
        if type in x:
            cur.append(type)
    return cur

# %%
df = df[~df['type_line'].str.contains('Basic')] # remove basic lands

# %%
df["legendary"] = df["type_line"].apply(lambda x: 1 if "Legendary" in x else 0)
df["subtype"] = df["type_line"].apply(filter_subtype)
df["main_type"]=df["type_line"].apply(filter_maintype)

# %%
df["price"] = df["prices"].str["usd"].astype(float) 
df = df.drop("prices", axis=1)

# %%
df = df.dropna(subset=["price"])
df = df[df["main_type"].map(len)>0]  # had to filter out bad cards with other types such as conspiracies and stickers

# %%
#le = LabelEncoder()
#le.fit(["Artifact", "Land", "Battle", "Creature", "Enchantment", "Planeswalker", "Instant", "Sorcery"])

# %%
#df["main_type"] = df["main_type"].apply(lambda x: le.transform(x))

# %% [markdown]
# #### Changed to One-Hot Encoding!

# %%
from sklearn.preprocessing import MultiLabelBinarizer

# %%
mlb = MultiLabelBinarizer()

# %%
test = pd.DataFrame(mlb.fit_transform(df["main_type"]), columns=mlb.classes_, index=df.index)

# %%
df = df.drop('main_type', axis=1)
df = df.join(test)

# %%
le2 = LabelEncoder()

# %%
df["subtype"].values
# Out:
# array([list(['Sliver']), list(['Kor', 'Soldier']),
#        list(['Siren', 'Pirate']), ..., list([]),
#        list(['Faerie', 'Rogue']), list(['Vampire', 'Soldier'])],
#       dtype=object)

# %%
subtypes = []
for unique in df["subtype"].values:
    if unique != []:
        for val in unique:
            if val not in subtypes:
                subtypes.append(val)

le2.fit(subtypes)
# Out:
# LabelEncoder()

# %%
df["subtype"] = df["subtype"].apply(lambda x: le2.transform(x)) # slow, probably better way to do this

# %%
df = df.drop("type_line", axis=1)

# %% [markdown]
# ### Date -> Year

# %%
df["year"] = df["released_at"].apply(lambda x: x.year)
df = df.drop("released_at", axis=1)

# %% [markdown]
# ### Mana Cost Breakdown
#
# - Number of Pips
# - Is X spell?

# %%
df["is_x"] = df["mana_cost"].apply(lambda x: 1 if r"{X}" in x else 0)
#df.loc[df["is_x"] == 1]

# %%
#print("{1}{W/R}{G}{G}".replace("{", "").replace("}", " ").split())  ->  df

def pip_counter(x):
    new = x.replace("{", "").replace("}", " ").split()
    count = 0
    for x in new:
        if x.isdigit() == False and x != "X":
            count += 1

    return count

# %%
df["pip_count"] = df["mana_cost"].apply(pip_counter)
df = df.drop("mana_cost", axis=1)
#df.sort_values(by="pip_count", ascending=False)

# %% [markdown]
# ### Oracle Text Breakdown -> NLP ? Or can try a parsing method to turn text into columns
#
# - activated ability?
# - etb effect?

# %%
df["oracle_text"] = df["oracle_text"].apply(lambda x: x.lower().replace("\n", ". "))

# %% [markdown]
# #### Main Phrases

# %% [markdown]
# using vectorizer to figure out most common substrings

# %%
vectorizer = CountVectorizer(ngram_range=(4, 7), lowercase=True, stop_words=None)

# %%
X = vectorizer.fit_transform(df["oracle_text"])

# %%
sum_words = X.sum(axis=0)
word_freq = [(word, sum_words[0, idx]) for word, idx in vectorizer.vocabulary_.items()]
word_freq = sorted(word_freq, key=lambda x: x[1], reverse=True)

# %%
common_phrases = pd.DataFrame(word_freq, columns=['phrase', 'count'])
common_phrases.iloc[:10]
# Out:
#                        phrase  count
# 0           until end of turn   5990
# 1         at the beginning of   3261
# 2   when this creature enters   3049
# 3           gets until end of   2131
# 4      gets until end of turn   2130
# 5       the beginning of your   1869
# 6    at the beginning of your   1814
# 7    card from your graveyard   1593
# 8     creature gets until end   1570
# 9  creature gets until end of   1570

# %%
"""
PHRASES = { # starter phrases
    r"when.*enters": "etb",
    r"until end of turn": "eot",
    r"beginning of .* upkeep": "b_o_u",
    r"search .* library": "tutor",
    r"without paying": "free",
    r"whenever .* attacks": "a_t",
    r"deals combat damage": "c_d_t",
    r"look at the tzo.*p": "s_s_t",
    r"return.*graveyard.*battlefield": "reanimate",
    r"when.*(this|a).*dies": "o_d_t",
    r"when.*(this|a).*leaves.": "l_b_t",
}"""
# Out:
# '\nPHRASES = { # starter phrases\n    r"when.*enters": "etb",\n    r"until end of turn": "eot",\n    r"beginning of .* upkeep": "b_o_u",\n    r"search .* library": "tutor",\n    r"without paying": "free",\n    r"whenever .* attacks": "a_t",\n    r"deals combat damage": "c_d_t",\n    r"look at the tzo.*p": "s_s_t",\n    r"return.*graveyard.*battlefield": "reanimate",\n    r"when.*(this|a).*dies": "o_d_t",\n    r"when.*(this|a).*leaves.": "l_b_t",\n}'

# %%
#def canonicalize_text(str):
#    for phr, rep in PHRASES.items():
#        if re.search(phr, str) != None:
#            str = re.sub(phr, rep, str)
#    return str

# %%
#df["oracle_text"] = df["oracle_text"].apply(canonicalize_text)

# %%
def extract_math_expression_with_variables(input_string):
  pattern = r'[\d\s.+\-*/(){}:a-zA-Z]'  # Matches digits, dot, plus, minus, asterisk, slash, parentheses, and letters
  
  # Use re.findall() to find all non-overlapping matches of the pattern
  matches = re.findall(pattern, input_string)
  
  # Join the matched characters back into a string
  return "".join(matches)

# %%
df["oracle_text"] = df["oracle_text"].apply(lambda x: extract_math_expression_with_variables(x))

# %%
def find_activated_abilities(input_string):
  patterns = r"pay {|:"  
    
    # Use re.findall() to find all non-overlapping matches of the pattern

  match = re.search(patterns, input_string)
  if match:
    str = input_string
  else:
    str = "None"

  return str

# %%
def cost_calc(input):
    if input != "None":
        matches = re.findall(r'pay \{.*\}+', input)
        if matches == []:
            matches = re.findall(r'((?:\{\d?[a-z]?\/?[a-z]?+\}\s?+)+:)|((?:\{\d?[a-z]?\/?[a-z]?+\}\s?+)[\da-z\s].+?):', input)
                #r'(?:((?:\{\d?[a-z]?\/?[a-z]?+\})\s?)+:)|(?:((?:\{\d?[a-z]?\/?[a-z]?+\})\s?)+[\da-z\s].+?:)', input)
            if matches == []:
                matches = ["{0}"]
            else:
                i = 0
                while i <= len(matches)-1:
                    matches[i] = [capture for capture in matches[i] if capture != ''][0]
                    i += 1
                   
        else:
            matches = [matches[0][4:]]
    else:   
        matches = []
    return matches

# %%
def cost_to_num(input):
    sum = []
    if input != []:
        for capt in input:
            i = 0
            parens = capt.find("(")
            if parens != -1:
                i = parens
            j = i + 1
            cost = 0
            while j <= len(capt)-1:
                if capt[i] == "{":
                    while capt[j] != "}":
                        j += 1
                    i += 1
                    if capt[i] == "t":
                        cost += 0.5
                    elif capt[i].isdigit() == False:
                        if capt[i] != "x":
                            cost += 1
                    else:
                        num = ''
                        while i != j:
                            if capt[i].isdigit():
                                num += capt[i]
                                i += 1
                            else:
                                i = j
                        cost += int(num)
                j += 1
                i = j-1
            sum.append(cost)
    return sum

# %%
df["activated_ability"] = df["oracle_text"].apply(lambda x: find_activated_abilities(x))
df["has_activated_ability"] = df["activated_ability"].apply(lambda x: 1 if x != "None" else 0)

# %%
df["activated_ability_cost"] = df["activated_ability"].apply(lambda x: cost_calc(x))

# %%
def remove_cost(input):
    if input["has_activated_ability"] == 1:
        costs = input["activated_ability_cost"]
        for cost in costs:
            cap = input["oracle_text"].find(cost)
            end = cap + len(cost)
            input["oracle_text"] = input["oracle_text"][:cap] + input["oracle_text"][end:]
    return input

# %%
df = df.apply(remove_cost, axis=1)

# %%
df["activated_ability_cost"] = df["activated_ability_cost"].apply(lambda x: cost_to_num(x))

# %%
text_vectorizer = TextVectorization(
    max_tokens=4000, # increased vocab size
    output_mode='int',
    ngrams = (2,6),
    encoding='utf-8'
)

# %%
text_vectorizer.adapt(df["oracle_text"])

# %%
df = df.drop("activated_ability", axis=1)

# %% [markdown]
# ### Rarity Encoding

# %%
df["rarity"].value_counts()
# Out:
# rarity
# rare        11445
# common       9878
# uncommon     8967
# mythic       1987
# special         2
# Name: count, dtype: int64

# %%
df["rarity"] = df["rarity"].apply(lambda x: "common" if x == "special" else x) # the two special cards have common rarity on scryfall

# %%
def rarity_encoding(x):
    if x == "common":
        return 0
    elif x == "uncommon":
        return 1
    elif x == "rare":
        return 2
    else:
        return 3

# %%
df["rarity"] = df["rarity"].apply(lambda x: rarity_encoding(x))

# %% [markdown]
# ### Keyword Encoding

# %%
keywrd_encoder = LabelEncoder()

# %%
keywords = [] # taking code from earlier
for unique in df["keywords"].values:
    if unique != []:
        for val in unique:
            if val not in keywords:
                keywords.append(val)

keywrd_encoder.fit(keywords)
# Out:
# LabelEncoder()

# %%
len(keywords)
# Out:
# 604

# %%
df["keywords"] = df["keywords"].apply(lambda x: keywrd_encoder.transform(x))

# %% [markdown]
# ### Color Identity Encoding (one more time!)
#
# definitely could've done a for loop for each column i wanted to encode but oh well it's a little late for that

# %%
c_i = LabelEncoder()

# %%
c_i.fit(["W", "G", "R", "B", "U"])
# Out:
# LabelEncoder()

# %%
c_i.transform(["W", "U"])
# Out:
# array([4, 3])

# %%
df["colors"] = df["colors"].apply(lambda x: c_i.transform(x))

# %% [markdown]
# ### Produced Mana
#
# changing this to binary value if it does(n't)

# %%
df["produced_mana"] = df["produced_mana"].replace(pd.NA, 0)

# %%
df["produced_mana"] = df["produced_mana"].apply(lambda x: 1 if x != 0 else x)

# %% [markdown]
# ### Final Step: Replace Power/Toughness NaN with -1

# %%
df["power"] = pd.to_numeric(df["power"], errors="coerce").fillna(-1)
df["toughness"] = pd.to_numeric(df["toughness"], errors="coerce").fillna(-1)

# %% [markdown]
# ### Final Data Filtering

# %%
df = df.loc[(df["price"] <= 500) & (df["price"] >= 0.05) & (df["year"] >= 2000)] # filter out cards that are too expensive/cheap/old

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#                       name  cmc  \
# 0              Fury Sliver  6.0
# 1            Kor Outfitter  2.0
# 2            Siren Lookout  3.0
# 3      Surge of Brilliance  2.0
# 4         Venerable Knight  1.0
# ...                    ...  ...
# 25060      Morkrut Banshee  5.0
# 25061   Deeproot Historian  4.0
# 25062  Aggressive Biomancy  2.0
# 25063  Faerie Bladecrafter  3.0
# 25064  Exultant Skymarcher  3.0
#
#                                              oracle_text  colors    keywords  \
# 0               all sliver creatures have double strike.     [2]          []
# 1      when this creature enters you may attach targe...     [4]          []
# 2      flying. when this creature enters it explores....     [3]  [230, 198]
# 3      paradox  draw a card for each spell youve cast...     [3]  [390, 238]
# 4      when this creature dies put a +1/+1 counter on...     [4]          []
# ...                                                  ...     ...         ...
# 25060  morbid  when this creature enters if a creatur...     [0]       [366]
# 25061  merfolk and druid cards in your graveyard have...     [1]          []
# 25062  create x tokens that are copies of target crea...  [1, 3]       [215]
# 25063  flying. whenever one or more faeries you contr...     [0]       [230]
# 25064                                             flying     [4]       [230]
#
#        produced_mana  rarity  power  toughness  legendary  ... Enchantment  \
# 0                  0       1    3.0        3.0          0  ...           0
# 1                  0       0    2.0        2.0          0  ...           0
# 2                  0       0    1.0        2.0          0  ...           0
# 3                  0       1   -1.0       -1.0          0  ...           0
# 4                  0       1    2.0        1.0          0  ...           0
# ...              ...     ...    ...        ...        ...  ...         ...
# 25060              0       1    4.0        4.0          0  ...           0
# 25061              0       2    3.0        3.0          0  ...           0
# 25062              0       2   -1.0       -1.0          0  ...           0
# 25063              0       2    2.0        2.0          0  ...           0
# 25064              0       0    2.0        3.0          0  ...           0
#
#        Instant  Land  Planeswalker  Sorcery  year  is_x  pip_count  \
# 0            0     0             0        0  2006     0          1
# 1            0     0             0        0  2009     0          2
# 2            0     0             0        0  2017     0          1
# 3            1     0             0        0  2023     0          1
# 4            0     0             0        0  2019     0          1
# ...        ...   ...           ...      ...   ...   ...        ...
# 25060        0     0             0        0  2011     0          2
# 25061        0     0             0        0  2023     0          1
# 25062        0     0             0        1  2024     1          2
# 25063        0     0             0        0  2023     0          1
# 25064        0     0             0        0  2018     0          2
#
#        has_activated_ability  activated_ability_cost
# 0                          0                      []
# 1                          0                      []
# 2                          0                      []
# 3                          1                     [2]
# 4                          0                      []
# ...                      ...                     ...
# 25060                      0                      []
# 25061                      0                      []
# 25062                      0                      []
# 25063                      0                      []
# 25064                      0                      []
#
# [25065 rows x 24 columns]

# %% [markdown]
# ### Additional Rows Added Later

# %%
df["num_colors"] = df["colors"].apply(lambda x: len(x))
#df["num_keywords"] = df["keywords"].apply(lambda x: len(x))
#df["num_subtypes"] = df["subtype"].apply(lambda x: len(x))
#df["num_maintypes"] = df["main_type"].apply(lambda x: len(x))
df["oracle_length"] = df["oracle_text"].apply(lambda x: len(x))
df["length per cmc"] = df["oracle_length"]/df["cmc"]
df["length per cmc"] = df["length per cmc"].replace(np.inf, 0)
df["length per cmc"] = df["length per cmc"].replace(np.nan, 0)

# %%
df.drop_duplicates(subset="name", keep="first", inplace=True)

# %%
save(df)

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Numerical Data

# %%
numerical = df.drop(["name", "oracle_text", "colors", "keywords", "subtype", "price", "activated_ability_cost"], axis=1)

# %%
numerical.columns
# Out:
# Index(['cmc', 'produced_mana', 'rarity', 'power', 'toughness', 'legendary',
#        'Artifact', 'Creature', 'Enchantment', 'Instant', 'Land',
#        'Planeswalker', 'Sorcery', 'year', 'is_x', 'pip_count',
#        'has_activated_ability', 'num_colors', 'oracle_length',
#        'length per cmc'],
#       dtype='object')

# %%
len(numerical)
# Out:
# 21309

# %%
scaler = RobustScaler()
scaled_data = scaler.fit_transform(numerical)

# %%
number_inputs = keras.Input(shape=(20,), name="numerical")
normalized = keras.layers.Normalization()(number_inputs)

# %%
price_scaler = RobustScaler()

# %%
price_scaled = price_scaler.fit_transform(pd.DataFrame(df["price"]))

# %%
price_scaled
# Out:
# array([[ 0.20833333],
#        [-0.125     ],
#        [-0.25      ],
#        ...,
#        [ 0.41666667],
#        [-0.22916667],
#        [-0.29166667]])

# %% [markdown]
# ### Array Data

# %% [markdown]
# describing code below:
# have to pad all the array inputs, tell keras the shape of the input, and create an embedding layer to vectorize said input
#
# input_dim is equal to number of unique ids

# %%
colors_padded = keras.preprocessing.sequence.pad_sequences(df['colors'])
colors_input = keras.Input(shape=(5,), dtype="float32", name="colors")
colors_embed = keras.layers.Embedding(input_dim=5, output_dim=4)(colors_input)
#colors_norm = keras.layers.Normalization()(colors_embed)
colors_pooled = keras.layers.GlobalAveragePooling1D()(colors_embed)

keywords_padded = keras.preprocessing.sequence.pad_sequences(df['keywords'])
keywords_input = keras.Input(shape=(10,), dtype="float32", name="keywords")
keywords_embed = keras.layers.Embedding(input_dim=604, output_dim=8)(keywords_input)
#keywords_norm = keras.layers.Normalization()(keywords_embed)
keywords_pooled = keras.layers.GlobalAveragePooling1D()(keywords_embed)

subtypes_padded = keras.preprocessing.sequence.pad_sequences(df['subtype'])
subtypes_input = keras.Input(shape=(4,), dtype="float32", name="subtypes")
subtypes_embed = keras.layers.Embedding(input_dim=393, output_dim=8)(subtypes_input)
#subtypes_norm = keras.layers.Normalization()(subtypes_embed)
subtypes_pooled = keras.layers.GlobalAveragePooling1D()(subtypes_embed)

aac_padded = keras.preprocessing.sequence.pad_sequences(df['activated_ability_cost'])
aac_input = keras.Input(shape=(5,), dtype="float32", name="aac")
aac_embed = keras.layers.Embedding(input_dim=199, output_dim=8)(aac_input)
#aac_norm = keras.layers.Normalization()(aac_embed)
aac_pooled = keras.layers.GlobalAveragePooling1D()(aac_embed)

#main_type_padded = keras.preprocessing.sequence.pad_sequences(df['main_type'])
#main_type_input = keras.Input(shape=(2,), dtype="int32", name="main_type")
#main_type_embed = keras.layers.Embedding(input_dim=8, output_dim=4)(main_type_input)
#main_type_pooled = keras.layers.GlobalAveragePooling1D()(main_type_embed)

# %% [markdown]
# ### Tokenized Data

# %%
text_input = keras.Input(shape=(), dtype=tf.string, name="oracle_text")
oracle_vector = text_vectorizer(text_input)
oracle_embed = keras.layers.Embedding(input_dim=4000, output_dim=512)(oracle_vector) #increased output_dim from 256 -> 512
oracle_pooled = keras.layers.GlobalAveragePooling1D()(oracle_embed)

# %%
#oracle_array = text_vectorizer(df["oracle_text"].values).numpy()

# %%
x_train = {
        "numerical": scaled_data[:18000],
        "oracle_text": df["oracle_text"].values[:18000],
        "keywords": keywords_padded[:18000],
        "colors": colors_padded[:18000],
        "subtypes": subtypes_padded[:18000],
        "aac": aac_padded[:18000]
    }
#y_train = df["price"][:18000]
y_train = price_scaled[:18000]
x_test = {
        "numerical": scaled_data[18000:],
        "oracle_text": df["oracle_text"].values[18000:],
        "keywords": keywords_padded[18000:],
        "colors": colors_padded[18000:],
        "subtypes": subtypes_padded[18000:],
        "aac": aac_padded[18000:]
    }
#y_test = df["price"][18000:]
y_test = price_scaled[18000:]

# %% [markdown]
# ### Model Compiling

# %%
all_inputs = [
    number_inputs,
    text_input,
    colors_input,
    keywords_input,
    subtypes_input,
    aac_input
]

all_features = keras.layers.concatenate([
    normalized,
    oracle_pooled,
    colors_pooled,
    keywords_pooled,
    subtypes_pooled,
    aac_pooled
])

# %%
x = keras.layers.Dense(64, activation="tanh")(all_features)
x = keras.layers.Normalization()(x)
x = keras.layers.Dense(32, activation="tanh")(x)
x = keras.layers.Normalization()(x)
x = keras.layers.Dense(16, activation="tanh")(x)
output = keras.layers.Dense(1, activation="linear", name="price")(x)

# %%
model = keras.Model(inputs=all_inputs, outputs=output)
model.compile(optimizer="adamax", loss=keras.losses.MeanSquaredError(), metrics=[keras.metrics.MeanAbsoluteError()])

# %%
early_stopping_cb = keras.callbacks.EarlyStopping(patience=25, start_from_epoch=20, monitor="val_loss", mode='min')
#model_checkpoint_cb = keras.callbacks.ModelCheckpoint(f"models\\best_model", save_best_only=True)
run_index = 1 # increment every time you train the model
run_logdir = os.path.join(os.curdir, "logs", "run_{:03d}".format(run_index))
tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)
callbacks = [early_stopping_cb, 
             #model_checkpoint_cb,
               tensorboard_cb]

# %%
model.fit(x_train, y_train, epochs=75, # long ahh runtime fr
    batch_size=32,
    validation_split=0.25,
    callbacks=callbacks,
    verbose=1
)

# %%
model.evaluate(x_test, y_test)
# Out:
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 41.9360 - mean_absolute_error: 2.1640
# [41.93601608276367, 2.1640121936798096]

# %% [markdown]
# #### Initial Results:
#
# Mean Absolute Error: 1.03
#
# Rerun With One-Hot Encoding: literally the same (1.025)

# %%
model.save("models\\best_model.keras")

# %%
text_vectorizer.save_assets("models\\text_vectorizer")

# %% [markdown]
# ## Model Improvement

# %%
model2 = keras.models.load_model(
    "models\\best_model.keras",
    custom_objects={
        "TextVectorization": TextVectorization,
    }
)

# %%
#numerical["price"] = df["price"]
numerical["price"] = np.concatenate((y_train,y_test))

# %%
numerical.corr().sort_values(by="price", ascending=False)["price"]
# Out:
# price                    1.000000
# rarity                   0.292915
# legendary                0.152600
# Land                     0.104526
# produced_mana            0.083137
# oracle_length            0.075567
# Planeswalker             0.059103
# Artifact                 0.051043
# cmc                      0.030353
# has_activated_ability    0.026905
# Enchantment              0.010717
# toughness                0.006657
# is_x                     0.005707
# power                    0.003431
# year                    -0.004188
# pip_count               -0.008071
# length per cmc          -0.008794
# Sorcery                 -0.031628
# Instant                 -0.038415
# Creature                -0.046203
# num_colors              -0.053613
# Name: price, dtype: float64

# %% [markdown]
# Might have to drop everything below cmc unless i can figure out a way to make power and toughness more relevant

# %% [markdown]
# ### Changes:
#
# 1. Changed activation function on dense layers from relu -> tanh
# 2. tried adding new columns (num_subtypes, num_keywords) and removed them because low correlation
# 3. Added oracle_length/cmc to try and show that low cmc cards are often better and can be evaluated higher?
# 4. Changed optimizer from adam to adamax
# 5. Removed non-mathematic symbols from oracle_text
# 6. Changed main_type array column to one-hot encoded columns
# 7. Added activated abilities columns - has_ + cost_
# 8. Testing increasing oracle_embed dims to 512
# 9. Tried scaling price (target variable)

# %% [markdown]
# #### Thinking of things:
#
# - Drop categories with poor correlation
# - Better categories? (Pow + Tough?)

# %% [markdown]
# ####  For Loop Running

# %%
def buildModel(testing, verbose=0, all_features=all_features, all_inputs=all_inputs, early_stop=False):
    num_nrns = testing["nrns"]
    activation = testing["act"]
    batch_size = testing["batch"]
    if_drop = testing["drop"]
    optimizer = testing["opt"]
    norm = testing["norm"]
    x = keras.layers.Dense(num_nrns[0], activation=activation)(all_features)
    if if_drop[0]:
        x = keras.layers.Dropout(rate=if_drop[1])(all_features)
    for num in num_nrns[1:]:
        x = keras.layers.Dense(num, activation=activation)(x)
        if norm == True:
            x = keras.layers.BatchNormalization()(x)
    output = keras.layers.Dense(1, activation="linear", name="price")(x)

    model = keras.Model(inputs=all_inputs, outputs=output)
    model.compile(optimizer=optimizer, loss=keras.losses.MeanSquaredError(), metrics=[keras.metrics.MeanAbsoluteError()])

    if early_stop:
        early_stopping_cb = keras.callbacks.EarlyStopping(patience=25, start_from_epoch=75, monitor="val_loss", mode='min')
        model_checkpoint_cb = keras.callbacks.ModelCheckpoint(f"models\\final_model.keras", save_best_only=True)
        run_index = 1
        run_logdir = os.path.join(os.curdir, "logs", "run_{:03d}".format(run_index))
        tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)
        callbacks = [early_stopping_cb, 
                    model_checkpoint_cb,
                    tensorboard_cb]

    model.fit(x_train, y_train,
    epochs=testing["eps"],
    batch_size=batch_size,
    validation_split=0.25,
    verbose=verbose,
    callbacks=callbacks
    )
    return model, model.evaluate(x_test, y_test)

# %%
bad_grid_search = [
     {"nrns": [64, 32, 16], "act": "tanh", "batch": 32, "drop": [False], "norm": True, "opt":"adamax", "eps": 50}, # base model
     {"nrns": [64, 32, 16], "act": "tanh", "batch": 128, "drop": [False],"norm": True, "opt":"adamax", "eps": 50},
     {"nrns": [64, 32, 16], "act": "relu", "batch": 32, "drop": [False],"norm": True, "opt":"adamax", "eps": 50},
     {"nrns": [256, 128, 64, 32, 16], "act": "tanh", "batch": 32, "drop": [False],"norm": True, "opt":"adamax", "eps": 50},
     {"nrns": [128, 64, 32, 16, 8], "act": "tanh", "batch": 32, "drop": [False],"norm": True, "opt":"adamax", "eps": 50},
     {"nrns": [64, 32, 16], "act": "tanh", "batch": 32, "drop": [True, 0.2], "norm": True, "opt":"adamax", "eps": 50},
     {"nrns": [64, 32, 16], "act": "tanh", "batch": 32, "drop": [True, 0.4],"norm": True, "opt":"adamax", "eps": 50},
     {"nrns": [64, 32, 16], "act": "tanh", "batch": 32, "drop": [False], "norm": False, "opt":"adamax", "eps": 50},
]

# %%
scores = []
for tests in bad_grid_search:
    result = buildModel(tests)
    scores.append([tests,result])
# Out:
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 60.6505 - mean_absolute_error: 2.2429
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 74.1374 - mean_absolute_error: 2.5901
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 108.6173 - mean_absolute_error: 2.3501
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 86.2647 - mean_absolute_error: 2.5868
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 69.0666 - mean_absolute_error: 2.2747
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 62.4984 - mean_absolute_error: 2.0689
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 61.8308 - mean_absolute_error: 2.1096
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 46.6315 - mean_absolute_error: 2.0909

# %% [markdown]
# Best: normal with either normalization off or drop = 0.2

# %%
bad_grid_search = [{"nrns": [64, 32, 16], "act": "tanh", "batch": 32, "drop": [True, 0.2], "norm": False, "opt":"adamax", "eps": 50},
                   {"nrns": [64, 32, 16], "act": "tanh", "batch": 32, "drop": [False], "norm": False,
                     "opt": keras.optimizers.Adam(learning_rate=0.001), "eps": 50},
                    {"nrns": [64, 32, 16], "act": "tanh", "batch": 32, "drop": [False], "norm": False,
                     "opt": keras.optimizers.Adam(learning_rate=0.0001), "eps": 50},
                     {"nrns": [64, 32, 16], "act": "tanh", "batch": 32, "drop": [True, 0.2], "norm": True,
                     "opt": keras.optimizers.Adam(learning_rate=0.0001), "eps": 50}
    ]

scores = []
for tests in bad_grid_search:
    result = buildModel(tests)
    scores.append(result)
# Out:
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 46.6985 - mean_absolute_error: 2.2765
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 39.8670 - mean_absolute_error: 1.5929
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 42.0418 - mean_absolute_error: 2.1846
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 49.1113 - mean_absolute_error: 2.0438

# %%
scores
# Out:
# [(<Functional name=functional_22, built=True>,
#   [46.698486328125, 2.2765324115753174]),
#  (<Functional name=functional_23, built=True>,
#   [39.866981506347656, 1.5928760766983032]),
#  (<Functional name=functional_24, built=True>,
#   [42.041786193847656, 2.1845853328704834]),
#  (<Functional name=functional_25, built=True>,
#   [49.111331939697266, 2.043816328048706])]

# %%
scores.sort(key=lambda x: x[1][1])

# %%
scores[0]
# Out:
# (<Functional name=functional_23, built=True>,
#  [39.866981506347656, 1.5928760766983032])

# %% [markdown]
# Best: {"nrns": [64, 32, 16], "act": "tanh", "batch": 32, "drop": [False], "norm": False,
#       "opt": keras.optimizers.Adam(learning_rate=0.001), "eps": 50}

# %%
scores[0][0].save("models\\best_model.keras")

# %%
model = buildModel({"nrns": [256, 128], "act": "tanh", "batch": 32, "drop": [True, 0.2], "norm": False,
      "opt": keras.optimizers.Adam(learning_rate=0.001), "eps": 100})
# Out:
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 10.2612 - mean_absolute_error: 0.9792

# %%
model[0].save("models\\100_eps.keras")

# %% [markdown]
# ### Text Vectorization Testing

# %%
def buildVectors(tokens, ngrams, dim):
    text_vectorizer = TextVectorization(
        max_tokens=tokens, # increased vocab size
        output_mode='int',
        ngrams = ngrams,
        encoding='utf-8'
    )
    text_vectorizer.adapt(df["oracle_text"])

    text_input = keras.Input(shape=(), dtype=tf.string, name="oracle_text")
    oracle_vector = text_vectorizer(text_input)
    oracle_embed = keras.layers.Embedding(input_dim=tokens, output_dim=dim)(oracle_vector) 
    oracle_pooled = keras.layers.GlobalAveragePooling1D()(oracle_embed)

    all_inputs = [
    number_inputs,
    text_input,
    colors_input,
    keywords_input,
    subtypes_input,
    aac_input
]

    all_features = keras.layers.concatenate([
    normalized,
    oracle_pooled,
    colors_pooled,
    keywords_pooled,
    subtypes_pooled,
    aac_pooled
    ])
    return text_vectorizer, all_features, all_inputs

# %%
ts = [1000, 500]
ngram = [(2,7), (2,8)]
dim = [64, 128]

tests = []
for t in ts:
    for ng in ngram:
        for d in dim:
            tests.append([t, ng, d])
len(tests)
# Out:
# 8

# %%
models = []
for i, build in enumerate(tests):
    tv = buildVectors(build[0], build[1], build[2])
    text_vectorizer = tv[0]
    features = tv[1]
    inputs = tv[2]
    result = buildModel({"nrns": [256, 128], "act": "tanh", "batch": 32, "drop": [True, 0.2], "norm": False,
      "opt": keras.optimizers.Adam(learning_rate=0.001), "eps": 10}, verbose=1, all_features=features, all_inputs=inputs)
    models.append([build, text_vectorizer, result[1]])
    print(i)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 19.4270 - mean_absolute_error: 1.7225 - val_loss: 13.3685 - val_mean_absolute_error: 1.5779
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 18.3709 - mean_absolute_error: 1.6940 - val_loss: 13.3852 - val_mean_absolute_error: 1.5834
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 17.6067 - mean_absolute_error: 1.6749 - val_loss: 13.5112 - val_mean_absolute_error: 1.4997
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 17.3966 - mean_absolute_error: 1.6056 - val_loss: 13.6741 - val_mean_absolute_error: 1.6169
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 17.1610 - mean_absolute_error: 1.5855 - val_loss: 13.5512 - val_mean_absolute_error: 1.4193
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 17.0448 - mean_absolute_error: 1.5503 - val_loss: 14.0138 - val_mean_absolute_error: 1.4798
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 16.7839 - mean_absolute_error: 1.5547 - val_loss: 13.9060 - val_mean_absolute_error: 1.5999
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 16.5613 - mean_absolute_error: 1.5338 - val_loss: 13.6074 - val_mean_absolute_error: 1.5381
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 16.4313 - mean_absolute_error: 1.5271 - val_loss: 14.3041 - val_mean_absolute_error: 1.7566
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 16.1209 - mean_absolute_error: 1.5274 - val_loss: 13.7028 - val_mean_absolute_error: 1.3819
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 10.3447 - mean_absolute_error: 1.2163
# 0
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 19.2820 - mean_absolute_error: 1.7152 - val_loss: 13.4942 - val_mean_absolute_error: 1.4611
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 18.2114 - mean_absolute_error: 1.6931 - val_loss: 13.3536 - val_mean_absolute_error: 1.4865
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 17.4901 - mean_absolute_error: 1.6443 - val_loss: 13.7922 - val_mean_absolute_error: 1.5090
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 17.4602 - mean_absolute_error: 1.6259 - val_loss: 13.7789 - val_mean_absolute_error: 1.5290
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 16.8661 - mean_absolute_error: 1.5853 - val_loss: 13.7284 - val_mean_absolute_error: 1.4224
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 16.7464 - mean_absolute_error: 1.5647 - val_loss: 13.7718 - val_mean_absolute_error: 1.4281
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 16.4518 - mean_absolute_error: 1.5514 - val_loss: 13.5875 - val_mean_absolute_error: 1.4798
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 16.1512 - mean_absolute_error: 1.5136 - val_loss: 13.9350 - val_mean_absolute_error: 1.7791
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 16.2791 - mean_absolute_error: 1.5269 - val_loss: 13.5690 - val_mean_absolute_error: 1.3556
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 15.9658 - mean_absolute_error: 1.5112 - val_loss: 14.2630 - val_mean_absolute_error: 1.5055
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 10.9474 - mean_absolute_error: 1.3312
# 1
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 19.5230 - mean_absolute_error: 1.7214 - val_loss: 13.5422 - val_mean_absolute_error: 1.4925
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 18.3274 - mean_absolute_error: 1.6895 - val_loss: 13.2808 - val_mean_absolute_error: 1.5154
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 17.4297 - mean_absolute_error: 1.6171 - val_loss: 13.5760 - val_mean_absolute_error: 1.4693
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 17.3448 - mean_absolute_error: 1.5897 - val_loss: 13.5924 - val_mean_absolute_error: 1.5340
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 16.8883 - mean_absolute_error: 1.5562 - val_loss: 14.4143 - val_mean_absolute_error: 1.6718
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 16.7020 - mean_absolute_error: 1.5466 - val_loss: 13.9713 - val_mean_absolute_error: 1.4655
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 16.4587 - mean_absolute_error: 1.5446 - val_loss: 13.7234 - val_mean_absolute_error: 1.3352
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 16.3298 - mean_absolute_error: 1.5241 - val_loss: 13.5400 - val_mean_absolute_error: 1.4010
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 16.4845 - mean_absolute_error: 1.5299 - val_loss: 13.6575 - val_mean_absolute_error: 1.3729
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 16.0100 - mean_absolute_error: 1.5052 - val_loss: 14.0795 - val_mean_absolute_error: 1.3390
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 10.7601 - mean_absolute_error: 1.1727
# 2
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 19.4257 - mean_absolute_error: 1.7264 - val_loss: 13.3734 - val_mean_absolute_error: 1.5698
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 18.2539 - mean_absolute_error: 1.7123 - val_loss: 13.6876 - val_mean_absolute_error: 1.6247
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 17.6320 - mean_absolute_error: 1.6689 - val_loss: 13.5605 - val_mean_absolute_error: 1.4409
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 17.3461 - mean_absolute_error: 1.6051 - val_loss: 13.8093 - val_mean_absolute_error: 1.5316
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 16.9780 - mean_absolute_error: 1.5789 - val_loss: 13.6374 - val_mean_absolute_error: 1.5215
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 16.7581 - mean_absolute_error: 1.5595 - val_loss: 13.8962 - val_mean_absolute_error: 1.6876
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 16.4326 - mean_absolute_error: 1.5406 - val_loss: 13.4188 - val_mean_absolute_error: 1.4394
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 16.3980 - mean_absolute_error: 1.5550 - val_loss: 13.6020 - val_mean_absolute_error: 1.2904
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 16.1876 - mean_absolute_error: 1.5112 - val_loss: 13.4150 - val_mean_absolute_error: 1.5171
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 16.2711 - mean_absolute_error: 1.5262 - val_loss: 13.5950 - val_mean_absolute_error: 1.4995
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 10.3850 - mean_absolute_error: 1.3460
# 3
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 19.3813 - mean_absolute_error: 1.7224 - val_loss: 13.5644 - val_mean_absolute_error: 1.5056
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 18.1944 - mean_absolute_error: 1.6938 - val_loss: 13.5967 - val_mean_absolute_error: 1.5078
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 17.7258 - mean_absolute_error: 1.6665 - val_loss: 13.7602 - val_mean_absolute_error: 1.4380
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 17.2798 - mean_absolute_error: 1.6033 - val_loss: 13.7210 - val_mean_absolute_error: 1.4493
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 17.1885 - mean_absolute_error: 1.6003 - val_loss: 13.8613 - val_mean_absolute_error: 1.5114
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 16.6567 - mean_absolute_error: 1.5777 - val_loss: 13.7192 - val_mean_absolute_error: 1.5143
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 16.7278 - mean_absolute_error: 1.5498 - val_loss: 14.0342 - val_mean_absolute_error: 1.7157
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 16.7403 - mean_absolute_error: 1.5442 - val_loss: 13.7536 - val_mean_absolute_error: 1.5109
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 16.5015 - mean_absolute_error: 1.5318 - val_loss: 13.9035 - val_mean_absolute_error: 1.3902
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 16.5483 - mean_absolute_error: 1.5036 - val_loss: 14.8525 - val_mean_absolute_error: 1.8839
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 11.5386 - mean_absolute_error: 1.7364
# 4
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 19.4412 - mean_absolute_error: 1.7149 - val_loss: 13.8335 - val_mean_absolute_error: 1.8078
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 18.1529 - mean_absolute_error: 1.7008 - val_loss: 13.9663 - val_mean_absolute_error: 1.8130
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 17.7229 - mean_absolute_error: 1.6648 - val_loss: 13.4751 - val_mean_absolute_error: 1.4059
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 17.3262 - mean_absolute_error: 1.6127 - val_loss: 13.7842 - val_mean_absolute_error: 1.4425
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 17.0016 - mean_absolute_error: 1.5862 - val_loss: 13.5908 - val_mean_absolute_error: 1.4833
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 16.6743 - mean_absolute_error: 1.5661 - val_loss: 13.7207 - val_mean_absolute_error: 1.3604
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 16.4361 - mean_absolute_error: 1.5209 - val_loss: 13.8996 - val_mean_absolute_error: 1.4444
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 16.6434 - mean_absolute_error: 1.5283 - val_loss: 14.1195 - val_mean_absolute_error: 1.7928
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 16.2083 - mean_absolute_error: 1.5277 - val_loss: 14.4479 - val_mean_absolute_error: 1.5101
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 16.0111 - mean_absolute_error: 1.4871 - val_loss: 14.2167 - val_mean_absolute_error: 1.6870
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 11.0317 - mean_absolute_error: 1.5371
# 5
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 19.3369 - mean_absolute_error: 1.7318 - val_loss: 13.4135 - val_mean_absolute_error: 1.4922
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 18.1859 - mean_absolute_error: 1.6922 - val_loss: 13.7920 - val_mean_absolute_error: 1.6711
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 17.5539 - mean_absolute_error: 1.6458 - val_loss: 13.5424 - val_mean_absolute_error: 1.6271
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 17.3863 - mean_absolute_error: 1.6072 - val_loss: 13.8161 - val_mean_absolute_error: 1.4971
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 17.1393 - mean_absolute_error: 1.5889 - val_loss: 13.6970 - val_mean_absolute_error: 1.3973
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 16.5251 - mean_absolute_error: 1.5423 - val_loss: 14.0104 - val_mean_absolute_error: 1.5058
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 16.7691 - mean_absolute_error: 1.5393 - val_loss: 14.8520 - val_mean_absolute_error: 1.7108
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 16.6728 - mean_absolute_error: 1.5397 - val_loss: 13.7973 - val_mean_absolute_error: 1.3799
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 16.4070 - mean_absolute_error: 1.5071 - val_loss: 13.8654 - val_mean_absolute_error: 1.5309
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 16.6567 - mean_absolute_error: 1.5118 - val_loss: 13.6466 - val_mean_absolute_error: 1.5405
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 10.3546 - mean_absolute_error: 1.3857
# 6
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 19.4063 - mean_absolute_error: 1.7215 - val_loss: 13.8728 - val_mean_absolute_error: 1.5947
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 18.1189 - mean_absolute_error: 1.6981 - val_loss: 13.4088 - val_mean_absolute_error: 1.5013
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 17.6236 - mean_absolute_error: 1.6453 - val_loss: 13.7597 - val_mean_absolute_error: 1.4593
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 17.3048 - mean_absolute_error: 1.6142 - val_loss: 14.3178 - val_mean_absolute_error: 1.8167
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 16.9798 - mean_absolute_error: 1.5844 - val_loss: 13.6955 - val_mean_absolute_error: 1.3754
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 16.7483 - mean_absolute_error: 1.5567 - val_loss: 13.8553 - val_mean_absolute_error: 1.3677
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 16.5333 - mean_absolute_error: 1.5529 - val_loss: 13.8899 - val_mean_absolute_error: 1.4474
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 16.5182 - mean_absolute_error: 1.5234 - val_loss: 14.0018 - val_mean_absolute_error: 1.4689
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 16.3625 - mean_absolute_error: 1.5257 - val_loss: 13.6948 - val_mean_absolute_error: 1.3990
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 16.0811 - mean_absolute_error: 1.5033 - val_loss: 13.8171 - val_mean_absolute_error: 1.5094
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 10.4885 - mean_absolute_error: 1.3493
# 7

# %%
models.sort(key=lambda x: x[2][1])
models[0]
#models[0][1].save_assets("models\\text_vectorizer_tested")
# Out:
# [[1000, (2, 8), 64],
#  <TextVectorization name=text_vectorization_113, built=True>,
#  [10.76006031036377, 1.1727124452590942]]

# %% [markdown]
# Best: [[3000, (2, 7), 128],
#  <TextVectorization name=text_vectorization_90, built=True>,
#  [10.209338188171387, 1.020315408706665]]

# %% [markdown]
# ### Final Tests:

# %%
tv = buildVectors(3000, (2,7), 128)
text_vectorizer = tv[0]
features = tv[1]
inputs = tv[2]

# %%
final_options = [{"nrns": [256, 128], "act": "tanh", "batch": 32, "drop": [True, 0.2], "norm": False,
      "opt": keras.optimizers.Adam(learning_rate=0.001), "eps": 15},
      {"nrns": [512, 256], "act": "tanh", "batch": 32, "drop": [True, 0.2], "norm": False,
      "opt": keras.optimizers.Adam(learning_rate=0.001), "eps": 15},
      {"nrns": [256, 128], "act": "tanh", "batch": 32, "drop": [False], "norm": True,
      "opt": keras.optimizers.Adam(learning_rate=0.001), "eps": 15},
      {"nrns": [512, 256], "act": "tanh", "batch": 32, "drop": [False], "norm": True,
      "opt": keras.optimizers.Adam(learning_rate=0.001), "eps": 15},
      {"nrns": [256, 128], "act": "tanh", "batch": 32, "drop": [True, 0.2], "norm": True,
      "opt": keras.optimizers.Adam(learning_rate=0.001), "eps": 15},
      {"nrns": [512, 256, 128], "act": "tanh", "batch": 32, "drop": [True, 0.2], "norm": False,
      "opt": keras.optimizers.Adam(learning_rate=0.001), "eps": 15}
      ]
models = []
for opt in final_options:
    model = buildModel(opt, verbose=0, all_features=features, all_inputs=inputs)
    models.append(model)
# Out:
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 10.7473 - mean_absolute_error: 1.3294
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 12.8841 - mean_absolute_error: 1.7112
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 12.6426 - mean_absolute_error: 1.0533
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 13.9944 - mean_absolute_error: 1.2350
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 14.1156 - mean_absolute_error: 1.2351
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 10.9325 - mean_absolute_error: 1.0893

# %%
final_model = buildModel({"nrns": [512, 256, 128], "act": "tanh", "batch": 32, "drop": [True, 0.2], "norm": False,
      "opt": keras.optimizers.Adam(learning_rate=0.001), "eps": 200}, verbose=1, all_features=features, all_inputs=inputs, early_stop=True)
# Out:
# Epoch 1/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 85.2111 - mean_absolute_error: 3.6141 - val_loss: 59.6167 - val_mean_absolute_error: 3.6689
# Epoch 2/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 83.5866 - mean_absolute_error: 3.6286 - val_loss: 57.1025 - val_mean_absolute_error: 2.8989
# Epoch 3/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 81.8530 - mean_absolute_error: 3.4457 - val_loss: 58.6450 - val_mean_absolute_error: 2.9697
# Epoch 4/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 80.3817 - mean_absolute_error: 3.2109 - val_loss: 56.2052 - val_mean_absolute_error: 2.6881
# Epoch 5/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 77.6023 - mean_absolute_error: 3.1100 - val_loss: 55.9655 - val_mean_absolute_error: 3.2873
# Epoch 6/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 74.4947 - mean_absolute_error: 3.0696 - val_loss: 51.4767 - val_mean_absolute_error: 2.4695
# Epoch 7/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 74.2825 - mean_absolute_error: 3.0146 - val_loss: 56.5808 - val_mean_absolute_error: 2.2643
# Epoch 8/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 74.0465 - mean_absolute_error: 3.0688 - val_loss: 57.7725 - val_mean_absolute_error: 3.2406
# Epoch 9/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 70.0452 - mean_absolute_error: 2.9048 - val_loss: 53.7328 - val_mean_absolute_error: 2.3434
# Epoch 10/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 71.7766 - mean_absolute_error: 3.0499 - val_loss: 54.4221 - val_mean_absolute_error: 2.5684
# Epoch 11/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 68.7429 - mean_absolute_error: 2.8995 - val_loss: 51.1810 - val_mean_absolute_error: 2.5635
# Epoch 12/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 68.5259 - mean_absolute_error: 2.9175 - val_loss: 53.0174 - val_mean_absolute_error: 2.1336
# Epoch 13/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 68.4045 - mean_absolute_error: 2.9605 - val_loss: 50.5772 - val_mean_absolute_error: 2.4661
# Epoch 14/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 66.0539 - mean_absolute_error: 2.8619 - val_loss: 50.7847 - val_mean_absolute_error: 2.3035
# Epoch 15/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 66.8498 - mean_absolute_error: 2.8595 - val_loss: 51.4603 - val_mean_absolute_error: 2.5892
# Epoch 16/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 64.8370 - mean_absolute_error: 2.8469 - val_loss: 50.7883 - val_mean_absolute_error: 2.5297
# Epoch 17/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 68.4897 - mean_absolute_error: 2.9619 - val_loss: 51.3622 - val_mean_absolute_error: 2.3260
# Epoch 18/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 60.4813 - mean_absolute_error: 2.7617 - val_loss: 51.3797 - val_mean_absolute_error: 2.5892
# Epoch 19/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 60.5574 - mean_absolute_error: 2.7562 - val_loss: 53.2823 - val_mean_absolute_error: 2.0815
# Epoch 20/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 61.1275 - mean_absolute_error: 2.8054 - val_loss: 55.2334 - val_mean_absolute_error: 2.7267
# Epoch 21/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 61.2422 - mean_absolute_error: 2.7790 - val_loss: 57.5221 - val_mean_absolute_error: 2.2535
# Epoch 22/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 59.7077 - mean_absolute_error: 2.7349 - val_loss: 50.8163 - val_mean_absolute_error: 2.8006
# Epoch 23/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 58.4733 - mean_absolute_error: 2.7364 - val_loss: 53.7077 - val_mean_absolute_error: 2.1441
# Epoch 24/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 60.3914 - mean_absolute_error: 2.8139 - val_loss: 52.7079 - val_mean_absolute_error: 2.3379
# Epoch 25/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 58.8964 - mean_absolute_error: 2.8018 - val_loss: 55.3160 - val_mean_absolute_error: 2.2372
# Epoch 26/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 57.3039 - mean_absolute_error: 2.7567 - val_loss: 52.1303 - val_mean_absolute_error: 2.3852
# Epoch 27/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 61.4382 - mean_absolute_error: 2.7735 - val_loss: 52.1752 - val_mean_absolute_error: 2.3843
# Epoch 28/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 62.6261 - mean_absolute_error: 2.8991 - val_loss: 54.5534 - val_mean_absolute_error: 2.3297
# Epoch 29/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 55.6678 - mean_absolute_error: 2.7438 - val_loss: 51.8943 - val_mean_absolute_error: 2.3528
# Epoch 30/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 58.3813 - mean_absolute_error: 2.8304 - val_loss: 62.1848 - val_mean_absolute_error: 2.4093
# Epoch 31/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 57.9205 - mean_absolute_error: 2.8114 - val_loss: 51.2332 - val_mean_absolute_error: 2.5789
# Epoch 32/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 55.3864 - mean_absolute_error: 2.7409 - val_loss: 53.4789 - val_mean_absolute_error: 2.2588
# Epoch 33/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 54.0307 - mean_absolute_error: 2.6640 - val_loss: 52.6155 - val_mean_absolute_error: 2.2604
# Epoch 34/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 50.7220 - mean_absolute_error: 2.6035 - val_loss: 56.4528 - val_mean_absolute_error: 2.8044
# Epoch 35/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 54.6792 - mean_absolute_error: 2.7009 - val_loss: 51.8642 - val_mean_absolute_error: 2.4151
# Epoch 36/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 50.9322 - mean_absolute_error: 2.6495 - val_loss: 54.0845 - val_mean_absolute_error: 2.8115
# Epoch 37/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 52.1267 - mean_absolute_error: 2.6669 - val_loss: 63.7242 - val_mean_absolute_error: 2.3363
# Epoch 38/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 54.6577 - mean_absolute_error: 2.6952 - val_loss: 57.2206 - val_mean_absolute_error: 2.2670
# Epoch 39/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 52.8673 - mean_absolute_error: 2.7000 - val_loss: 59.2337 - val_mean_absolute_error: 2.8962
# Epoch 40/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 50.9249 - mean_absolute_error: 2.6366 - val_loss: 54.3167 - val_mean_absolute_error: 3.0821
# Epoch 41/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 51.4944 - mean_absolute_error: 2.6161 - val_loss: 50.0244 - val_mean_absolute_error: 2.3269
# Epoch 42/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 51.1700 - mean_absolute_error: 2.6253 - val_loss: 53.8970 - val_mean_absolute_error: 2.3857
# Epoch 43/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 47.9562 - mean_absolute_error: 2.6091 - val_loss: 53.7992 - val_mean_absolute_error: 2.4818
# Epoch 44/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 48.5672 - mean_absolute_error: 2.5643 - val_loss: 56.4386 - val_mean_absolute_error: 2.8924
# Epoch 45/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 47.9889 - mean_absolute_error: 2.5724 - val_loss: 53.2030 - val_mean_absolute_error: 2.8429
# Epoch 46/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 47.4103 - mean_absolute_error: 2.6406 - val_loss: 53.9012 - val_mean_absolute_error: 2.4280
# Epoch 47/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 47.5699 - mean_absolute_error: 2.5621 - val_loss: 51.7600 - val_mean_absolute_error: 2.5181
# Epoch 48/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 47.0944 - mean_absolute_error: 2.5813 - val_loss: 50.6590 - val_mean_absolute_error: 2.8795
# Epoch 49/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 48.2137 - mean_absolute_error: 2.5773 - val_loss: 52.7351 - val_mean_absolute_error: 2.5002
# Epoch 50/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 47.6059 - mean_absolute_error: 2.5631 - val_loss: 54.2318 - val_mean_absolute_error: 2.5595
# Epoch 51/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 53.2394 - mean_absolute_error: 2.7792 - val_loss: 54.5192 - val_mean_absolute_error: 2.1864
# Epoch 52/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 50.9132 - mean_absolute_error: 2.6602 - val_loss: 56.0504 - val_mean_absolute_error: 2.6374
# Epoch 53/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 46.7640 - mean_absolute_error: 2.5541 - val_loss: 53.8531 - val_mean_absolute_error: 2.3554
# Epoch 54/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 42.7659 - mean_absolute_error: 2.4337 - val_loss: 53.8484 - val_mean_absolute_error: 2.4297
# Epoch 55/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 44.8157 - mean_absolute_error: 2.4688 - val_loss: 51.7077 - val_mean_absolute_error: 2.5495
# Epoch 56/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 46.7602 - mean_absolute_error: 2.5122 - val_loss: 56.8599 - val_mean_absolute_error: 2.9621
# Epoch 57/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 43.2837 - mean_absolute_error: 2.4575 - val_loss: 56.8590 - val_mean_absolute_error: 3.5570
# Epoch 58/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 49.1565 - mean_absolute_error: 2.5815 - val_loss: 56.5167 - val_mean_absolute_error: 3.0016
# Epoch 59/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 45.9985 - mean_absolute_error: 2.5420 - val_loss: 56.3584 - val_mean_absolute_error: 2.6419
# Epoch 60/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 44.3932 - mean_absolute_error: 2.5410 - val_loss: 61.0891 - val_mean_absolute_error: 2.7841
# Epoch 61/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 39.9271 - mean_absolute_error: 2.4633 - val_loss: 70.9500 - val_mean_absolute_error: 3.1638
# Epoch 62/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 55.8450 - mean_absolute_error: 2.8376 - val_loss: 56.9084 - val_mean_absolute_error: 2.3872
# Epoch 63/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 48.8895 - mean_absolute_error: 2.6297 - val_loss: 59.0402 - val_mean_absolute_error: 2.4010
# Epoch 64/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 39.8362 - mean_absolute_error: 2.4131 - val_loss: 52.9296 - val_mean_absolute_error: 2.6390
# Epoch 65/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 42.6095 - mean_absolute_error: 2.5235 - val_loss: 58.3795 - val_mean_absolute_error: 2.9395
# Epoch 66/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 56.8007 - mean_absolute_error: 2.7949 - val_loss: 52.6741 - val_mean_absolute_error: 2.6091
# Epoch 67/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 43.3119 - mean_absolute_error: 2.4713 - val_loss: 59.9673 - val_mean_absolute_error: 2.2919
# Epoch 68/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 45.2103 - mean_absolute_error: 2.5011 - val_loss: 56.4132 - val_mean_absolute_error: 2.2067
# Epoch 69/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 40.6862 - mean_absolute_error: 2.4252 - val_loss: 54.0258 - val_mean_absolute_error: 2.5265
# Epoch 70/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 38.0873 - mean_absolute_error: 2.3960 - val_loss: 51.3730 - val_mean_absolute_error: 2.3639
# Epoch 71/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 41.5305 - mean_absolute_error: 2.4159 - val_loss: 57.5529 - val_mean_absolute_error: 3.3206
# Epoch 72/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 41.1227 - mean_absolute_error: 2.4838 - val_loss: 53.8384 - val_mean_absolute_error: 2.3222
# Epoch 73/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 47.0618 - mean_absolute_error: 2.4996 - val_loss: 58.7641 - val_mean_absolute_error: 2.5259
# Epoch 74/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 42.1407 - mean_absolute_error: 2.4793 - val_loss: 58.1819 - val_mean_absolute_error: 2.3819
# Epoch 75/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 42.9287 - mean_absolute_error: 2.4773 - val_loss: 56.8953 - val_mean_absolute_error: 2.7012
# Epoch 76/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 38.7543 - mean_absolute_error: 2.3860 - val_loss: 57.4331 - val_mean_absolute_error: 2.2876
# Epoch 77/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 35.4112 - mean_absolute_error: 2.2975 - val_loss: 56.0407 - val_mean_absolute_error: 2.4402
# Epoch 78/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 39.4250 - mean_absolute_error: 2.3537 - val_loss: 55.8989 - val_mean_absolute_error: 2.3252
# Epoch 79/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 49.5204 - mean_absolute_error: 2.6551 - val_loss: 62.6380 - val_mean_absolute_error: 4.0967
# Epoch 80/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 49.7366 - mean_absolute_error: 2.6759 - val_loss: 74.9667 - val_mean_absolute_error: 3.2288
# Epoch 81/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 42.3004 - mean_absolute_error: 2.4851 - val_loss: 62.9812 - val_mean_absolute_error: 3.1831
# Epoch 82/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 35.0792 - mean_absolute_error: 2.3057 - val_loss: 59.6787 - val_mean_absolute_error: 2.0896
# Epoch 83/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 35.6187 - mean_absolute_error: 2.2861 - val_loss: 58.3115 - val_mean_absolute_error: 2.1607
# Epoch 84/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 46.8894 - mean_absolute_error: 2.5029 - val_loss: 62.9045 - val_mean_absolute_error: 2.7316
# Epoch 85/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 37.1379 - mean_absolute_error: 2.3459 - val_loss: 56.8637 - val_mean_absolute_error: 2.3607
# Epoch 86/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 35.3721 - mean_absolute_error: 2.2837 - val_loss: 70.7147 - val_mean_absolute_error: 2.7307
# Epoch 87/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 36.4101 - mean_absolute_error: 2.2845 - val_loss: 63.9434 - val_mean_absolute_error: 2.6110
# Epoch 88/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 37.7848 - mean_absolute_error: 2.3616 - val_loss: 56.8965 - val_mean_absolute_error: 2.3353
# Epoch 89/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 37.0925 - mean_absolute_error: 2.3029 - val_loss: 58.0510 - val_mean_absolute_error: 2.7747
# Epoch 90/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 51.3118 - mean_absolute_error: 2.5994 - val_loss: 57.6094 - val_mean_absolute_error: 2.4823
# Epoch 91/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 34.6892 - mean_absolute_error: 2.2905 - val_loss: 56.8989 - val_mean_absolute_error: 2.2163
# Epoch 92/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 41.4492 - mean_absolute_error: 2.4207 - val_loss: 65.8959 - val_mean_absolute_error: 2.5362
# Epoch 93/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 34.9230 - mean_absolute_error: 2.2759 - val_loss: 69.4840 - val_mean_absolute_error: 2.7949
# Epoch 94/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 35.1115 - mean_absolute_error: 2.2702 - val_loss: 60.6845 - val_mean_absolute_error: 2.4370
# Epoch 95/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 39.3055 - mean_absolute_error: 2.3813 - val_loss: 57.4072 - val_mean_absolute_error: 2.3685
# Epoch 96/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 34.9245 - mean_absolute_error: 2.3065 - val_loss: 55.1241 - val_mean_absolute_error: 2.6014
# Epoch 97/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 37.6551 - mean_absolute_error: 2.3363 - val_loss: 55.3129 - val_mean_absolute_error: 2.3564
# Epoch 98/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 32.4544 - mean_absolute_error: 2.2278 - val_loss: 59.1724 - val_mean_absolute_error: 2.7256
# Epoch 99/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 37.9495 - mean_absolute_error: 2.3666 - val_loss: 60.1196 - val_mean_absolute_error: 2.2661
# Epoch 100/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 30.8313 - mean_absolute_error: 2.1913 - val_loss: 59.9564 - val_mean_absolute_error: 2.3626
# Epoch 101/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 34.5923 - mean_absolute_error: 2.2607 - val_loss: 58.9687 - val_mean_absolute_error: 2.5814
# Epoch 102/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 30.8876 - mean_absolute_error: 2.1933 - val_loss: 83.2480 - val_mean_absolute_error: 3.6431
# Epoch 103/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 36.5428 - mean_absolute_error: 2.3341 - val_loss: 58.3898 - val_mean_absolute_error: 2.4270
# Epoch 104/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 34.0540 - mean_absolute_error: 2.2885 - val_loss: 56.9754 - val_mean_absolute_error: 2.4996
# Epoch 105/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 36.4006 - mean_absolute_error: 2.3509 - val_loss: 60.0065 - val_mean_absolute_error: 2.6978
# Epoch 106/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 30.9564 - mean_absolute_error: 2.2049 - val_loss: 55.1324 - val_mean_absolute_error: 2.2825
# Epoch 107/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 39.1169 - mean_absolute_error: 2.3697 - val_loss: 63.9543 - val_mean_absolute_error: 2.6547
# Epoch 108/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 28.9672 - mean_absolute_error: 2.1418 - val_loss: 59.0512 - val_mean_absolute_error: 2.3688
# Epoch 109/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 34.4802 - mean_absolute_error: 2.3072 - val_loss: 64.6974 - val_mean_absolute_error: 3.2182
# Epoch 110/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 30.3960 - mean_absolute_error: 2.1564 - val_loss: 73.0393 - val_mean_absolute_error: 2.7386
# Epoch 111/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 28.5167 - mean_absolute_error: 2.1102 - val_loss: 56.7683 - val_mean_absolute_error: 2.5664
# Epoch 112/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 33.9270 - mean_absolute_error: 2.2011 - val_loss: 55.4317 - val_mean_absolute_error: 2.3730
# Epoch 113/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 26.8877 - mean_absolute_error: 2.0757 - val_loss: 58.3180 - val_mean_absolute_error: 2.3053
# Epoch 114/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 31.5696 - mean_absolute_error: 2.2315 - val_loss: 55.7275 - val_mean_absolute_error: 2.4404
# Epoch 115/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 33.8461 - mean_absolute_error: 2.2356 - val_loss: 72.2760 - val_mean_absolute_error: 2.9475
# Epoch 116/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 31.0645 - mean_absolute_error: 2.1603 - val_loss: 72.2535 - val_mean_absolute_error: 2.4645
# Epoch 117/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 34.2126 - mean_absolute_error: 2.2107 - val_loss: 60.0196 - val_mean_absolute_error: 2.7353
# Epoch 118/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 29.3922 - mean_absolute_error: 2.1394 - val_loss: 57.5762 - val_mean_absolute_error: 2.2615
# Epoch 119/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 30.9479 - mean_absolute_error: 2.1737 - val_loss: 56.3797 - val_mean_absolute_error: 2.9920
# Epoch 120/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 26.6431 - mean_absolute_error: 2.0903 - val_loss: 54.6208 - val_mean_absolute_error: 2.6138
# Epoch 121/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 52.6544 - mean_absolute_error: 2.5830 - val_loss: 58.7295 - val_mean_absolute_error: 2.6242
# Epoch 122/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 30.7444 - mean_absolute_error: 2.1895 - val_loss: 60.1467 - val_mean_absolute_error: 2.3470
# Epoch 123/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 34.5012 - mean_absolute_error: 2.1908 - val_loss: 65.6362 - val_mean_absolute_error: 3.4425
# Epoch 124/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 30.0451 - mean_absolute_error: 2.1575 - val_loss: 56.6873 - val_mean_absolute_error: 2.4807
# Epoch 125/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 36.1437 - mean_absolute_error: 2.2306 - val_loss: 55.6475 - val_mean_absolute_error: 2.2207
# Epoch 126/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 27.3078 - mean_absolute_error: 2.0633 - val_loss: 54.9591 - val_mean_absolute_error: 2.8375
# Epoch 127/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 31.3693 - mean_absolute_error: 2.1852 - val_loss: 57.6002 - val_mean_absolute_error: 2.4351
# Epoch 128/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 25.9374 - mean_absolute_error: 2.0546 - val_loss: 62.0868 - val_mean_absolute_error: 2.5626
# Epoch 129/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 35.2274 - mean_absolute_error: 2.2623 - val_loss: 56.6851 - val_mean_absolute_error: 2.4193
# Epoch 130/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 29.2074 - mean_absolute_error: 2.1263 - val_loss: 66.4620 - val_mean_absolute_error: 2.6221
# Epoch 131/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 34.3731 - mean_absolute_error: 2.2738 - val_loss: 58.2433 - val_mean_absolute_error: 2.9948
# Epoch 132/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 27.7603 - mean_absolute_error: 2.1197 - val_loss: 58.1649 - val_mean_absolute_error: 2.3906
# Epoch 133/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 36.1629 - mean_absolute_error: 2.2531 - val_loss: 54.5730 - val_mean_absolute_error: 2.5652
# Epoch 134/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 31.3694 - mean_absolute_error: 2.2032 - val_loss: 63.2725 - val_mean_absolute_error: 2.5159
# Epoch 135/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 34.7094 - mean_absolute_error: 2.3101 - val_loss: 61.0030 - val_mean_absolute_error: 2.3271
# Epoch 136/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 29.4661 - mean_absolute_error: 2.1471 - val_loss: 55.7730 - val_mean_absolute_error: 2.8267
# Epoch 137/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 27.1188 - mean_absolute_error: 2.0689 - val_loss: 55.9538 - val_mean_absolute_error: 2.3525
# Epoch 138/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 31.3779 - mean_absolute_error: 2.1849 - val_loss: 73.1218 - val_mean_absolute_error: 3.0811
# Epoch 139/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 30.0414 - mean_absolute_error: 2.1789 - val_loss: 59.6724 - val_mean_absolute_error: 2.5287
# Epoch 140/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 26.4045 - mean_absolute_error: 2.0580 - val_loss: 53.7253 - val_mean_absolute_error: 2.3793
# Epoch 141/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 24.6380 - mean_absolute_error: 2.0101 - val_loss: 55.5678 - val_mean_absolute_error: 2.3367
# Epoch 142/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 31.8682 - mean_absolute_error: 2.1737 - val_loss: 63.9378 - val_mean_absolute_error: 2.5320
# Epoch 143/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 28.5904 - mean_absolute_error: 2.0907 - val_loss: 58.3574 - val_mean_absolute_error: 2.2403
# Epoch 144/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 24.2177 - mean_absolute_error: 2.0273 - val_loss: 57.1262 - val_mean_absolute_error: 2.5486
# Epoch 145/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 35.3239 - mean_absolute_error: 2.3068 - val_loss: 56.4458 - val_mean_absolute_error: 2.3815
# Epoch 146/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 27.4649 - mean_absolute_error: 2.0727 - val_loss: 54.4586 - val_mean_absolute_error: 2.6329
# Epoch 147/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 32.0773 - mean_absolute_error: 2.1730 - val_loss: 56.1284 - val_mean_absolute_error: 2.3936
# Epoch 148/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 23.7703 - mean_absolute_error: 1.9594 - val_loss: 54.8778 - val_mean_absolute_error: 2.6437
# Epoch 149/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 28.0876 - mean_absolute_error: 2.0908 - val_loss: 58.5682 - val_mean_absolute_error: 2.5048
# Epoch 150/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 23.4579 - mean_absolute_error: 1.9917 - val_loss: 61.9917 - val_mean_absolute_error: 2.4802
# Epoch 151/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 22.0877 - mean_absolute_error: 1.9407 - val_loss: 55.3640 - val_mean_absolute_error: 2.3618
# Epoch 152/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 24.0049 - mean_absolute_error: 1.9950 - val_loss: 54.7611 - val_mean_absolute_error: 2.0915
# Epoch 153/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 24.7134 - mean_absolute_error: 2.0500 - val_loss: 55.8003 - val_mean_absolute_error: 2.2215
# Epoch 154/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 23.5425 - mean_absolute_error: 1.9529 - val_loss: 57.5113 - val_mean_absolute_error: 2.3504
# Epoch 155/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 34.1529 - mean_absolute_error: 2.3291 - val_loss: 60.3963 - val_mean_absolute_error: 2.8685
# Epoch 156/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 23.4263 - mean_absolute_error: 2.0480 - val_loss: 53.3350 - val_mean_absolute_error: 2.4328
# Epoch 157/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 30.4066 - mean_absolute_error: 2.1905 - val_loss: 53.2860 - val_mean_absolute_error: 2.7930
# Epoch 158/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 27.3120 - mean_absolute_error: 2.1146 - val_loss: 56.5093 - val_mean_absolute_error: 2.3503
# Epoch 159/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 26.4274 - mean_absolute_error: 2.0235 - val_loss: 61.1853 - val_mean_absolute_error: 2.4165
# Epoch 160/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 26.0503 - mean_absolute_error: 1.9995 - val_loss: 58.9157 - val_mean_absolute_error: 2.5237
# Epoch 161/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 24.3643 - mean_absolute_error: 2.0320 - val_loss: 56.5884 - val_mean_absolute_error: 2.6057
# Epoch 162/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 21.2199 - mean_absolute_error: 1.9387 - val_loss: 56.6481 - val_mean_absolute_error: 2.1821
# Epoch 163/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 28.3759 - mean_absolute_error: 2.1251 - val_loss: 69.8127 - val_mean_absolute_error: 3.0550
# Epoch 164/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 27.0746 - mean_absolute_error: 2.0733 - val_loss: 58.4786 - val_mean_absolute_error: 2.4720
# Epoch 165/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 34.9619 - mean_absolute_error: 2.2201 - val_loss: 62.1462 - val_mean_absolute_error: 2.7259
# Epoch 166/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 24.5924 - mean_absolute_error: 1.9766 - val_loss: 60.1294 - val_mean_absolute_error: 2.3058
# Epoch 167/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 29.0533 - mean_absolute_error: 2.1320 - val_loss: 58.6217 - val_mean_absolute_error: 3.0789
# Epoch 168/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 24.6241 - mean_absolute_error: 1.9764 - val_loss: 57.1132 - val_mean_absolute_error: 2.8950
# Epoch 169/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 26.8780 - mean_absolute_error: 2.0100 - val_loss: 60.6293 - val_mean_absolute_error: 2.2557
# Epoch 170/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 21.9526 - mean_absolute_error: 1.9552 - val_loss: 56.8308 - val_mean_absolute_error: 2.6509
# Epoch 171/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 24.4428 - mean_absolute_error: 2.0283 - val_loss: 66.3010 - val_mean_absolute_error: 2.5251
# Epoch 172/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 23.2066 - mean_absolute_error: 1.9674 - val_loss: 55.9682 - val_mean_absolute_error: 2.1694
# Epoch 173/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 20.7148 - mean_absolute_error: 1.9361 - val_loss: 55.8758 - val_mean_absolute_error: 2.2506
# Epoch 174/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 24.3777 - mean_absolute_error: 2.0003 - val_loss: 52.7057 - val_mean_absolute_error: 2.4838
# Epoch 175/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 23.1781 - mean_absolute_error: 1.9419 - val_loss: 53.6990 - val_mean_absolute_error: 2.2355
# Epoch 176/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 23.3165 - mean_absolute_error: 2.0190 - val_loss: 96.8734 - val_mean_absolute_error: 4.2917
# Epoch 177/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 25.2010 - mean_absolute_error: 2.0445 - val_loss: 58.7084 - val_mean_absolute_error: 2.3172
# Epoch 178/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 38.7640 - mean_absolute_error: 2.1484 - val_loss: 71.8213 - val_mean_absolute_error: 2.6661
# Epoch 179/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 28.6185 - mean_absolute_error: 2.0943 - val_loss: 53.6284 - val_mean_absolute_error: 2.4857
# Epoch 180/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 27.9869 - mean_absolute_error: 2.1163 - val_loss: 54.9077 - val_mean_absolute_error: 2.1734
# Epoch 181/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 22.1914 - mean_absolute_error: 1.9206 - val_loss: 53.8701 - val_mean_absolute_error: 2.8180
# Epoch 182/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 20.5206 - mean_absolute_error: 1.9157 - val_loss: 58.2272 - val_mean_absolute_error: 2.3396
# Epoch 183/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 21.0832 - mean_absolute_error: 1.9146 - val_loss: 56.4021 - val_mean_absolute_error: 2.5571
# Epoch 184/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 22.8868 - mean_absolute_error: 1.9311 - val_loss: 62.3838 - val_mean_absolute_error: 2.5816
# Epoch 185/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 22.1984 - mean_absolute_error: 1.9252 - val_loss: 63.5419 - val_mean_absolute_error: 2.8188
# Epoch 186/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 27.9927 - mean_absolute_error: 2.0607 - val_loss: 56.7073 - val_mean_absolute_error: 2.2948
# Epoch 187/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 20.7203 - mean_absolute_error: 1.8703 - val_loss: 53.1531 - val_mean_absolute_error: 2.3762
# Epoch 188/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 26.1751 - mean_absolute_error: 2.0390 - val_loss: 76.2773 - val_mean_absolute_error: 3.2974
# Epoch 189/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 22.8483 - mean_absolute_error: 1.9827 - val_loss: 58.7110 - val_mean_absolute_error: 2.5173
# Epoch 190/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 29.4756 - mean_absolute_error: 2.1106 - val_loss: 60.8117 - val_mean_absolute_error: 2.4592
# Epoch 191/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 20.5870 - mean_absolute_error: 1.8866 - val_loss: 54.3123 - val_mean_absolute_error: 2.6169
# Epoch 192/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 21.0826 - mean_absolute_error: 1.9006 - val_loss: 56.9148 - val_mean_absolute_error: 2.5461
# Epoch 193/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 27.2652 - mean_absolute_error: 1.9850 - val_loss: 62.8601 - val_mean_absolute_error: 3.2904
# Epoch 194/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 19.0455 - mean_absolute_error: 1.8359 - val_loss: 54.9589 - val_mean_absolute_error: 2.5829
# Epoch 195/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 20.2440 - mean_absolute_error: 1.8707 - val_loss: 57.9601 - val_mean_absolute_error: 2.5540
# Epoch 196/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 18.5061 - mean_absolute_error: 1.7840 - val_loss: 61.6319 - val_mean_absolute_error: 2.2965
# Epoch 197/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 25.7477 - mean_absolute_error: 2.0897 - val_loss: 57.1038 - val_mean_absolute_error: 2.5437
# Epoch 198/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 24.5360 - mean_absolute_error: 1.9848 - val_loss: 60.1953 - val_mean_absolute_error: 2.5009
# Epoch 199/200
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 22.3803 - mean_absolute_error: 1.9515 - val_loss: 60.4800 - val_mean_absolute_error: 3.2396
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 44.7005 - mean_absolute_error: 2.9105

# %%
final = keras.models.load_model("models\\final_model.keras", custom_objects={
        "TextVectorization": TextVectorization,
    })

# %%
preds=final.predict(x_test)
# Out:
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
x_test["oracle_text"][1108]
# Out:
# 'flying. if damage would be dealt to this creature prevent that damage. when damage is prevented this way this creature deals that much damage to any other target.'

# %%
unscaled = price_scaler.inverse_transform(preds)
unscaled[1108]
# Out:
# array([1.4336947], dtype=float32)

# %%
import joblib

# %%
joblib.dump(price_scaler, 'models\\price_scaler.gz')
joblib.dump(le2, "models\\SubtypeEncoder.gz")
joblib.dump(mlb,'models\\MultiLabelB.gz')
joblib.dump(keywrd_encoder, 'models\\keywordEncoder.gz')
joblib.dump(c_i, 'models\\c_i_encoder.gz')
# Out:
# ['models\\c_i_encoder.gz']

# %%
price_scaler.inverse_transform(y_test[1108].reshape(1,-1))
# Out:
# array([[2.21]])
