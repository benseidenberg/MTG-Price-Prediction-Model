# %% [markdown]
# # MTG Price Predictor
#
# ## About/Goals:
#
# The idea of this project is to create an ML model that can take a card's data and return the value of the card should be, based on previous cards it has analysed. This requires NLP processing for the text box, and utilizes tensorflow to build the model.
#
# Cards are evaluated purely based on what a person looking at it for the first time can see - year, text, color, etc.. nothing about format legalities, special flags, or anythingn else of the sort. Also, price is based on standard, nonfoil variant only.

# %% [markdown]
# # Data Importation and Cleaning

# %% [markdown]
# #### All imports cell

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer
import tensorflow as tf
from tensorflow.keras.layers import TextVectorization
from sklearn.preprocessing import StandardScaler
import re
import os

# %%
def save(file):
    file.to_pickle('data/updated_data.pkl')

def load():
    df = pd.read_pickle('data/updated_data.pkl')
    return df # band-aid work-around

# %%
df = pd.read_json("data/default_cards_08_05_2025.json")

# %%
df.columns
# Out:
# Index(['object', 'id', 'oracle_id', 'multiverse_ids', 'mtgo_id', 'arena_id',
#        'tcgplayer_id', 'cardmarket_id', 'name', 'lang', 'released_at', 'uri',
#        'scryfall_uri', 'layout', 'highres_image', 'image_status', 'image_uris',
#        'mana_cost', 'cmc', 'type_line', 'oracle_text', 'colors',
#        'color_identity', 'keywords', 'produced_mana', 'legalities', 'games',
#        'reserved', 'game_changer', 'foil', 'nonfoil', 'finishes', 'oversized',
#        'promo', 'reprint', 'variation', 'set_id', 'set', 'set_name',
#        'set_type', 'set_uri', 'set_search_uri', 'scryfall_set_uri',
#        'rulings_uri', 'prints_search_uri', 'collector_number', 'digital',
#        'rarity', 'card_back_id', 'artist', 'artist_ids', 'illustration_id',
#        'border_color', 'frame', 'full_art', 'textless', 'booster',
#        'story_spotlight', 'prices', 'related_uris', 'purchase_uris',
#        'mtgo_foil_id', 'power', 'toughness', 'flavor_text', 'edhrec_rank',
#        'penny_rank', 'all_parts', 'promo_types', 'security_stamp',
#        'card_faces', 'preview', 'watermark', 'frame_effects', 'loyalty',
#        'printed_name', 'tcgplayer_etched_id', 'flavor_name',
#        'attraction_lights', 'color_indicator', 'printed_type_line',
#        'printed_text', 'variation_of', 'life_modifier', 'hand_modifier',
#        'content_warning', 'defense'],
#       dtype='object')

# %% [markdown]
# can drop so many of these columns, only need ones that are useful.

# %% [markdown]
# ### Column Cleaning

# %%
len(df)
# Out:
# 108955

# %%
df.value_counts("variation")
df.value_counts("oversized")
# Out:
# oversized
# False    108229
# True        726
# Name: count, dtype: int64

# %%
df = df[(df["variation"]==False) & (df["reprint"]==False) & (df["oversized"]==False) & (df["promo"]==False) & (df["full_art"]==False) & (df["textless"] == False) & (df["content_warning"]!=True)]

# %%
len(df) # Dropped about 40k entries
# Out:
# 41387

# %%
doubles = df["card_faces"].dropna()
doubles.iloc[0] ## this is gonna be tough to work with
# Out:
# [{'object': 'card_face',
#   'name': "Obyra's Attendants",
#   'mana_cost': '{4}{U}',
#   'type_line': 'Creature — Faerie Wizard',
#   'oracle_text': 'Flying',
#   'power': '3',
#   'toughness': '4',
#   'flavor_text': "Obyra's devoted servants shrieked as their sleeping mistress slashed at them, unseeing.",
#   'artist': 'Andreas Zafiratos',
#   'artist_id': 'e2f13a9a-57c5-40de-81d4-3b0723899cdf',
#   'illustration_id': 'd1ea5321-62e2-4894-a79f-03b792daf2c8'},
#  {'object': 'card_face',
#   'name': 'Desperate Parry',
#   'mana_cost': '{1}{U}',
#   'type_line': 'Instant — Adventure',
#   'oracle_text': 'Target creature gets -4/-0 until end of turn. (Then exile this card. You may cast the creature later from exile.)',
#   'artist': 'Andreas Zafiratos',
#   'artist_id': 'e2f13a9a-57c5-40de-81d4-3b0723899cdf'}]

# %% [markdown]
# For first iteration of model, will be removing the multi-faced cards

# %%
df = df[df["card_faces"].isna()]

# %%
def is_legal(x):
    if 'legal' in x.values():
        return True
    else:
        return False

# %%
df["playable"] = df["legalities"].apply(is_legal)

# %%
df = df[df["playable"] == True] # remove unnplayable cards

# %%
unneeded = ['object', 'id', 'oracle_id', 'multiverse_ids', 'mtgo_id', 'arena_id',
       'tcgplayer_id', 'cardmarket_id', #'name',
         'lang', 'uri',
       'scryfall_uri', 'layout', 'highres_image', 'image_status', 'image_uris', 'legalities', 'games',
       'reserved', 'game_changer', 'finishes', 'oversized',
       'promo', 'reprint', 'variation', 'set_id', 'set', 'set_name',
       'set_type', 'set_uri', 'set_search_uri', 'scryfall_set_uri',
       'rulings_uri', 'prints_search_uri', 'collector_number', 'digital', 'card_back_id', 'artist', 'artist_ids', 'illustration_id',
       'border_color', 'frame', 'full_art', 'textless', 'booster',
       'story_spotlight', 'related_uris', 'purchase_uris',
       'mtgo_foil_id', 'flavor_text', 'edhrec_rank',
       'penny_rank', 'all_parts', 'promo_types', 'security_stamp', 'preview', 'watermark', 'frame_effects', 'loyalty',
       'printed_name', 'tcgplayer_etched_id', 'flavor_name',
       'attraction_lights', 'color_indicator', 'printed_type_line',
       'printed_text', 'variation_of', 'life_modifier', 'hand_modifier',
       'content_warning', 'defense', 'card_faces', 'foil', 'nonfoil'
       , 'playable', 'color_identity']
df = df.drop(unneeded, axis=1)

# %% [markdown]
# now that I've cleaned out cards and columns that aren't needed, I need to figure out the best way to transform this data into something that the ML model can actually use.
#
# For instance, the "type_line" column will have to be split up into various super and subtypes, probably using categorical encoding.

# %% [markdown]
# ### Type Labeling + Encoding

# %%
df["type_line"].describe() # has 4246 unique types currently
# Out:
# count       35098
# unique       3120
# top       Instant
# freq         3592
# Name: type_line, dtype: object

# %%
"""
df["creature_type"] = df["type_line"].apply(lambda x: x[10:] if "Creature" in x else "NaN")
df["planeswalker_type"] = df["type_line"].apply(lambda x: x[24:] if "Planeswalker" in x else "NaN")
df["kindred_type"] = df["type_line"].apply(lambda x: x.split()[-1] if "Kindred" in x or "Tribal" in x else "NaN")"""
# Found a better way!
# Out:
# '\ndf["creature_type"] = df["type_line"].apply(lambda x: x[10:] if "Creature" in x else "NaN")\ndf["planeswalker_type"] = df["type_line"].apply(lambda x: x[24:] if "Planeswalker" in x else "NaN")\ndf["kindred_type"] = df["type_line"].apply(lambda x: x.split()[-1] if "Kindred" in x or "Tribal" in x else "NaN")'

# %%
def filter_subtype(x):
    if "—" in x:
        ind = x.index("—")
        types = x[ind+1:].split()
        return types
    else:
        return []

# %%
def filter_maintype(x):
    types = ["Artifact", "Land", "Battle", "Creature", "Enchantment", "Planeswalker", "Instant", "Sorcery"]
    cur = []
    for type in types:
        if type in x:
            cur.append(type)
    return cur

# %%
df = df[~df['type_line'].str.contains('Basic')] # remove basic lands

# %%
df["legendary"] = df["type_line"].apply(lambda x: 1 if "Legendary" in x else 0)
df["subtype"] = df["type_line"].apply(filter_subtype)
df["main_type"]=df["type_line"].apply(filter_maintype)

# %%
df["price"] = df["prices"].str["usd"].astype(float) 
df = df.drop("prices", axis=1)

# %%
df = df.dropna(subset=["price"])
df = df[df["main_type"].map(len)>0]  # had to filter out bad cards with other types such as conspiracies and stickers

# %%
le = LabelEncoder()
le.fit(["Artifact", "Land", "Battle", "Creature", "Enchantment", "Planeswalker", "Instant", "Sorcery"])
# Out:
# LabelEncoder()

# %%
df["main_type"] = df["main_type"].apply(lambda x: le.transform(x))

# %%
le2 = LabelEncoder()

# %%
df["subtype"].values
# Out:
# array([list(['Sliver']), list(['Kor', 'Soldier']),
#        list(['Siren', 'Pirate']), ..., list([]),
#        list(['Faerie', 'Rogue']), list(['Vampire', 'Soldier'])],
#       dtype=object)

# %%
subtypes = []
for unique in df["subtype"].values:
    if unique != []:
        for val in unique:
            if val not in subtypes:
                subtypes.append(val)

le2.fit(subtypes)
# Out:
# LabelEncoder()

# %%
df["subtype"] = df["subtype"].apply(lambda x: le2.transform(x)) # slow, probably better way to do this

# %%
df = df.drop("type_line", axis=1)

# %% [markdown]
# ### Date -> Year

# %%
df["year"] = df["released_at"].apply(lambda x: x.year)
df = df.drop("released_at", axis=1)

# %% [markdown]
# ### Mana Cost Breakdown
#
# - Number of Pips
# - Is X spell?

# %%
df["is_x"] = df["mana_cost"].apply(lambda x: 1 if r"{X}" in x else 0)
#df.loc[df["is_x"] == 1]

# %%
#print("{1}{W/R}{G}{G}".replace("{", "").replace("}", " ").split())  ->  df

def pip_counter(x):
    new = x.replace("{", "").replace("}", " ").split()
    count = 0
    for x in new:
        if x.isdigit() == False and x != "X":
            count += 1

    return count

# %%
df["pip_count"] = df["mana_cost"].apply(pip_counter)
df = df.drop("mana_cost", axis=1)
#df.sort_values(by="pip_count", ascending=False)

# %% [markdown]
# ### Oracle Text Breakdown -> NLP ? Or can try a parsing method to turn text into columns
#
# - activated ability?
# - etb effect?

# %%
df["oracle_text"] = df["oracle_text"].apply(lambda x: x.lower().replace("\n", ". "))

# %% [markdown]
# #### Main Phrases

# %% [markdown]
# using vectorizer to figure out most common substrings

# %%
vectorizer = CountVectorizer(ngram_range=(4, 7), lowercase=True, stop_words=None)

# %%
X = vectorizer.fit_transform(df["oracle_text"])

# %%
sum_words = X.sum(axis=0)
word_freq = [(word, sum_words[0, idx]) for word, idx in vectorizer.vocabulary_.items()]
word_freq = sorted(word_freq, key=lambda x: x[1], reverse=True)

# %%
common_phrases = pd.DataFrame(word_freq, columns=['phrase', 'count'])
common_phrases.iloc[:10]
# Out:
#                        phrase  count
# 0           until end of turn   5990
# 1         at the beginning of   3261
# 2   when this creature enters   3049
# 3           gets until end of   2131
# 4      gets until end of turn   2130
# 5       the beginning of your   1869
# 6    at the beginning of your   1814
# 7    card from your graveyard   1593
# 8     creature gets until end   1570
# 9  creature gets until end of   1570

# %%
PHRASES = { # starter phrases
    r"when.*enters": "etb",
    r"until end of turn": "eot",
    r"beginning of .* upkeep": "b_o_u",
    r"search .* library": "tutor",
    r"without paying": "free",
    r"whenever .* attacks": "a_t",
    r"deals combat damage": "c_d_t",
    r"look at the tzo.*p": "s_s_t",
    r"return.*graveyard.*battlefield": "reanimate",
    r"when.*(this|a).*dies": "o_d_t",
    r"when.*(this|a).*leaves.": "l_b_t",
}

# %%
def canonicalize_text(str):
    for phr, rep in PHRASES.items():
        if re.search(phr, str) != None:
            str = re.sub(phr, rep, str)
    return str

# %%
df["oracle_text"] = df["oracle_text"].apply(canonicalize_text)

# %%
text_vectorizer = TextVectorization(
    max_tokens=5000, # increased vocab size
    output_mode='int',
    ngrams = (2,6),
    encoding='utf-8'
)

# %%
text_vectorizer.adapt(df["oracle_text"])

# %% [markdown]
# ### Rarity Encoding

# %%
rare_encoder = LabelEncoder()

# %%
df["rarity"].value_counts()
# Out:
# rarity
# rare        11445
# common       9878
# uncommon     8967
# mythic       1987
# special         2
# Name: count, dtype: int64

# %%
df["rarity"] = df["rarity"].apply(lambda x: "common" if x == "special" else x) # the two special cards have common rarity on scryfall

# %%
df["rarity"] = rare_encoder.fit_transform(df["rarity"])

# %% [markdown]
# ### Keyword Encoding

# %%
keywrd_encoder = LabelEncoder()

# %%
keywords = [] # taking code from earlier
for unique in df["keywords"].values:
    if unique != []:
        for val in unique:
            if val not in keywords:
                keywords.append(val)

keywrd_encoder.fit(keywords)
# Out:
# LabelEncoder()

# %%
len(keywords)
# Out:
# 604

# %%
df["keywords"] = df["keywords"].apply(lambda x: keywrd_encoder.transform(x))

# %% [markdown]
# ### Color Identity Encoding (one more time!)
#
# definitely could've done a for loop for each column i wanted to encode but oh well it's a little late for that

# %%
df
# Out:
#                        name  cmc  \
# 1               Fury Sliver  6.0
# 2             Kor Outfitter  2.0
# 4             Siren Lookout  3.0
# 7       Surge of Brilliance  2.0
# 9          Venerable Knight  1.0
# ...                     ...  ...
# 108944      Morkrut Banshee  5.0
# 108947   Deeproot Historian  4.0
# 108949  Aggressive Biomancy  2.0
# 108952  Faerie Bladecrafter  3.0
# 108953  Exultant Skymarcher  3.0
#
#                                               oracle_text  colors    keywords  \
# 1                all sliver creatures have double strike.     [R]          []
# 2       etb, you may attach target equipment you contr...     [W]          []
# 4       flying. etb, it explores. (reveal the top card...     [U]  [230, 198]
# 7       paradox — draw a card for each spell you've ca...     [U]  [390, 238]
# 9       o_d_t, put a +1/+1 counter on target knight yo...     [W]          []
# ...                                                   ...     ...         ...
# 108944  morbid — etb, if a creature died this turn, ta...     [B]       [366]
# 108947  merfolk and druid cards in your graveyard have...     [G]          []
# 108949  create x tokens that are copies of target crea...  [G, U]       [215]
# 108952  flying. o_d_t, each opponent loses x life and ...     [B]       [230]
# 108953                                             flying     [W]       [230]
#
#        produced_mana  rarity power toughness  legendary     subtype main_type  \
# 1                NaN       3     3         3          0       [310]       [2]
# 2                NaN       0     2         2          0  [183, 315]       [2]
# 4                NaN       0     1         2          0  [305, 259]       [2]
# 7                NaN       3   NaN       NaN          0          []       [4]
# 9                NaN       3     2         1          0  [157, 181]       [2]
# ...              ...     ...   ...       ...        ...         ...       ...
# 108944           NaN       3     4         4          0       [325]       [2]
# 108947           NaN       2     3         3          0   [204, 97]       [2]
# 108949           NaN       2   NaN       NaN          0          []       [7]
# 108952           NaN       2     2         2          0  [114, 280]       [2]
# 108953           NaN       0     2         3          0  [360, 315]       [2]
#
#         price  year  is_x  pip_count
# 1        0.30  2006     0          1
# 2        0.14  2009     0          2
# 4        0.08  2017     0          1
# 7        0.20  2023     0          1
# 9        0.14  2019     0          1
# ...       ...   ...   ...        ...
# 108944   0.09  2011     0          2
# 108947   0.15  2023     0          1
# 108949   0.19  2024     1          2
# 108952   1.29  2023     0          1
# 108953   0.06  2018     0          2
#
# [32279 rows x 16 columns]

# %%
c_i = LabelEncoder()

# %%
c_i.fit(["W", "G", "R", "B", "U"])
# Out:
# LabelEncoder()

# %%
c_i.transform(["W", "U"])
# Out:
# array([4, 3])

# %%
df["colors"] = df["colors"].apply(lambda x: c_i.transform(x))

# %% [markdown]
# ### Produced Mana
#
# changing this to binary value if it does(n't)

# %%
df["produced_mana"] = df["produced_mana"].replace(pd.NA, 0)

# %%
df["produced_mana"] = df["produced_mana"].apply(lambda x: 1 if x != 0 else x)

# %% [markdown]
# ### Final Step: Replace Power/Toughness NaN with -1

# %%
df["power"] = pd.to_numeric(df["power"], errors="coerce").fillna(-1)
df["toughness"] = pd.to_numeric(df["toughness"], errors="coerce").fillna(-1)

# %% [markdown]
# ### Final Data Filtering

# %%
df = df.loc[df["price"] <= 500]

# %%
df = df.loc[df["year"] >= 2000]

# %%
df.sort_values(by="price", ascending=False)
# Out:
#                                name  cmc  \
# 45968                      Mox Opal  0.0
# 11050   Liliana, Dreadhorde General  6.0
# 45216                    Chrome Mox  0.0
# 108758              The Great Henge  9.0
# 93570                  The One Ring  4.0
# ...                             ...  ...
# 76273              Constrictor Sage  5.0
# 13449             Flummoxed Cyclops  4.0
# 105586               Gruul Scrapper  4.0
# 57252           Shepherding Spirits  6.0
# 92024               Puncturing Blow  4.0
#
#                                               oracle_text colors  \
# 45968   metalcraft — {t}: add one mana of any color. a...     []
# 11050   o_d_t, draw a card.. +1: create a 2/2 black zo...    [0]
# 45216   imprint — etb, you may exile a nonartifact, no...     []
# 108758  this spell costs {x} less to cast, where x is ...    [1]
# 93570   indestructible. etb, if you cast it, you gain ...     []
# ...                                                   ...    ...
# 76273   etb, tap target creature an opponent controls ...    [3]
# 13449   reach. whenever two or more creatures your opp...    [2]
# 105586  etb, if {r} was spent to cast it, it gains has...    [1]
# 57252   flying. plainscycling {2} ({2}, discard this c...    [4]
# 92024   puncturing blow deals 5 damage to target creat...    [2]
#
#                          keywords  produced_mana  rarity  power  toughness  \
# 45968                       [356]              1       1   -1.0       -1.0
# 11050                          []              0       1   -1.0       -1.0
# 45216                       [293]              1       2   -1.0       -1.0
# 108758                         []              1       1   -1.0       -1.0
# 93570                       [296]              0       1   -1.0       -1.0
# ...                           ...            ...     ...    ...        ...
# 76273                          []              0       3    4.0        4.0
# 13449                       [435]              0       0    4.0        4.0
# 105586                         []              0       0    3.0        2.0
# 57252   [230, 402, 318, 570, 129]              0       0    4.0        5.0
# 92024                          []              0       0   -1.0       -1.0
#
#         legendary     subtype main_type   price  year  is_x  pip_count
# 45968           1          []       [0]  153.41  2010     0          0
# 11050           1       [194]       [6]  133.33  2019     0          2
# 45216           0          []       [0]   96.92  2003     0          0
# 108758          1          []       [0]   92.30  2019     0          2
# 93570           1          []       [0]   79.86  2023     0          0
# ...           ...         ...       ...     ...   ...   ...        ...
# 76273           0  [314, 378]       [2]    0.01  2025     0          1
# 13449           0        [73]       [2]    0.01  2020     0          1
# 105586          0   [157, 38]       [2]    0.01  2006     0          1
# 57252           0       [325]       [2]    0.01  2024     0          2
# 92024           0          []       [7]    0.01  2017     0          2
#
# [28076 rows x 16 columns]

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#                       name  cmc  \
# 0              Fury Sliver  6.0
# 1            Kor Outfitter  2.0
# 2            Siren Lookout  3.0
# 3      Surge of Brilliance  2.0
# 4         Venerable Knight  1.0
# ...                    ...  ...
# 28071      Morkrut Banshee  5.0
# 28072   Deeproot Historian  4.0
# 28073  Aggressive Biomancy  2.0
# 28074  Faerie Bladecrafter  3.0
# 28075  Exultant Skymarcher  3.0
#
#                                              oracle_text  colors    keywords  \
# 0               all sliver creatures have double strike.     [2]          []
# 1      etb, you may attach target equipment you contr...     [4]          []
# 2      flying. etb, it explores. (reveal the top card...     [3]  [230, 198]
# 3      paradox — draw a card for each spell you've ca...     [3]  [390, 238]
# 4      o_d_t, put a +1/+1 counter on target knight yo...     [4]          []
# ...                                                  ...     ...         ...
# 28071  morbid — etb, if a creature died this turn, ta...     [0]       [366]
# 28072  merfolk and druid cards in your graveyard have...     [1]          []
# 28073  create x tokens that are copies of target crea...  [1, 3]       [215]
# 28074  flying. o_d_t, each opponent loses x life and ...     [0]       [230]
# 28075                                             flying     [4]       [230]
#
#        produced_mana  rarity  power  toughness  legendary     subtype  \
# 0                  0       3    3.0        3.0          0       [310]
# 1                  0       0    2.0        2.0          0  [183, 315]
# 2                  0       0    1.0        2.0          0  [305, 259]
# 3                  0       3   -1.0       -1.0          0          []
# 4                  0       3    2.0        1.0          0  [157, 181]
# ...              ...     ...    ...        ...        ...         ...
# 28071              0       3    4.0        4.0          0       [325]
# 28072              0       2    3.0        3.0          0   [204, 97]
# 28073              0       2   -1.0       -1.0          0          []
# 28074              0       2    2.0        2.0          0  [114, 280]
# 28075              0       0    2.0        3.0          0  [360, 315]
#
#       main_type  price  year  is_x  pip_count
# 0           [2]   0.30  2006     0          1
# 1           [2]   0.14  2009     0          2
# 2           [2]   0.08  2017     0          1
# 3           [4]   0.20  2023     0          1
# 4           [2]   0.14  2019     0          1
# ...         ...    ...   ...   ...        ...
# 28071       [2]   0.09  2011     0          2
# 28072       [2]   0.15  2023     0          1
# 28073       [7]   0.19  2024     1          2
# 28074       [2]   1.29  2023     0          1
# 28075       [2]   0.06  2018     0          2
#
# [28076 rows x 16 columns]

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Numerical Data

# %%
numerical = df.drop(["name", "oracle_text", "colors", "keywords", "subtype", "main_type", "price"], axis=1)

# %%
numerical.columns
# Out:
# Index(['cmc', 'produced_mana', 'rarity', 'power', 'toughness', 'legendary',
#        'year', 'is_x', 'pip_count'],
#       dtype='object')

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(numerical)

# %%
number_inputs = keras.Input(shape=(9,), name="numerical")
normalized = keras.layers.Normalization()(number_inputs)

# %% [markdown]
# ### Array Data

# %% [markdown]
# describing code below:
# have to pad all the array inputs, tell keras the shape of the input, and create an embedding layer to vectorize said input
#
# input_dim is equal to number of unique ids

# %%
colors_padded = keras.preprocessing.sequence.pad_sequences(df['colors'])
colors_input = keras.Input(shape=(5,), dtype="int32", name="colors")
colors_embed = keras.layers.Embedding(input_dim=5, output_dim=4)(colors_input)
colors_pooled = keras.layers.GlobalAveragePooling1D()(colors_embed)

keywords_padded = keras.preprocessing.sequence.pad_sequences(df['keywords'])
keywords_input = keras.Input(shape=(10,), dtype="int32", name="keywords")
keywords_embed = keras.layers.Embedding(input_dim=604, output_dim=8)(keywords_input)
keywords_pooled = keras.layers.GlobalAveragePooling1D()(keywords_embed)

subtypes_padded = keras.preprocessing.sequence.pad_sequences(df['subtype'])
subtypes_input = keras.Input(shape=(4,), dtype="int32", name="subtypes")
subtypes_embed = keras.layers.Embedding(input_dim=393, output_dim=8)(subtypes_input)
subtypes_pooled = keras.layers.GlobalAveragePooling1D()(subtypes_embed)

main_type_padded = keras.preprocessing.sequence.pad_sequences(df['main_type'])
main_type_input = keras.Input(shape=(2,), dtype="int32", name="main_type")
main_type_embed = keras.layers.Embedding(input_dim=8, output_dim=4)(main_type_input)
main_type_pooled = keras.layers.GlobalAveragePooling1D()(main_type_embed)

# %% [markdown]
# ### Tokenized Data

# %%
text_input = keras.Input(shape=(), dtype=tf.string, name="oracle_text")
oracle_vector = text_vectorizer(text_input)
oracle_embed = keras.layers.Embedding(input_dim=5000, output_dim=64)(oracle_vector)
oracle_pooled = keras.layers.GlobalAveragePooling1D()(oracle_embed)

# %%
#oracle_array = text_vectorizer(df["oracle_text"].values).numpy()

# %% [markdown]
# ### Model Compiling

# %%
all_inputs = [
    number_inputs,
    text_input,
    colors_input,
    keywords_input,
    subtypes_input,
    main_type_input
]

all_features = keras.layers.concatenate([
    normalized,
    oracle_pooled,
    colors_pooled,
    keywords_pooled,
    subtypes_pooled,
    main_type_pooled
])

# %%
x = keras.layers.Dense(128, activation="relu")(all_features)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.Dense(32, activation="relu")(x)
output = keras.layers.Dense(1, name="price")(x)

# %%
x = keras.layers.BatchNormalization()(x)
x = keras.layers.Dense(32, activation="relu")(x)
output = keras.layers.Dense(1, name="price")(x)

# %%
model = keras.Model(inputs=all_inputs, outputs=output)
model.compile(optimizer="adam", loss=keras.losses.MeanSquaredError(), metrics=[keras.metrics.MeanAbsoluteError()])

# %%
early_stopping_cb = keras.callbacks.EarlyStopping(patience=25, start_from_epoch=100, monitor="mean_absolute_error", mode='min')
#model_checkpoint_cb = keras.callbacks.ModelCheckpoint(f"models\\best_model", save_best_only=True)
run_index = 1 # increment every time you train the model
run_logdir = os.path.join(os.curdir, "logs", "run_{:03d}".format(run_index))
tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)
callbacks = [early_stopping_cb, 
             #model_checkpoint_cb,
               tensorboard_cb]

# %%
model.fit(
    {
        "numerical": scaled_data,
        "oracle_text": df["oracle_text"].values,
        "keywords": keywords_padded,
        "colors": colors_padded,
        "subtypes": subtypes_padded,
        "main_type": main_type_padded
    },
    y=df["price"],
    epochs=200, # long ahh runtime fr
    batch_size=32,
    validation_split=0.3,
    callbacks=callbacks
)
# Out:
# Epoch 1/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 15.8369 - mean_absolute_error: 1.4765 - val_loss: 15.2136 - val_mean_absolute_error: 1.2526
# Epoch 2/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 13.9673 - mean_absolute_error: 1.3678 - val_loss: 13.4691 - val_mean_absolute_error: 1.3660
# Epoch 3/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 12.3213 - mean_absolute_error: 1.2603 - val_loss: 12.8788 - val_mean_absolute_error: 1.1394
# Epoch 4/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 10.5052 - mean_absolute_error: 1.1641 - val_loss: 13.1343 - val_mean_absolute_error: 1.1621
# Epoch 5/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 9.6859 - mean_absolute_error: 1.1404 - val_loss: 11.7872 - val_mean_absolute_error: 1.3163
# Epoch 6/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 8.8488 - mean_absolute_error: 1.1020 - val_loss: 11.4496 - val_mean_absolute_error: 1.1694
# Epoch 7/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 7.9140 - mean_absolute_error: 1.0822 - val_loss: 13.4710 - val_mean_absolute_error: 1.2502
# Epoch 8/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 7.5232 - mean_absolute_error: 1.0489 - val_loss: 15.1662 - val_mean_absolute_error: 1.2729
# Epoch 9/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 7.1150 - mean_absolute_error: 1.0330 - val_loss: 17.3623 - val_mean_absolute_error: 1.2959
# Epoch 10/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 6.5424 - mean_absolute_error: 1.0221 - val_loss: 23.4360 - val_mean_absolute_error: 1.5706
# Epoch 11/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 6.5671 - mean_absolute_error: 1.0156 - val_loss: 18.4917 - val_mean_absolute_error: 1.4155
# Epoch 12/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 5.8574 - mean_absolute_error: 0.9677 - val_loss: 21.0701 - val_mean_absolute_error: 1.3174
# Epoch 13/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 5.9245 - mean_absolute_error: 0.9694 - val_loss: 15.1447 - val_mean_absolute_error: 1.1136
# Epoch 14/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 5.1160 - mean_absolute_error: 0.9274 - val_loss: 28.5140 - val_mean_absolute_error: 1.4636
# Epoch 15/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 5.1696 - mean_absolute_error: 0.9331 - val_loss: 13.3222 - val_mean_absolute_error: 0.9980
# Epoch 16/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 4.8480 - mean_absolute_error: 0.9086 - val_loss: 37.2063 - val_mean_absolute_error: 1.9935
# Epoch 17/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 4.9235 - mean_absolute_error: 0.9153 - val_loss: 22.1823 - val_mean_absolute_error: 1.1999
# Epoch 18/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 4.6098 - mean_absolute_error: 0.9013 - val_loss: 19.4733 - val_mean_absolute_error: 1.2733
# Epoch 19/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 4.2963 - mean_absolute_error: 0.8771 - val_loss: 26.5252 - val_mean_absolute_error: 1.4472
# Epoch 20/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 4.1445 - mean_absolute_error: 0.8523 - val_loss: 34.8507 - val_mean_absolute_error: 1.2597
# Epoch 21/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 4.1598 - mean_absolute_error: 0.8518 - val_loss: 21.5510 - val_mean_absolute_error: 1.1213
# Epoch 22/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 4.3173 - mean_absolute_error: 0.8617 - val_loss: 18.6277 - val_mean_absolute_error: 1.1433
# Epoch 23/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 3.6881 - mean_absolute_error: 0.8244 - val_loss: 35.5669 - val_mean_absolute_error: 1.6650
# Epoch 24/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 3.7741 - mean_absolute_error: 0.8167 - val_loss: 21.6189 - val_mean_absolute_error: 1.1246
# Epoch 25/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 3.5360 - mean_absolute_error: 0.7978 - val_loss: 23.9647 - val_mean_absolute_error: 1.2502
# Epoch 26/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 3.6116 - mean_absolute_error: 0.8096 - val_loss: 28.0189 - val_mean_absolute_error: 1.3888
# Epoch 27/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 3.6793 - mean_absolute_error: 0.7975 - val_loss: 25.6756 - val_mean_absolute_error: 1.0943
# Epoch 28/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 3.6573 - mean_absolute_error: 0.7958 - val_loss: 28.0750 - val_mean_absolute_error: 1.4552
# Epoch 29/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 3.5835 - mean_absolute_error: 0.8130 - val_loss: 31.4054 - val_mean_absolute_error: 1.2213
# Epoch 30/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 3.0454 - mean_absolute_error: 0.7565 - val_loss: 34.7729 - val_mean_absolute_error: 1.3742
# Epoch 31/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 3.1873 - mean_absolute_error: 0.7785 - val_loss: 28.0002 - val_mean_absolute_error: 1.5568
# Epoch 32/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 3.2350 - mean_absolute_error: 0.7513 - val_loss: 25.1222 - val_mean_absolute_error: 1.3148
# Epoch 33/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 3.2427 - mean_absolute_error: 0.7576 - val_loss: 26.4178 - val_mean_absolute_error: 1.3785
# Epoch 34/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2.9712 - mean_absolute_error: 0.7353 - val_loss: 20.8515 - val_mean_absolute_error: 1.1220
# Epoch 35/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2.9475 - mean_absolute_error: 0.7356 - val_loss: 26.1824 - val_mean_absolute_error: 1.0835
# Epoch 36/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 2.9710 - mean_absolute_error: 0.7349 - val_loss: 23.2560 - val_mean_absolute_error: 1.2762
# Epoch 37/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2.7379 - mean_absolute_error: 0.7104 - val_loss: 40.4226 - val_mean_absolute_error: 1.2322
# Epoch 38/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2.7108 - mean_absolute_error: 0.7106 - val_loss: 33.6663 - val_mean_absolute_error: 1.3352
# Epoch 39/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2.6322 - mean_absolute_error: 0.6951 - val_loss: 48.9643 - val_mean_absolute_error: 1.7291
# Epoch 40/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 3.1303 - mean_absolute_error: 0.7313 - val_loss: 34.5134 - val_mean_absolute_error: 1.4974
# Epoch 41/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2.8635 - mean_absolute_error: 0.7059 - val_loss: 30.7273 - val_mean_absolute_error: 1.1365
# Epoch 42/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2.5212 - mean_absolute_error: 0.6860 - val_loss: 23.8322 - val_mean_absolute_error: 1.0683
# Epoch 43/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2.5978 - mean_absolute_error: 0.6821 - val_loss: 31.7521 - val_mean_absolute_error: 1.0525
# Epoch 44/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2.8323 - mean_absolute_error: 0.7014 - val_loss: 23.4693 - val_mean_absolute_error: 1.1654
# Epoch 45/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2.3801 - mean_absolute_error: 0.6561 - val_loss: 25.7717 - val_mean_absolute_error: 1.3555
# Epoch 46/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2.3741 - mean_absolute_error: 0.6717 - val_loss: 39.0690 - val_mean_absolute_error: 1.8916
# Epoch 47/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2.5684 - mean_absolute_error: 0.6577 - val_loss: 29.9931 - val_mean_absolute_error: 1.1270
# Epoch 48/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2.7434 - mean_absolute_error: 0.6896 - val_loss: 32.6036 - val_mean_absolute_error: 1.1715
# Epoch 49/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2.2874 - mean_absolute_error: 0.6490 - val_loss: 25.3077 - val_mean_absolute_error: 1.0503
# Epoch 50/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2.2213 - mean_absolute_error: 0.6402 - val_loss: 53.4354 - val_mean_absolute_error: 2.0685
# Epoch 51/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2.4974 - mean_absolute_error: 0.6534 - val_loss: 38.0675 - val_mean_absolute_error: 1.3188
# Epoch 52/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2.5539 - mean_absolute_error: 0.6571 - val_loss: 36.0302 - val_mean_absolute_error: 1.2303
# Epoch 53/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2.2897 - mean_absolute_error: 0.6380 - val_loss: 32.3266 - val_mean_absolute_error: 1.3984
# Epoch 54/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2.2281 - mean_absolute_error: 0.6365 - val_loss: 26.3183 - val_mean_absolute_error: 1.3881
# Epoch 55/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.9077 - mean_absolute_error: 0.6127 - val_loss: 34.8804 - val_mean_absolute_error: 1.1914
# Epoch 56/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2.1329 - mean_absolute_error: 0.6212 - val_loss: 19.3042 - val_mean_absolute_error: 1.2107
# Epoch 57/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2.1420 - mean_absolute_error: 0.6182 - val_loss: 38.7841 - val_mean_absolute_error: 1.2064
# Epoch 58/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2.1363 - mean_absolute_error: 0.6196 - val_loss: 23.1272 - val_mean_absolute_error: 1.2380
# Epoch 59/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2.1095 - mean_absolute_error: 0.6138 - val_loss: 20.2769 - val_mean_absolute_error: 1.2166
# Epoch 60/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.8754 - mean_absolute_error: 0.5953 - val_loss: 25.8271 - val_mean_absolute_error: 1.1429
# Epoch 61/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2.0603 - mean_absolute_error: 0.6105 - val_loss: 49.9141 - val_mean_absolute_error: 1.9130
# Epoch 62/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.9367 - mean_absolute_error: 0.5972 - val_loss: 25.1028 - val_mean_absolute_error: 1.0890
# Epoch 63/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.7665 - mean_absolute_error: 0.5783 - val_loss: 15.8135 - val_mean_absolute_error: 1.0039
# Epoch 64/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2.0237 - mean_absolute_error: 0.5972 - val_loss: 26.7510 - val_mean_absolute_error: 1.0618
# Epoch 65/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2.1104 - mean_absolute_error: 0.6061 - val_loss: 42.7054 - val_mean_absolute_error: 1.8921
# Epoch 66/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.9725 - mean_absolute_error: 0.5958 - val_loss: 34.8457 - val_mean_absolute_error: 1.2435
# Epoch 67/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.6963 - mean_absolute_error: 0.5724 - val_loss: 30.4865 - val_mean_absolute_error: 1.2197
# Epoch 68/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.8566 - mean_absolute_error: 0.5869 - val_loss: 25.4976 - val_mean_absolute_error: 1.1819
# Epoch 69/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.7700 - mean_absolute_error: 0.5725 - val_loss: 37.8776 - val_mean_absolute_error: 1.0696
# Epoch 70/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.9203 - mean_absolute_error: 0.5834 - val_loss: 28.3675 - val_mean_absolute_error: 1.4546
# Epoch 71/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.8319 - mean_absolute_error: 0.5915 - val_loss: 30.0261 - val_mean_absolute_error: 1.0404
# Epoch 72/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.7588 - mean_absolute_error: 0.5706 - val_loss: 28.3924 - val_mean_absolute_error: 1.0597
# Epoch 73/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.7797 - mean_absolute_error: 0.5682 - val_loss: 30.5991 - val_mean_absolute_error: 1.2969
# Epoch 74/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.7118 - mean_absolute_error: 0.5689 - val_loss: 24.6356 - val_mean_absolute_error: 1.0824
# Epoch 75/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.7473 - mean_absolute_error: 0.5666 - val_loss: 32.5856 - val_mean_absolute_error: 1.2647
# Epoch 76/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.9941 - mean_absolute_error: 0.5728 - val_loss: 57.1562 - val_mean_absolute_error: 1.1213
# Epoch 77/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.8921 - mean_absolute_error: 0.5778 - val_loss: 32.9538 - val_mean_absolute_error: 1.1111
# Epoch 78/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.7028 - mean_absolute_error: 0.5577 - val_loss: 47.6897 - val_mean_absolute_error: 1.1915
# Epoch 79/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.6604 - mean_absolute_error: 0.5474 - val_loss: 34.9201 - val_mean_absolute_error: 1.1731
# Epoch 80/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.6923 - mean_absolute_error: 0.5553 - val_loss: 41.0855 - val_mean_absolute_error: 1.4163
# Epoch 81/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.6336 - mean_absolute_error: 0.5473 - val_loss: 34.1326 - val_mean_absolute_error: 1.3255
# Epoch 82/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.5335 - mean_absolute_error: 0.5355 - val_loss: 40.9717 - val_mean_absolute_error: 1.1234
# Epoch 83/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.5836 - mean_absolute_error: 0.5428 - val_loss: 36.0281 - val_mean_absolute_error: 1.1995
# Epoch 84/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.5526 - mean_absolute_error: 0.5386 - val_loss: 57.0190 - val_mean_absolute_error: 1.2560
# Epoch 85/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.8056 - mean_absolute_error: 0.5608 - val_loss: 15.4787 - val_mean_absolute_error: 1.0218
# Epoch 86/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.6034 - mean_absolute_error: 0.5420 - val_loss: 49.7185 - val_mean_absolute_error: 1.8139
# Epoch 87/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.6075 - mean_absolute_error: 0.5346 - val_loss: 30.1569 - val_mean_absolute_error: 1.1105
# Epoch 88/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.9093 - mean_absolute_error: 0.5944 - val_loss: 27.6939 - val_mean_absolute_error: 1.0855
# Epoch 89/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.5970 - mean_absolute_error: 0.5352 - val_loss: 27.2634 - val_mean_absolute_error: 1.0265
# Epoch 90/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.4184 - mean_absolute_error: 0.5170 - val_loss: 27.4831 - val_mean_absolute_error: 1.0421
# Epoch 91/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 1.4103 - mean_absolute_error: 0.5123 - val_loss: 33.3174 - val_mean_absolute_error: 1.2043
# Epoch 92/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 1.4368 - mean_absolute_error: 0.5167 - val_loss: 43.3762 - val_mean_absolute_error: 1.2065
# Epoch 93/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.6249 - mean_absolute_error: 0.5325 - val_loss: 21.5783 - val_mean_absolute_error: 1.0902
# Epoch 94/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.6176 - mean_absolute_error: 0.5478 - val_loss: 39.2003 - val_mean_absolute_error: 1.2784
# Epoch 95/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 1.3288 - mean_absolute_error: 0.5131 - val_loss: 39.9570 - val_mean_absolute_error: 1.4172
# Epoch 96/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.4256 - mean_absolute_error: 0.5126 - val_loss: 23.9582 - val_mean_absolute_error: 1.1668
# Epoch 97/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.6762 - mean_absolute_error: 0.5640 - val_loss: 22.7829 - val_mean_absolute_error: 1.3827
# Epoch 98/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.4795 - mean_absolute_error: 0.5213 - val_loss: 30.8003 - val_mean_absolute_error: 1.1338
# Epoch 99/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 1.4182 - mean_absolute_error: 0.5159 - val_loss: 35.0557 - val_mean_absolute_error: 1.1734
# Epoch 100/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.5460 - mean_absolute_error: 0.5226 - val_loss: 22.8841 - val_mean_absolute_error: 1.0556
# Epoch 101/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 1.5219 - mean_absolute_error: 0.5242 - val_loss: 33.4888 - val_mean_absolute_error: 1.0812
# Epoch 102/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.3762 - mean_absolute_error: 0.5087 - val_loss: 57.7134 - val_mean_absolute_error: 1.1840
# Epoch 103/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.2845 - mean_absolute_error: 0.4932 - val_loss: 63.7587 - val_mean_absolute_error: 1.3347
# Epoch 104/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.4550 - mean_absolute_error: 0.5147 - val_loss: 44.6112 - val_mean_absolute_error: 1.1681
# Epoch 105/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.7909 - mean_absolute_error: 0.5483 - val_loss: 42.3594 - val_mean_absolute_error: 1.1592
# Epoch 106/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 1.4154 - mean_absolute_error: 0.5100 - val_loss: 65.9624 - val_mean_absolute_error: 1.8379
# Epoch 107/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.3436 - mean_absolute_error: 0.5026 - val_loss: 50.4312 - val_mean_absolute_error: 1.1020
# Epoch 108/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.3057 - mean_absolute_error: 0.4996 - val_loss: 49.3226 - val_mean_absolute_error: 1.1936
# Epoch 109/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.5418 - mean_absolute_error: 0.5062 - val_loss: 36.9235 - val_mean_absolute_error: 1.2336
# Epoch 110/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.3097 - mean_absolute_error: 0.4877 - val_loss: 61.8088 - val_mean_absolute_error: 1.2993
# Epoch 111/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.1741 - mean_absolute_error: 0.4784 - val_loss: 61.0791 - val_mean_absolute_error: 1.3724
# Epoch 112/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.3545 - mean_absolute_error: 0.4982 - val_loss: 36.0208 - val_mean_absolute_error: 1.0608
# Epoch 113/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.3124 - mean_absolute_error: 0.4931 - val_loss: 37.5368 - val_mean_absolute_error: 1.1390
# Epoch 114/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.4200 - mean_absolute_error: 0.5079 - val_loss: 40.5807 - val_mean_absolute_error: 1.1420
# Epoch 115/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.3268 - mean_absolute_error: 0.4986 - val_loss: 37.2074 - val_mean_absolute_error: 1.1378
# Epoch 116/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.2428 - mean_absolute_error: 0.4881 - val_loss: 28.8841 - val_mean_absolute_error: 1.0710
# Epoch 117/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.2619 - mean_absolute_error: 0.4852 - val_loss: 56.4191 - val_mean_absolute_error: 1.2355
# Epoch 118/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.2937 - mean_absolute_error: 0.4877 - val_loss: 49.1348 - val_mean_absolute_error: 1.1729
# Epoch 119/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.3461 - mean_absolute_error: 0.4956 - val_loss: 50.8726 - val_mean_absolute_error: 1.3073
# Epoch 120/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.1747 - mean_absolute_error: 0.4767 - val_loss: 35.5298 - val_mean_absolute_error: 1.1438
# Epoch 121/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.3611 - mean_absolute_error: 0.4867 - val_loss: 38.8476 - val_mean_absolute_error: 1.1823
# Epoch 122/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.3266 - mean_absolute_error: 0.4781 - val_loss: 31.6179 - val_mean_absolute_error: 1.1403
# Epoch 123/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.5592 - mean_absolute_error: 0.5241 - val_loss: 45.1473 - val_mean_absolute_error: 1.1237
# Epoch 124/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.2741 - mean_absolute_error: 0.4911 - val_loss: 41.6424 - val_mean_absolute_error: 1.1319
# Epoch 125/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.1712 - mean_absolute_error: 0.4706 - val_loss: 57.3804 - val_mean_absolute_error: 1.3547
# Epoch 126/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.2782 - mean_absolute_error: 0.4821 - val_loss: 76.8713 - val_mean_absolute_error: 1.4004
# Epoch 127/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.2185 - mean_absolute_error: 0.4814 - val_loss: 50.6526 - val_mean_absolute_error: 1.3890
# Epoch 128/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.1799 - mean_absolute_error: 0.4701 - val_loss: 78.7198 - val_mean_absolute_error: 2.0386
# Epoch 129/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.2631 - mean_absolute_error: 0.4786 - val_loss: 64.6444 - val_mean_absolute_error: 1.2205
# Epoch 130/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.2128 - mean_absolute_error: 0.4649 - val_loss: 62.2560 - val_mean_absolute_error: 1.1625
# Epoch 131/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.1404 - mean_absolute_error: 0.4618 - val_loss: 93.2730 - val_mean_absolute_error: 2.3052
# Epoch 132/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.2059 - mean_absolute_error: 0.4685 - val_loss: 55.3959 - val_mean_absolute_error: 1.0844
# Epoch 133/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.3154 - mean_absolute_error: 0.4833 - val_loss: 70.9437 - val_mean_absolute_error: 1.1972
# Epoch 134/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.4093 - mean_absolute_error: 0.4813 - val_loss: 88.0930 - val_mean_absolute_error: 1.3685
# Epoch 135/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.2615 - mean_absolute_error: 0.4838 - val_loss: 79.5166 - val_mean_absolute_error: 1.1509
# Epoch 136/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.1503 - mean_absolute_error: 0.4656 - val_loss: 83.2487 - val_mean_absolute_error: 1.2533
# Epoch 137/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.1891 - mean_absolute_error: 0.4690 - val_loss: 70.8641 - val_mean_absolute_error: 1.1942
# Epoch 138/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.2115 - mean_absolute_error: 0.4681 - val_loss: 104.8028 - val_mean_absolute_error: 1.3207
# Epoch 139/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.1869 - mean_absolute_error: 0.4638 - val_loss: 77.1723 - val_mean_absolute_error: 1.6614
# Epoch 140/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.0675 - mean_absolute_error: 0.4493 - val_loss: 56.8486 - val_mean_absolute_error: 1.1797
# Epoch 141/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.0936 - mean_absolute_error: 0.4470 - val_loss: 98.2815 - val_mean_absolute_error: 1.2456
# Epoch 142/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.1529 - mean_absolute_error: 0.4656 - val_loss: 79.4832 - val_mean_absolute_error: 1.1555
# Epoch 143/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 1.1020 - mean_absolute_error: 0.4536 - val_loss: 78.6242 - val_mean_absolute_error: 1.2719
# Epoch 144/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 1.1481 - mean_absolute_error: 0.4594 - val_loss: 52.0825 - val_mean_absolute_error: 1.1074
# Epoch 145/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.2897 - mean_absolute_error: 0.4665 - val_loss: 87.5900 - val_mean_absolute_error: 1.3942
# Epoch 146/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.1207 - mean_absolute_error: 0.4496 - val_loss: 64.0313 - val_mean_absolute_error: 1.2250
# Epoch 147/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 1.2098 - mean_absolute_error: 0.4594 - val_loss: 29.4380 - val_mean_absolute_error: 1.0196
# Epoch 148/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.2008 - mean_absolute_error: 0.4635 - val_loss: 96.3683 - val_mean_absolute_error: 1.2883
# Epoch 149/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.0709 - mean_absolute_error: 0.4404 - val_loss: 70.8370 - val_mean_absolute_error: 1.6355
# Epoch 150/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.1232 - mean_absolute_error: 0.4515 - val_loss: 57.3422 - val_mean_absolute_error: 1.1353
# Epoch 151/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.2294 - mean_absolute_error: 0.4630 - val_loss: 154.4062 - val_mean_absolute_error: 1.4801
# Epoch 152/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.2173 - mean_absolute_error: 0.4522 - val_loss: 48.8217 - val_mean_absolute_error: 1.2689
# Epoch 153/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.1533 - mean_absolute_error: 0.4501 - val_loss: 50.7509 - val_mean_absolute_error: 1.5810
# Epoch 154/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.0931 - mean_absolute_error: 0.4434 - val_loss: 68.3921 - val_mean_absolute_error: 1.1335
# Epoch 155/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.0882 - mean_absolute_error: 0.4429 - val_loss: 72.9546 - val_mean_absolute_error: 1.7395
# Epoch 156/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.1663 - mean_absolute_error: 0.4621 - val_loss: 52.4371 - val_mean_absolute_error: 1.2225
# Epoch 157/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.1278 - mean_absolute_error: 0.4463 - val_loss: 83.2096 - val_mean_absolute_error: 1.5491
# Epoch 158/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.1207 - mean_absolute_error: 0.4523 - val_loss: 60.3022 - val_mean_absolute_error: 1.1722
# Epoch 159/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.0381 - mean_absolute_error: 0.4433 - val_loss: 65.5145 - val_mean_absolute_error: 1.0862
# Epoch 160/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.0491 - mean_absolute_error: 0.4432 - val_loss: 79.1055 - val_mean_absolute_error: 1.2265
# Epoch 161/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.0537 - mean_absolute_error: 0.4499 - val_loss: 104.4848 - val_mean_absolute_error: 1.5624
# Epoch 162/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 1.0990 - mean_absolute_error: 0.4458 - val_loss: 65.1352 - val_mean_absolute_error: 1.1547
# Epoch 163/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.3006 - mean_absolute_error: 0.4722 - val_loss: 55.5224 - val_mean_absolute_error: 1.6835
# Epoch 164/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.0134 - mean_absolute_error: 0.4341 - val_loss: 55.3573 - val_mean_absolute_error: 1.2340
# Epoch 165/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.0701 - mean_absolute_error: 0.4436 - val_loss: 34.3620 - val_mean_absolute_error: 1.2394
# Epoch 166/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.9462 - mean_absolute_error: 0.4258 - val_loss: 63.4458 - val_mean_absolute_error: 1.3962
# Epoch 167/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.0613 - mean_absolute_error: 0.4381 - val_loss: 62.2212 - val_mean_absolute_error: 1.1736
# Epoch 168/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.1126 - mean_absolute_error: 0.4479 - val_loss: 61.1739 - val_mean_absolute_error: 1.1167
# Epoch 169/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.1578 - mean_absolute_error: 0.4442 - val_loss: 103.0672 - val_mean_absolute_error: 1.2311
# Epoch 170/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.2497 - mean_absolute_error: 0.4615 - val_loss: 131.3236 - val_mean_absolute_error: 1.4147
# Epoch 171/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.0917 - mean_absolute_error: 0.4342 - val_loss: 91.8882 - val_mean_absolute_error: 1.3449
# Epoch 172/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.3327 - mean_absolute_error: 0.4747 - val_loss: 59.8057 - val_mean_absolute_error: 1.2168
# Epoch 173/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.0577 - mean_absolute_error: 0.4369 - val_loss: 61.9347 - val_mean_absolute_error: 1.1905
# Epoch 174/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.0723 - mean_absolute_error: 0.4383 - val_loss: 74.4386 - val_mean_absolute_error: 1.2407
# Epoch 175/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.9678 - mean_absolute_error: 0.4243 - val_loss: 123.3144 - val_mean_absolute_error: 1.4349
# Epoch 176/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.0536 - mean_absolute_error: 0.4288 - val_loss: 65.7396 - val_mean_absolute_error: 1.2326
# Epoch 177/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.1253 - mean_absolute_error: 0.4407 - val_loss: 65.0989 - val_mean_absolute_error: 1.2519
# Epoch 178/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.0163 - mean_absolute_error: 0.4293 - val_loss: 49.6575 - val_mean_absolute_error: 1.1135
# Epoch 179/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.3341 - mean_absolute_error: 0.4594 - val_loss: 100.4190 - val_mean_absolute_error: 1.1981
# Epoch 180/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.0491 - mean_absolute_error: 0.4289 - val_loss: 108.2857 - val_mean_absolute_error: 1.6874
# Epoch 181/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.9517 - mean_absolute_error: 0.4146 - val_loss: 78.6099 - val_mean_absolute_error: 1.3437
# Epoch 182/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.0192 - mean_absolute_error: 0.4343 - val_loss: 118.8716 - val_mean_absolute_error: 1.1751
# Epoch 183/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.4693 - mean_absolute_error: 0.4917 - val_loss: 71.3424 - val_mean_absolute_error: 1.1921
# Epoch 184/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.0157 - mean_absolute_error: 0.4264 - val_loss: 61.0399 - val_mean_absolute_error: 1.1088
# Epoch 185/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.0631 - mean_absolute_error: 0.4338 - val_loss: 71.2184 - val_mean_absolute_error: 1.2247
# Epoch 186/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.9722 - mean_absolute_error: 0.4180 - val_loss: 69.5205 - val_mean_absolute_error: 1.1186
# Epoch 187/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.9695 - mean_absolute_error: 0.4190 - val_loss: 112.7485 - val_mean_absolute_error: 1.3031
# Epoch 188/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.1033 - mean_absolute_error: 0.4351 - val_loss: 150.7306 - val_mean_absolute_error: 1.3999
# Epoch 189/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.0572 - mean_absolute_error: 0.4303 - val_loss: 53.9646 - val_mean_absolute_error: 1.3655
# Epoch 190/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.0305 - mean_absolute_error: 0.4274 - val_loss: 99.6504 - val_mean_absolute_error: 1.3379
# Epoch 191/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.9676 - mean_absolute_error: 0.4187 - val_loss: 59.1970 - val_mean_absolute_error: 1.3264
# Epoch 192/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.9698 - mean_absolute_error: 0.4206 - val_loss: 104.3711 - val_mean_absolute_error: 1.3163
# Epoch 193/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.9654 - mean_absolute_error: 0.4161 - val_loss: 67.4949 - val_mean_absolute_error: 1.2809
# Epoch 194/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.0904 - mean_absolute_error: 0.4239 - val_loss: 119.6958 - val_mean_absolute_error: 1.3507
# Epoch 195/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.0853 - mean_absolute_error: 0.4240 - val_loss: 74.0117 - val_mean_absolute_error: 1.1055
# Epoch 196/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.0132 - mean_absolute_error: 0.4214 - val_loss: 93.8493 - val_mean_absolute_error: 1.3153
# Epoch 197/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.0444 - mean_absolute_error: 0.4361 - val_loss: 65.2762 - val_mean_absolute_error: 1.1133
# Epoch 198/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.0825 - mean_absolute_error: 0.4304 - val_loss: 53.9670 - val_mean_absolute_error: 1.1315
# Epoch 199/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.0475 - mean_absolute_error: 0.4223 - val_loss: 57.0511 - val_mean_absolute_error: 1.2417
# Epoch 200/200
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.0520 - mean_absolute_error: 0.4265 - val_loss: 75.2233 - val_mean_absolute_error: 1.2259

# %% [markdown]
# #### Initial Results:
#
# MAE of 0.36 cents, loss of 0.81. Will try to optimize!

# %%
model.save("models\\best_model.keras")

# %% [markdown]
# ## Model Improvement

# %%
text_vectorizer.save_assets("models\\text_vectorizer")

# %%
model2 = keras.models.load_model(
    "models\\best_model.keras",
    custom_objects={
        "TextVectorization": TextVectorization,
    }
)

# %%
df.loc[df["name"].str.contains("Liliana")]
# Out:
#                               name  cmc  \
# 1515              Liliana's Caress  2.0
# 1726              Liliana's Defeat  1.0
# 2509                  Liliana Vess  5.0
# 2788             Liliana's Steward  1.0
# 2826   Liliana, Dreadhorde General  6.0
# 3201               Liliana's Shade  4.0
# 3519               Oath of Liliana  3.0
# 4450           Liliana's Influence  6.0
# 4877    Liliana of the Dark Realms  4.0
# 5575             Liliana's Specter  3.0
# 6112         Liliana's Indignation  1.0
# 6494     Liliana's Standard Bearer  3.0
# 6735     Liliana's Standard Bearer  3.0
# 7028      Liliana, Death's Majesty  5.0
# 9862           Liliana's Scrounger  3.0
# 10076            Liliana's Mastery  5.0
# 11474            Liliana's Devotee  3.0
# 12768           Liliana's Contract  5.0
# 14471            Liliana's Triumph  2.0
# 18338             Liliana's Reaver  4.0
# 18383  Liliana, Untouched by Death  4.0
# 18705            Liliana's Steward  1.0
# 18879             Liliana's Talent  2.0
# 18901          Liliana of the Veil  3.0
# 19021              Liliana's Elite  3.0
# 19138            Liliana's Devotee  3.0
# 19540              Liliana's Scorn  5.0
# 23617  Liliana, Dreadhorde General  6.0
# 24900   Liliana, Waker of the Dead  4.0
# 25498   Liliana, Waker of the Dead  4.0
# 25545             Liliana's Spoils  4.0
# 27456       Liliana, the Last Hope  3.0
# 27546             Liliana's Talent  2.0
#
#                                              oracle_text colors keywords  \
# 1515   whenever an opponent discards a card, that pla...    [0]       []
# 1726   destroy target black creature or black planesw...    [0]       []
# 2509   +1: target player discards a card.. −2: tutor ...    [0]       []
# 2788   {t}, sacrifice this creature: target opponent ...    [0]       []
# 2826   o_d_t, draw a card.. +1: create a 2/2 black zo...    [0]       []
# 3201   etb, you may tutor for a swamp card, reveal it...    [0]       []
# 3519   etb, each opponent sacrifices a creature of th...    [0]       []
# 4450   put a -1/-1 counter on each creature you don't...    [0]       []
# 4877   +1: tutor for a swamp card, reveal it, put it ...    [0]       []
# 5575         flying. etb, each opponent discards a card.    [0]    [230]
# 6112   mill x cards. target player loses 2 life for e...    [0]    [359]
# 6494   flash. etb, draw x cards, where x is the numbe...    [0]    [225]
# 6735   flash. etb, draw x cards, where x is the numbe...    [0]    [225]
# 7028   +1: create a 2/2 black zombie creature token. ...    [0]    [359]
# 9862   at the beginning of each end step, if a creatu...    [0]       []
# 10076  zombies you control get +1/+1.. etb, create tw...    [0]       []
# 11474  zombies you control get +1/+0.. at the beginni...    [0]       []
# 12768  etb, you draw four cards and you lose 4 life.....    [0]       []
# 14471  each opponent sacrifices a creature of their c...    [0]       []
# 18338  deathtouch. whenever this creature c_d_t to a ...    [0]    [136]
# 18383  +1: mill three cards. if at least one zombie c...    [0]    [359]
# 18705  {t}, sacrifice this creature: target opponent ...    [0]       []
# 18879  enchant planeswalker. enchanted planeswalker h...    [0]    [174]
# 18901  +1: each player discards a card.. −2: target p...    [0]       []
# 19021  this creature gets +1/+1 for each creature car...    [0]       []
# 19138  zombies you control get +1/+0.. at the beginni...    [0]       []
# 19540  destroy target creature. you may tutor this wa...    [0]       []
# 23617  o_d_t, draw a card.. +1: create a 2/2 black zo...    [0]       []
# 24900  +1: each player discards a card. each opponent...    [0]       []
# 25498  +1: each player discards a card. each opponent...    [0]       []
# 25545  target opponent discards a card.. look at the ...    [0]       []
# 27456  +1: up to one target creature gets -2/-1 until...    [0]    [359]
# 27546  enchant planeswalker. enchanted planeswalker h...    [0]    [174]
#
#        produced_mana  rarity  power  toughness  legendary     subtype  \
# 1515               0       3   -1.0       -1.0          0          []
# 1726               0       3   -1.0       -1.0          0          []
# 2509               0       2   -1.0       -1.0          1       [194]
# 2788               0       0    1.0        2.0          0       [391]
# 2826               0       1   -1.0       -1.0          1       [194]
# 3201               0       0    1.0        1.0          0       [299]
# 3519               0       2   -1.0       -1.0          1          []
# 4450               0       2   -1.0       -1.0          0          []
# 4877               1       1   -1.0       -1.0          1       [194]
# 5575               0       0    2.0        1.0          0       [319]
# 6112               0       3   -1.0       -1.0          0          []
# 6494               0       2    3.0        1.0          0  [391, 181]
# 6735               0       2    3.0        1.0          0  [391, 181]
# 7028               0       1   -1.0       -1.0          1       [194]
# 9862               0       3    3.0        2.0          0  [157, 378]
# 10076              0       2   -1.0       -1.0          0          []
# 11474              0       3    2.0        3.0          0  [157, 371]
# 12768              0       2   -1.0       -1.0          0          []
# 14471              0       3   -1.0       -1.0          0          []
# 18338              0       2    4.0        3.0          0       [391]
# 18383              0       1   -1.0       -1.0          1       [194]
# 18705              0       0    1.0        2.0          0       [391]
# 18879              0       2   -1.0       -1.0          0        [21]
# 18901              0       1   -1.0       -1.0          1       [194]
# 19021              0       3    1.0        1.0          0       [391]
# 19138              0       3    2.0        3.0          0  [157, 371]
# 19540              0       2   -1.0       -1.0          0          []
# 23617              0       1   -1.0       -1.0          1       [194]
# 24900              0       1   -1.0       -1.0          1       [194]
# 25498              0       1   -1.0       -1.0          1       [194]
# 25545              0       2   -1.0       -1.0          0          []
# 27456              0       1   -1.0       -1.0          1       [194]
# 27546              0       2   -1.0       -1.0          0        [21]
#
#       main_type   price  year  is_x  pip_count
# 1515        [3]    6.53  2010     0          1
# 1726        [7]    0.09  2017     0          1
# 2509        [6]   11.57  2007     0          2
# 2788        [2]    0.03  2020     0          1
# 2826        [6]  133.33  2019     0          2
# 3201        [2]    0.07  2012     0          2
# 3519        [3]    0.34  2016     0          1
# 4450        [7]    0.30  2017     0          2
# 4877        [6]    6.65  2012     0          2
# 5575        [2]    0.20  2010     0          2
# 6112        [7]    0.13  2016     1          1
# 6494        [2]    0.21  2020     0          1
# 6735        [2]    0.16  2020     0          1
# 7028        [6]    0.67  2017     0          2
# 9862        [2]    0.41  2020     0          1
# 10076       [3]    0.43  2017     0          2
# 11474       [2]    0.09  2020     0          1
# 12768       [3]    1.48  2018     0          2
# 14471       [4]    0.23  2019     0          1
# 18338       [2]    0.49  2013     0          2
# 18383       [6]    1.75  2018     0          2
# 18705       [2]    0.10  2020     0          1
# 18879       [3]    0.41  2023     0          2
# 18901       [6]   13.94  2011     0          2
# 19021       [2]    0.06  2016     0          1
# 19138       [2]    0.09  2020     0          1
# 19540       [7]    0.22  2020     0          2
# 23617       [6]    6.43  2019     0          2
# 24900       [6]    2.25  2020     0          2
# 25498       [6]    2.42  2020     0          2
# 25545       [7]    0.32  2018     0          1
# 27456       [6]    2.91  2016     0          2
# 27546       [3]    0.30  2023     0          2

# %%
df.iloc[2509]
# Out:
# name                                                  Liliana Vess
# cmc                                                            5.0
# oracle_text      +1: target player discards a card.. −2: tutor ...
# colors                                                         [0]
# keywords                                                        []
# produced_mana                                                    0
# rarity                                                           2
# power                                                         -1.0
# toughness                                                     -1.0
# legendary                                                        1
# subtype                                                      [194]
# main_type                                                      [6]
# price                                                        11.57
# year                                                          2007
# is_x                                                             0
# pip_count                                                        2
# Name: 2509, dtype: object

# %%
model2.predict({
    "numerical": scaled_data[2509:2510],
    "oracle_text": np.array([df["oracle_text"].values[2509]], dtype=object),
    "keywords": np.array([keywords_padded[2509]]),
    "colors": np.array([colors_padded[2509]]),
    "subtypes": np.array([subtypes_padded[2509]]),
    "main_type": np.array([main_type_padded[2509]])
})
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# array([[14.1174755]], dtype=float32)
