# %% [markdown]
# # MTG Price Predictor
#
# ## About/Goals:
#
# The idea of this project is to create an ML model that can take a card's data and return the value of the card should be, based on previous cards it has analysed. This requires NLP processing for the text box, and utilizes tensorflow to build the model.
#
# Cards are evaluated purely based on what a person looking at it for the first time can see - year, text, color, etc.. nothing about format legalities, special flags, or anythingn else of the sort. Also, price is based on standard, nonfoil variant only.

# %% [markdown]
# # Data Importation and Cleaning

# %% [markdown]
# #### All imports cell

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer
import tensorflow as tf
from tensorflow.keras.layers import TextVectorization
from sklearn.preprocessing import MinMaxScaler
import re
import os
from sklearn.preprocessing import RobustScaler

# %%
def save(file):
    file.to_pickle('data/updated_data.pkl')

def load():
    df = pd.read_pickle('data/updated_data.pkl')
    return df # band-aid work-around

# %%
df = pd.read_json("data/default_cards_08_05_2025.json")

# %%
df.columns
# Out:
# Index(['object', 'id', 'oracle_id', 'multiverse_ids', 'mtgo_id', 'arena_id',
#        'tcgplayer_id', 'cardmarket_id', 'name', 'lang', 'released_at', 'uri',
#        'scryfall_uri', 'layout', 'highres_image', 'image_status', 'image_uris',
#        'mana_cost', 'cmc', 'type_line', 'oracle_text', 'colors',
#        'color_identity', 'keywords', 'produced_mana', 'legalities', 'games',
#        'reserved', 'game_changer', 'foil', 'nonfoil', 'finishes', 'oversized',
#        'promo', 'reprint', 'variation', 'set_id', 'set', 'set_name',
#        'set_type', 'set_uri', 'set_search_uri', 'scryfall_set_uri',
#        'rulings_uri', 'prints_search_uri', 'collector_number', 'digital',
#        'rarity', 'card_back_id', 'artist', 'artist_ids', 'illustration_id',
#        'border_color', 'frame', 'full_art', 'textless', 'booster',
#        'story_spotlight', 'prices', 'related_uris', 'purchase_uris',
#        'mtgo_foil_id', 'power', 'toughness', 'flavor_text', 'edhrec_rank',
#        'penny_rank', 'all_parts', 'promo_types', 'security_stamp',
#        'card_faces', 'preview', 'watermark', 'frame_effects', 'loyalty',
#        'printed_name', 'tcgplayer_etched_id', 'flavor_name',
#        'attraction_lights', 'color_indicator', 'printed_type_line',
#        'printed_text', 'variation_of', 'life_modifier', 'hand_modifier',
#        'content_warning', 'defense'],
#       dtype='object')

# %% [markdown]
# can drop so many of these columns, only need ones that are useful.

# %% [markdown]
# ### Column Cleaning

# %%
len(df)
# Out:
# 108955

# %%
df.value_counts("variation")
#df.value_counts("oversized")
# Out:
# variation
# False    108867
# True         88
# Name: count, dtype: int64

# %%
df = df[(df["variation"]==False) & (df["reprint"]==False) & (df["oversized"]==False) & (df["promo"]==False) & (df["full_art"]==False) & (df["textless"] == False) & (df["content_warning"]!=True)]

# %%
len(df) # Dropped about 40k entries
# Out:
# 41387

# %%
doubles = df["card_faces"].dropna()
doubles.iloc[0] ## this is gonna be tough to work with
# Out:
# [{'object': 'card_face',
#   'name': "Obyra's Attendants",
#   'mana_cost': '{4}{U}',
#   'type_line': 'Creature — Faerie Wizard',
#   'oracle_text': 'Flying',
#   'power': '3',
#   'toughness': '4',
#   'flavor_text': "Obyra's devoted servants shrieked as their sleeping mistress slashed at them, unseeing.",
#   'artist': 'Andreas Zafiratos',
#   'artist_id': 'e2f13a9a-57c5-40de-81d4-3b0723899cdf',
#   'illustration_id': 'd1ea5321-62e2-4894-a79f-03b792daf2c8'},
#  {'object': 'card_face',
#   'name': 'Desperate Parry',
#   'mana_cost': '{1}{U}',
#   'type_line': 'Instant — Adventure',
#   'oracle_text': 'Target creature gets -4/-0 until end of turn. (Then exile this card. You may cast the creature later from exile.)',
#   'artist': 'Andreas Zafiratos',
#   'artist_id': 'e2f13a9a-57c5-40de-81d4-3b0723899cdf'}]

# %% [markdown]
# For first iteration of model, will be removing the multi-faced cards

# %%
df = df[df["card_faces"].isna()]

# %%
def is_legal(x):
    if 'legal' in x.values():
        return True
    else:
        return False

# %%
df["playable"] = df["legalities"].apply(is_legal)

# %%
df = df[df["playable"] == True] # remove unnplayable cards

# %%
unneeded = ['object', 'id', 'oracle_id', 'multiverse_ids', 'mtgo_id', 'arena_id',
       'tcgplayer_id', 'cardmarket_id', #'name',
         'lang', 'uri',
       'scryfall_uri', 'layout', 'highres_image', 'image_status', 'image_uris', 'legalities', 'games',
       'reserved', 'game_changer', 'finishes', 'oversized',
       'promo', 'reprint', 'variation', 'set_id', 'set', 'set_name',
       'set_type', 'set_uri', 'set_search_uri', 'scryfall_set_uri',
       'rulings_uri', 'prints_search_uri', 'collector_number', 'digital', 'card_back_id', 'artist', 'artist_ids', 'illustration_id',
       'border_color', 'frame', 'full_art', 'textless', 'booster',
       'story_spotlight', 'related_uris', 'purchase_uris',
       'mtgo_foil_id', 'flavor_text', 'edhrec_rank',
       'penny_rank', 'all_parts', 'promo_types', 'security_stamp', 'preview', 'watermark', 'frame_effects', 'loyalty',
       'printed_name', 'tcgplayer_etched_id', 'flavor_name',
       'attraction_lights', 'color_indicator', 'printed_type_line',
       'printed_text', 'variation_of', 'life_modifier', 'hand_modifier',
       'content_warning', 'defense', 'card_faces', 'foil', 'nonfoil'
       , 'playable', 'color_identity']
df = df.drop(unneeded, axis=1)

# %% [markdown]
# now that I've cleaned out cards and columns that aren't needed, I need to figure out the best way to transform this data into something that the ML model can actually use.
#
# For instance, the "type_line" column will have to be split up into various super and subtypes, probably using categorical encoding.

# %% [markdown]
# ### Type Labeling + Encoding

# %%
df["type_line"].describe() # has 4246 unique types currently
# Out:
# count       35098
# unique       3120
# top       Instant
# freq         3592
# Name: type_line, dtype: object

# %%
"""
df["creature_type"] = df["type_line"].apply(lambda x: x[10:] if "Creature" in x else "NaN")
df["planeswalker_type"] = df["type_line"].apply(lambda x: x[24:] if "Planeswalker" in x else "NaN")
df["kindred_type"] = df["type_line"].apply(lambda x: x.split()[-1] if "Kindred" in x or "Tribal" in x else "NaN")"""
# Found a better way!
# Out:
# '\ndf["creature_type"] = df["type_line"].apply(lambda x: x[10:] if "Creature" in x else "NaN")\ndf["planeswalker_type"] = df["type_line"].apply(lambda x: x[24:] if "Planeswalker" in x else "NaN")\ndf["kindred_type"] = df["type_line"].apply(lambda x: x.split()[-1] if "Kindred" in x or "Tribal" in x else "NaN")'

# %%
def filter_subtype(x):
    if "—" in x:
        ind = x.index("—")
        types = x[ind+1:].split()
        return types
    else:
        return []

# %%
def filter_maintype(x):
    types = ["Artifact", "Land", 
             #"Battle", 
             "Creature", "Enchantment", "Planeswalker", "Instant", "Sorcery"]
    cur = []
    for type in types:
        if type in x:
            cur.append(type)
    return cur

# %%
df = df[~df['type_line'].str.contains('Basic')] # remove basic lands

# %%
df["legendary"] = df["type_line"].apply(lambda x: 1 if "Legendary" in x else 0)
df["subtype"] = df["type_line"].apply(filter_subtype)
df["main_type"]=df["type_line"].apply(filter_maintype)

# %%
df["price"] = df["prices"].str["usd"].astype(float) 
df = df.drop("prices", axis=1)

# %%
df = df.dropna(subset=["price"])
df = df[df["main_type"].map(len)>0]  # had to filter out bad cards with other types such as conspiracies and stickers

# %%
#le = LabelEncoder()
#le.fit(["Artifact", "Land", "Battle", "Creature", "Enchantment", "Planeswalker", "Instant", "Sorcery"])

# %%
#df["main_type"] = df["main_type"].apply(lambda x: le.transform(x))

# %% [markdown]
# #### Changed to One-Hot Encoding!

# %%
from sklearn.preprocessing import MultiLabelBinarizer

# %%
mlb = MultiLabelBinarizer()

# %%
test = pd.DataFrame(mlb.fit_transform(df["main_type"]), columns=mlb.classes_, index=df.index)

# %%
df = df.drop('main_type', axis=1)
df = df.join(test)

# %%
le2 = LabelEncoder()

# %%
df["subtype"].values
# Out:
# array([list(['Sliver']), list(['Kor', 'Soldier']),
#        list(['Siren', 'Pirate']), ..., list([]),
#        list(['Faerie', 'Rogue']), list(['Vampire', 'Soldier'])],
#       dtype=object)

# %%
subtypes = []
for unique in df["subtype"].values:
    if unique != []:
        for val in unique:
            if val not in subtypes:
                subtypes.append(val)

le2.fit(subtypes)
# Out:
# LabelEncoder()

# %%
df["subtype"] = df["subtype"].apply(lambda x: le2.transform(x)) # slow, probably better way to do this

# %%
df = df.drop("type_line", axis=1)

# %% [markdown]
# ### Date -> Year

# %%
df["year"] = df["released_at"].apply(lambda x: x.year)
df = df.drop("released_at", axis=1)

# %% [markdown]
# ### Mana Cost Breakdown
#
# - Number of Pips
# - Is X spell?

# %%
df["is_x"] = df["mana_cost"].apply(lambda x: 1 if r"{X}" in x else 0)
#df.loc[df["is_x"] == 1]

# %%
#print("{1}{W/R}{G}{G}".replace("{", "").replace("}", " ").split())  ->  df

def pip_counter(x):
    new = x.replace("{", "").replace("}", " ").split()
    count = 0
    for x in new:
        if x.isdigit() == False and x != "X":
            count += 1

    return count

# %%
df["pip_count"] = df["mana_cost"].apply(pip_counter)
df = df.drop("mana_cost", axis=1)
#df.sort_values(by="pip_count", ascending=False)

# %% [markdown]
# ### Oracle Text Breakdown -> NLP ? Or can try a parsing method to turn text into columns
#
# - activated ability?
# - etb effect?

# %%
df["oracle_text"] = df["oracle_text"].apply(lambda x: x.lower().replace("\n", ". "))

# %% [markdown]
# #### Main Phrases

# %% [markdown]
# using vectorizer to figure out most common substrings

# %%
vectorizer = CountVectorizer(ngram_range=(4, 7), lowercase=True, stop_words=None)

# %%
X = vectorizer.fit_transform(df["oracle_text"])

# %%
sum_words = X.sum(axis=0)
word_freq = [(word, sum_words[0, idx]) for word, idx in vectorizer.vocabulary_.items()]
word_freq = sorted(word_freq, key=lambda x: x[1], reverse=True)

# %%
common_phrases = pd.DataFrame(word_freq, columns=['phrase', 'count'])
common_phrases.iloc[:10]
# Out:
#                        phrase  count
# 0           until end of turn   5990
# 1         at the beginning of   3261
# 2   when this creature enters   3049
# 3           gets until end of   2131
# 4      gets until end of turn   2130
# 5       the beginning of your   1869
# 6    at the beginning of your   1814
# 7    card from your graveyard   1593
# 8     creature gets until end   1570
# 9  creature gets until end of   1570

# %%
"""
PHRASES = { # starter phrases
    r"when.*enters": "etb",
    r"until end of turn": "eot",
    r"beginning of .* upkeep": "b_o_u",
    r"search .* library": "tutor",
    r"without paying": "free",
    r"whenever .* attacks": "a_t",
    r"deals combat damage": "c_d_t",
    r"look at the tzo.*p": "s_s_t",
    r"return.*graveyard.*battlefield": "reanimate",
    r"when.*(this|a).*dies": "o_d_t",
    r"when.*(this|a).*leaves.": "l_b_t",
}"""
# Out:
# '\nPHRASES = { # starter phrases\n    r"when.*enters": "etb",\n    r"until end of turn": "eot",\n    r"beginning of .* upkeep": "b_o_u",\n    r"search .* library": "tutor",\n    r"without paying": "free",\n    r"whenever .* attacks": "a_t",\n    r"deals combat damage": "c_d_t",\n    r"look at the tzo.*p": "s_s_t",\n    r"return.*graveyard.*battlefield": "reanimate",\n    r"when.*(this|a).*dies": "o_d_t",\n    r"when.*(this|a).*leaves.": "l_b_t",\n}'

# %%
#def canonicalize_text(str):
#    for phr, rep in PHRASES.items():
#        if re.search(phr, str) != None:
#            str = re.sub(phr, rep, str)
#    return str

# %%
#df["oracle_text"] = df["oracle_text"].apply(canonicalize_text)

# %%
def extract_math_expression_with_variables(input_string):
  pattern = r'[\d\s.+\-*/()a-zA-Z]'  # Matches digits, dot, plus, minus, asterisk, slash, parentheses, and letters
  
  # Use re.findall() to find all non-overlapping matches of the pattern
  matches = re.findall(pattern, input_string)
  
  # Join the matched characters back into a string
  return "".join(matches)

# %%
df["oracle_text"] = df["oracle_text"].apply(lambda x: extract_math_expression_with_variables(x))
df
# Out:
#                        name  cmc  \
# 1               Fury Sliver  6.0
# 2             Kor Outfitter  2.0
# 4             Siren Lookout  3.0
# 7       Surge of Brilliance  2.0
# 9          Venerable Knight  1.0
# ...                     ...  ...
# 108944      Morkrut Banshee  5.0
# 108947   Deeproot Historian  4.0
# 108949  Aggressive Biomancy  2.0
# 108952  Faerie Bladecrafter  3.0
# 108953  Exultant Skymarcher  3.0
#
#                                               oracle_text  colors  \
# 1                all sliver creatures have double strike.     [R]
# 2       when this creature enters you may attach targe...     [W]
# 4       flying. when this creature enters it explores....     [U]
# 7       paradox  draw a card for each spell youve cast...     [U]
# 9       when this creature dies put a +1/+1 counter on...     [W]
# ...                                                   ...     ...
# 108944  morbid  when this creature enters if a creatur...     [B]
# 108947  merfolk and druid cards in your graveyard have...     [G]
# 108949  create x tokens that are copies of target crea...  [G, U]
# 108952  flying. whenever one or more faeries you contr...     [B]
# 108953                                             flying     [W]
#
#                    keywords produced_mana    rarity power toughness  \
# 1                        []           NaN  uncommon     3         3
# 2                        []           NaN    common     2         2
# 4         [Flying, Explore]           NaN    common     1         2
# 7       [Paradox, Foretell]           NaN  uncommon   NaN       NaN
# 9                        []           NaN  uncommon     2         1
# ...                     ...           ...       ...   ...       ...
# 108944             [Morbid]           NaN  uncommon     4         4
# 108947                   []           NaN      rare     3         3
# 108949              [Fight]           NaN      rare   NaN       NaN
# 108952             [Flying]           NaN      rare     2         2
# 108953             [Flying]           NaN    common     2         3
#
#         legendary  ... Artifact  Creature  Enchantment  Instant  Land  \
# 1               0  ...        0         1            0        0     0
# 2               0  ...        0         1            0        0     0
# 4               0  ...        0         1            0        0     0
# 7               0  ...        0         0            0        1     0
# 9               0  ...        0         1            0        0     0
# ...           ...  ...      ...       ...          ...      ...   ...
# 108944          0  ...        0         1            0        0     0
# 108947          0  ...        0         1            0        0     0
# 108949          0  ...        0         0            0        0     0
# 108952          0  ...        0         1            0        0     0
# 108953          0  ...        0         1            0        0     0
#
#         Planeswalker  Sorcery  year  is_x  pip_count
# 1                  0        0  2006     0          1
# 2                  0        0  2009     0          2
# 4                  0        0  2017     0          1
# 7                  0        0  2023     0          1
# 9                  0        0  2019     0          1
# ...              ...      ...   ...   ...        ...
# 108944             0        0  2011     0          2
# 108947             0        0  2023     0          1
# 108949             0        1  2024     1          2
# 108952             0        0  2023     0          1
# 108953             0        0  2018     0          2
#
# [32279 rows x 22 columns]

# %%
text_vectorizer = TextVectorization(
    max_tokens=4000, # increased vocab size
    output_mode='int',
    ngrams = (2,6),
    encoding='utf-8'
)

# %%
text_vectorizer.adapt(df["oracle_text"])

# %% [markdown]
# ### Rarity Encoding

# %%
df["rarity"].value_counts()
# Out:
# rarity
# rare        11445
# common       9878
# uncommon     8967
# mythic       1987
# special         2
# Name: count, dtype: int64

# %%
df["rarity"] = df["rarity"].apply(lambda x: "common" if x == "special" else x) # the two special cards have common rarity on scryfall

# %%
def rarity_encoding(x):
    if x == "common":
        return 0
    elif x == "uncommon":
        return 1
    elif x == "rare":
        return 2
    else:
        return 3

# %%
df["rarity"] = df["rarity"].apply(lambda x: rarity_encoding(x))

# %% [markdown]
# ### Keyword Encoding

# %%
keywrd_encoder = LabelEncoder()

# %%
keywords = [] # taking code from earlier
for unique in df["keywords"].values:
    if unique != []:
        for val in unique:
            if val not in keywords:
                keywords.append(val)

keywrd_encoder.fit(keywords)
# Out:
# LabelEncoder()

# %%
len(keywords)
# Out:
# 604

# %%
df["keywords"] = df["keywords"].apply(lambda x: keywrd_encoder.transform(x))

# %% [markdown]
# ### Color Identity Encoding (one more time!)
#
# definitely could've done a for loop for each column i wanted to encode but oh well it's a little late for that

# %%
df
# Out:
#                        name  cmc  \
# 1               Fury Sliver  6.0
# 2             Kor Outfitter  2.0
# 4             Siren Lookout  3.0
# 7       Surge of Brilliance  2.0
# 9          Venerable Knight  1.0
# ...                     ...  ...
# 108944      Morkrut Banshee  5.0
# 108947   Deeproot Historian  4.0
# 108949  Aggressive Biomancy  2.0
# 108952  Faerie Bladecrafter  3.0
# 108953  Exultant Skymarcher  3.0
#
#                                               oracle_text  colors    keywords  \
# 1                all sliver creatures have double strike.     [R]          []
# 2       when this creature enters you may attach targe...     [W]          []
# 4       flying. when this creature enters it explores....     [U]  [230, 198]
# 7       paradox  draw a card for each spell youve cast...     [U]  [390, 238]
# 9       when this creature dies put a +1/+1 counter on...     [W]          []
# ...                                                   ...     ...         ...
# 108944  morbid  when this creature enters if a creatur...     [B]       [366]
# 108947  merfolk and druid cards in your graveyard have...     [G]          []
# 108949  create x tokens that are copies of target crea...  [G, U]       [215]
# 108952  flying. whenever one or more faeries you contr...     [B]       [230]
# 108953                                             flying     [W]       [230]
#
#        produced_mana  rarity power toughness  legendary  ... Artifact  \
# 1                NaN       1     3         3          0  ...        0
# 2                NaN       0     2         2          0  ...        0
# 4                NaN       0     1         2          0  ...        0
# 7                NaN       1   NaN       NaN          0  ...        0
# 9                NaN       1     2         1          0  ...        0
# ...              ...     ...   ...       ...        ...  ...      ...
# 108944           NaN       1     4         4          0  ...        0
# 108947           NaN       2     3         3          0  ...        0
# 108949           NaN       2   NaN       NaN          0  ...        0
# 108952           NaN       2     2         2          0  ...        0
# 108953           NaN       0     2         3          0  ...        0
#
#         Creature  Enchantment  Instant  Land  Planeswalker  Sorcery  year  \
# 1              1            0        0     0             0        0  2006
# 2              1            0        0     0             0        0  2009
# 4              1            0        0     0             0        0  2017
# 7              0            0        1     0             0        0  2023
# 9              1            0        0     0             0        0  2019
# ...          ...          ...      ...   ...           ...      ...   ...
# 108944         1            0        0     0             0        0  2011
# 108947         1            0        0     0             0        0  2023
# 108949         0            0        0     0             0        1  2024
# 108952         1            0        0     0             0        0  2023
# 108953         1            0        0     0             0        0  2018
#
#         is_x  pip_count
# 1          0          1
# 2          0          2
# 4          0          1
# 7          0          1
# 9          0          1
# ...      ...        ...
# 108944     0          2
# 108947     0          1
# 108949     1          2
# 108952     0          1
# 108953     0          2
#
# [32279 rows x 22 columns]

# %%
c_i = LabelEncoder()

# %%
c_i.fit(["W", "G", "R", "B", "U"])
# Out:
# LabelEncoder()

# %%
c_i.transform(["W", "U"])
# Out:
# array([4, 3])

# %%
df["colors"] = df["colors"].apply(lambda x: c_i.transform(x))

# %% [markdown]
# ### Produced Mana
#
# changing this to binary value if it does(n't)

# %%
df["produced_mana"] = df["produced_mana"].replace(pd.NA, 0)

# %%
df["produced_mana"] = df["produced_mana"].apply(lambda x: 1 if x != 0 else x)

# %% [markdown]
# ### Final Step: Replace Power/Toughness NaN with -1

# %%
df["power"] = pd.to_numeric(df["power"], errors="coerce").fillna(-1)
df["toughness"] = pd.to_numeric(df["toughness"], errors="coerce").fillna(-1)

# %% [markdown]
# ### Final Data Filtering

# %%
df = df.loc[(df["price"] <= 500) & (df["price"] >= 0.10) & (df["year"] >= 2000)] # filter out cards that are too expensive or too cheap

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#                        name  cmc  \
# 0               Fury Sliver  6.0
# 1             Kor Outfitter  2.0
# 2       Surge of Brilliance  2.0
# 3          Venerable Knight  1.0
# 4            Wall of Vipers  3.0
# ...                     ...  ...
# 19842  White Sun's Twilight  2.0
# 19843     Tezzeret's Gambit  4.0
# 19844    Deeproot Historian  4.0
# 19845   Aggressive Biomancy  2.0
# 19846   Faerie Bladecrafter  3.0
#
#                                              oracle_text  colors    keywords  \
# 0               all sliver creatures have double strike.     [2]          []
# 1      when this creature enters you may attach targe...     [4]          []
# 2      paradox  draw a card for each spell youve cast...     [3]  [390, 238]
# 3      when this creature dies put a +1/+1 counter on...     [4]          []
# 4      defender (this creature cant attack.). 3 destr...     [0]       [139]
# ...                                                  ...     ...         ...
# 19842  you gain x life. create x 1/1 colorless phyrex...     [4]          []
# 19843  (u/p can be paid with either u or 2 life.). dr...     [3]       [415]
# 19844  merfolk and druid cards in your graveyard have...     [1]          []
# 19845  create x tokens that are copies of target crea...  [1, 3]       [215]
# 19846  flying. whenever one or more faeries you contr...     [0]       [230]
#
#        produced_mana  rarity  power  toughness  legendary  ... Artifact  \
# 0                  0       1    3.0        3.0          0  ...        0
# 1                  0       0    2.0        2.0          0  ...        0
# 2                  0       1   -1.0       -1.0          0  ...        0
# 3                  0       1    2.0        1.0          0  ...        0
# 4                  0       1    2.0        4.0          0  ...        0
# ...              ...     ...    ...        ...        ...  ...      ...
# 19842              0       2   -1.0       -1.0          0  ...        0
# 19843              0       1   -1.0       -1.0          0  ...        0
# 19844              0       2    3.0        3.0          0  ...        0
# 19845              0       2   -1.0       -1.0          0  ...        0
# 19846              0       2    2.0        2.0          0  ...        0
#
#        Creature  Enchantment  Instant  Land  Planeswalker  Sorcery  year  \
# 0             1            0        0     0             0        0  2006
# 1             1            0        0     0             0        0  2009
# 2             0            0        1     0             0        0  2023
# 3             1            0        0     0             0        0  2019
# 4             1            0        0     0             0        0  2000
# ...         ...          ...      ...   ...           ...      ...   ...
# 19842         0            0        0     0             0        1  2023
# 19843         0            0        0     0             0        1  2011
# 19844         1            0        0     0             0        0  2023
# 19845         0            0        0     0             0        1  2024
# 19846         1            0        0     0             0        0  2023
#
#        is_x  pip_count
# 0         0          1
# 1         0          2
# 2         0          1
# 3         0          1
# 4         0          1
# ...     ...        ...
# 19842     1          2
# 19843     0          1
# 19844     0          1
# 19845     1          2
# 19846     0          1
#
# [19847 rows x 22 columns]

# %% [markdown]
# ### Additional Rows Added Later

# %%
df["num_colors"] = df["colors"].apply(lambda x: len(x))
#df["num_keywords"] = df["keywords"].apply(lambda x: len(x))
#df["num_subtypes"] = df["subtype"].apply(lambda x: len(x))
#df["num_maintypes"] = df["main_type"].apply(lambda x: len(x))
df["oracle_length"] = df["oracle_text"].apply(lambda x: len(x))
df["length per cmc"] = df["oracle_length"]/df["cmc"]
df["length per cmc"] = df["length per cmc"].replace(np.inf, 0)
df["length per cmc"] = df["length per cmc"].replace(np.nan, 0)
# Out:
# C:\Users\bense\AppData\Local\Temp\ipykernel_33576\3765719277.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["num_colors"] = df["colors"].apply(lambda x: len(x))
# C:\Users\bense\AppData\Local\Temp\ipykernel_33576\3765719277.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["oracle_length"] = df["oracle_text"].apply(lambda x: len(x))
# C:\Users\bense\AppData\Local\Temp\ipykernel_33576\3765719277.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["length per cmc"] = df["oracle_length"]/df["cmc"]
# C:\Users\bense\AppData\Local\Temp\ipykernel_33576\3765719277.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["length per cmc"] = df["length per cmc"].replace(np.inf, 0)
# C:\Users\bense\AppData\Local\Temp\ipykernel_33576\3765719277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["length per cmc"] = df["length per cmc"].replace(np.nan, 0)

# %%
save(df)

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Numerical Data

# %%
numerical = df.drop(["name", "oracle_text", "colors", "keywords", "subtype", "price"], axis=1)

# %%
numerical.columns
# Out:
# Index(['cmc', 'produced_mana', 'rarity', 'power', 'toughness', 'legendary',
#        'Artifact', 'Creature', 'Enchantment', 'Instant', 'Land',
#        'Planeswalker', 'Sorcery', 'year', 'is_x', 'pip_count', 'num_colors',
#        'oracle_length', 'length per cmc'],
#       dtype='object')

# %%
scaler = RobustScaler()
scaled_data = scaler.fit_transform(numerical)

# %%
number_inputs = keras.Input(shape=(19,), name="numerical")
normalized = keras.layers.Normalization()(number_inputs)

# %% [markdown]
# ### Array Data

# %% [markdown]
# describing code below:
# have to pad all the array inputs, tell keras the shape of the input, and create an embedding layer to vectorize said input
#
# input_dim is equal to number of unique ids

# %%
colors_padded = keras.preprocessing.sequence.pad_sequences(df['colors'])
colors_input = keras.Input(shape=(5,), dtype="int32", name="colors")
colors_embed = keras.layers.Embedding(input_dim=5, output_dim=4)(colors_input)
colors_pooled = keras.layers.GlobalAveragePooling1D()(colors_embed)

keywords_padded = keras.preprocessing.sequence.pad_sequences(df['keywords'])
keywords_input = keras.Input(shape=(10,), dtype="int32", name="keywords")
keywords_embed = keras.layers.Embedding(input_dim=604, output_dim=8)(keywords_input)
keywords_pooled = keras.layers.GlobalAveragePooling1D()(keywords_embed)

subtypes_padded = keras.preprocessing.sequence.pad_sequences(df['subtype'])
subtypes_input = keras.Input(shape=(4,), dtype="int32", name="subtypes")
subtypes_embed = keras.layers.Embedding(input_dim=393, output_dim=8)(subtypes_input)
subtypes_pooled = keras.layers.GlobalAveragePooling1D()(subtypes_embed)

#main_type_padded = keras.preprocessing.sequence.pad_sequences(df['main_type'])
#main_type_input = keras.Input(shape=(2,), dtype="int32", name="main_type")
#main_type_embed = keras.layers.Embedding(input_dim=8, output_dim=4)(main_type_input)
#main_type_pooled = keras.layers.GlobalAveragePooling1D()(main_type_embed)

# %% [markdown]
# ### Tokenized Data

# %%
text_input = keras.Input(shape=(), dtype=tf.string, name="oracle_text")
oracle_vector = text_vectorizer(text_input)
oracle_embed = keras.layers.Embedding(input_dim=4000, output_dim=256)(oracle_vector)
oracle_pooled = keras.layers.GlobalAveragePooling1D()(oracle_embed)

# %%
#oracle_array = text_vectorizer(df["oracle_text"].values).numpy()

# %% [markdown]
# ### Model Compiling

# %%
all_inputs = [
    number_inputs,
    text_input,
    colors_input,
    keywords_input,
    subtypes_input,
    #main_type_input
]

all_features = keras.layers.concatenate([
    normalized,
    oracle_pooled,
    colors_pooled,
    keywords_pooled,
    subtypes_pooled,
    #main_type_pooled
])

# %%
x = keras.layers.Dense(64, activation="tanh")(all_features)
x = keras.layers.Normalization()(x)
x = keras.layers.Dense(32, activation="tanh")(x)
x = keras.layers.Normalization()(x)
x = keras.layers.Dense(16, activation="tanh")(x)
output = keras.layers.Dense(1, activation="linear", name="price")(x)

# %%
model = keras.Model(inputs=all_inputs, outputs=output)
model.compile(optimizer="adamax", loss=keras.losses.MeanSquaredError(), metrics=[keras.metrics.MeanAbsoluteError()])

# %%
early_stopping_cb = keras.callbacks.EarlyStopping(patience=25, start_from_epoch=20, monitor="val_loss", mode='min')
#model_checkpoint_cb = keras.callbacks.ModelCheckpoint(f"models\\best_model", save_best_only=True)
run_index = 1 # increment every time you train the model
run_logdir = os.path.join(os.curdir, "logs", "run_{:03d}".format(run_index))
tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)
callbacks = [early_stopping_cb, 
             #model_checkpoint_cb,
               tensorboard_cb]

# %%
model.fit(
    {
        "numerical": scaled_data,
        "oracle_text": df["oracle_text"].values,
        "keywords": keywords_padded,
        "colors": colors_padded,
        "subtypes": subtypes_padded,
        #"main_type": main_type_padded
    },
    y=df["price"],
    epochs=75, # long ahh runtime fr
    batch_size=32,
    validation_split=0.25,
    callbacks=callbacks
)
# Out:
# Epoch 1/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 22.1311 - mean_absolute_error: 1.8813 - val_loss: 22.8824 - val_mean_absolute_error: 1.9238
# Epoch 2/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 21.6031 - mean_absolute_error: 1.8190 - val_loss: 22.4618 - val_mean_absolute_error: 1.8023
# Epoch 3/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 21.1460 - mean_absolute_error: 1.7608 - val_loss: 22.2447 - val_mean_absolute_error: 1.8929
# Epoch 4/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 20.6726 - mean_absolute_error: 1.7192 - val_loss: 21.7112 - val_mean_absolute_error: 1.6848
# Epoch 5/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 20.1481 - mean_absolute_error: 1.6728 - val_loss: 21.4762 - val_mean_absolute_error: 1.7875
# Epoch 6/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 19.6678 - mean_absolute_error: 1.6337 - val_loss: 21.1239 - val_mean_absolute_error: 1.7497
# Epoch 7/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 19.1599 - mean_absolute_error: 1.6164 - val_loss: 20.8992 - val_mean_absolute_error: 1.5639
# Epoch 8/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 18.7494 - mean_absolute_error: 1.5794 - val_loss: 20.5135 - val_mean_absolute_error: 1.6118
# Epoch 9/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 18.2599 - mean_absolute_error: 1.5524 - val_loss: 20.5156 - val_mean_absolute_error: 1.7480
# Epoch 10/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 17.8868 - mean_absolute_error: 1.5238 - val_loss: 20.0711 - val_mean_absolute_error: 1.5541
# Epoch 11/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 17.4694 - mean_absolute_error: 1.5033 - val_loss: 20.0763 - val_mean_absolute_error: 1.7274
# Epoch 12/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 17.1841 - mean_absolute_error: 1.4875 - val_loss: 19.7605 - val_mean_absolute_error: 1.6711
# Epoch 13/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 16.8163 - mean_absolute_error: 1.4650 - val_loss: 19.5571 - val_mean_absolute_error: 1.6488
# Epoch 14/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 16.4304 - mean_absolute_error: 1.4481 - val_loss: 19.2777 - val_mean_absolute_error: 1.5863
# Epoch 15/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 16.1416 - mean_absolute_error: 1.4182 - val_loss: 19.1557 - val_mean_absolute_error: 1.5567
# Epoch 16/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 15.8994 - mean_absolute_error: 1.4196 - val_loss: 19.0579 - val_mean_absolute_error: 1.5836
# Epoch 17/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 15.5404 - mean_absolute_error: 1.3917 - val_loss: 19.7091 - val_mean_absolute_error: 1.7971
# Epoch 18/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 15.2622 - mean_absolute_error: 1.3828 - val_loss: 20.2158 - val_mean_absolute_error: 1.8612
# Epoch 19/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 15.0050 - mean_absolute_error: 1.3615 - val_loss: 18.5901 - val_mean_absolute_error: 1.4840
# Epoch 20/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 14.8439 - mean_absolute_error: 1.3616 - val_loss: 19.3300 - val_mean_absolute_error: 1.7624
# Epoch 21/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 14.5042 - mean_absolute_error: 1.3316 - val_loss: 18.5010 - val_mean_absolute_error: 1.5623
# Epoch 22/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 14.3838 - mean_absolute_error: 1.3349 - val_loss: 19.8845 - val_mean_absolute_error: 1.8362
# Epoch 23/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 14.1217 - mean_absolute_error: 1.3194 - val_loss: 18.2336 - val_mean_absolute_error: 1.5263
# Epoch 24/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 13.8732 - mean_absolute_error: 1.3043 - val_loss: 18.6019 - val_mean_absolute_error: 1.6421
# Epoch 25/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 13.7210 - mean_absolute_error: 1.3000 - val_loss: 18.2413 - val_mean_absolute_error: 1.5137
# Epoch 26/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 13.5039 - mean_absolute_error: 1.2958 - val_loss: 18.2995 - val_mean_absolute_error: 1.5378
# Epoch 27/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 13.3340 - mean_absolute_error: 1.2799 - val_loss: 18.4195 - val_mean_absolute_error: 1.6442
# Epoch 28/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 13.0384 - mean_absolute_error: 1.2678 - val_loss: 19.0803 - val_mean_absolute_error: 1.7395
# Epoch 29/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 12.9985 - mean_absolute_error: 1.2607 - val_loss: 17.9041 - val_mean_absolute_error: 1.5285
# Epoch 30/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 12.6415 - mean_absolute_error: 1.2379 - val_loss: 18.9238 - val_mean_absolute_error: 1.7040
# Epoch 31/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 12.5103 - mean_absolute_error: 1.2344 - val_loss: 17.7155 - val_mean_absolute_error: 1.4798
# Epoch 32/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 12.5066 - mean_absolute_error: 1.2431 - val_loss: 19.8270 - val_mean_absolute_error: 1.8315
# Epoch 33/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 12.2685 - mean_absolute_error: 1.2226 - val_loss: 18.2534 - val_mean_absolute_error: 1.6314
# Epoch 34/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 11.9876 - mean_absolute_error: 1.2051 - val_loss: 17.5177 - val_mean_absolute_error: 1.4893
# Epoch 35/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 11.8581 - mean_absolute_error: 1.2000 - val_loss: 18.4045 - val_mean_absolute_error: 1.6740
# Epoch 36/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 11.8413 - mean_absolute_error: 1.2050 - val_loss: 17.2754 - val_mean_absolute_error: 1.4957
# Epoch 37/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 11.6234 - mean_absolute_error: 1.1938 - val_loss: 17.5475 - val_mean_absolute_error: 1.5273
# Epoch 38/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 11.5918 - mean_absolute_error: 1.1968 - val_loss: 17.2804 - val_mean_absolute_error: 1.4290
# Epoch 39/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 11.4294 - mean_absolute_error: 1.1835 - val_loss: 17.9939 - val_mean_absolute_error: 1.6373
# Epoch 40/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 11.2521 - mean_absolute_error: 1.1839 - val_loss: 17.4662 - val_mean_absolute_error: 1.5235
# Epoch 41/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 11.0569 - mean_absolute_error: 1.1643 - val_loss: 17.5352 - val_mean_absolute_error: 1.5269
# Epoch 42/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 11.0290 - mean_absolute_error: 1.1648 - val_loss: 18.7362 - val_mean_absolute_error: 1.6903
# Epoch 43/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 10.9146 - mean_absolute_error: 1.1601 - val_loss: 18.1080 - val_mean_absolute_error: 1.6203
# Epoch 44/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 10.7589 - mean_absolute_error: 1.1525 - val_loss: 18.0302 - val_mean_absolute_error: 1.5891
# Epoch 45/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 10.6215 - mean_absolute_error: 1.1436 - val_loss: 17.8086 - val_mean_absolute_error: 1.5721
# Epoch 46/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 10.6025 - mean_absolute_error: 1.1537 - val_loss: 17.3131 - val_mean_absolute_error: 1.4858
# Epoch 47/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 10.4200 - mean_absolute_error: 1.1368 - val_loss: 17.6098 - val_mean_absolute_error: 1.5514
# Epoch 48/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 10.3106 - mean_absolute_error: 1.1243 - val_loss: 17.8642 - val_mean_absolute_error: 1.5738
# Epoch 49/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 10.3137 - mean_absolute_error: 1.1331 - val_loss: 17.2819 - val_mean_absolute_error: 1.5451
# Epoch 50/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 10.1441 - mean_absolute_error: 1.1233 - val_loss: 17.9990 - val_mean_absolute_error: 1.5614
# Epoch 51/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 10.1620 - mean_absolute_error: 1.1285 - val_loss: 18.1885 - val_mean_absolute_error: 1.6336
# Epoch 52/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 9.9233 - mean_absolute_error: 1.1136 - val_loss: 17.0507 - val_mean_absolute_error: 1.4271
# Epoch 53/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 9.9151 - mean_absolute_error: 1.1139 - val_loss: 16.9311 - val_mean_absolute_error: 1.4514
# Epoch 54/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 9.8523 - mean_absolute_error: 1.1087 - val_loss: 17.7916 - val_mean_absolute_error: 1.5743
# Epoch 55/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 9.6762 - mean_absolute_error: 1.0938 - val_loss: 17.0147 - val_mean_absolute_error: 1.4830
# Epoch 56/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 9.6338 - mean_absolute_error: 1.0917 - val_loss: 18.7115 - val_mean_absolute_error: 1.6760
# Epoch 57/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 9.5942 - mean_absolute_error: 1.0870 - val_loss: 17.3406 - val_mean_absolute_error: 1.4691
# Epoch 58/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 9.5194 - mean_absolute_error: 1.0882 - val_loss: 17.9012 - val_mean_absolute_error: 1.5746
# Epoch 59/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 9.4072 - mean_absolute_error: 1.0773 - val_loss: 17.5596 - val_mean_absolute_error: 1.5662
# Epoch 60/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 9.2871 - mean_absolute_error: 1.0786 - val_loss: 17.3009 - val_mean_absolute_error: 1.4853
# Epoch 61/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 9.2720 - mean_absolute_error: 1.0753 - val_loss: 17.1636 - val_mean_absolute_error: 1.4792
# Epoch 62/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 9.3907 - mean_absolute_error: 1.0978 - val_loss: 17.1123 - val_mean_absolute_error: 1.4699
# Epoch 63/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 9.1347 - mean_absolute_error: 1.0723 - val_loss: 17.9823 - val_mean_absolute_error: 1.5574
# Epoch 64/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 9.0292 - mean_absolute_error: 1.0602 - val_loss: 18.0967 - val_mean_absolute_error: 1.5601
# Epoch 65/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 9.0296 - mean_absolute_error: 1.0702 - val_loss: 18.1317 - val_mean_absolute_error: 1.5747
# Epoch 66/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 8.8617 - mean_absolute_error: 1.0531 - val_loss: 17.9548 - val_mean_absolute_error: 1.5364
# Epoch 67/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 8.7251 - mean_absolute_error: 1.0469 - val_loss: 17.5380 - val_mean_absolute_error: 1.4895
# Epoch 68/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 8.7992 - mean_absolute_error: 1.0550 - val_loss: 17.3493 - val_mean_absolute_error: 1.4899
# Epoch 69/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 8.7068 - mean_absolute_error: 1.0403 - val_loss: 17.3655 - val_mean_absolute_error: 1.4804
# Epoch 70/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 8.6171 - mean_absolute_error: 1.0389 - val_loss: 17.4379 - val_mean_absolute_error: 1.4724
# Epoch 71/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 8.4653 - mean_absolute_error: 1.0263 - val_loss: 17.8917 - val_mean_absolute_error: 1.5331
# Epoch 72/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 8.5305 - mean_absolute_error: 1.0283 - val_loss: 19.9631 - val_mean_absolute_error: 1.7071
# Epoch 73/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 8.4615 - mean_absolute_error: 1.0368 - val_loss: 17.5693 - val_mean_absolute_error: 1.5096
# Epoch 74/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 8.3392 - mean_absolute_error: 1.0260 - val_loss: 17.8151 - val_mean_absolute_error: 1.5234
# Epoch 75/75
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 8.3378 - mean_absolute_error: 1.0242 - val_loss: 17.9301 - val_mean_absolute_error: 1.5656

# %% [markdown]
# #### Initial Results:
#
# Mean Absolute Error: 1.03
#
# Rerun With One-Hot Encoding: literally the same (1.025)

# %%
model.save("models\\best_model.keras")

# %%
text_vectorizer.save_assets("models\\text_vectorizer")

# %% [markdown]
# ## Model Improvement

# %%
model2 = keras.models.load_model(
    "models\\best_model.keras",
    custom_objects={
        "TextVectorization": TextVectorization,
    }
)

# %%
len(scaled_data)
# Out:
# 19847

# %%
model2.evaluate({
        "numerical": scaled_data[18000:],
        "oracle_text": df["oracle_text"].values[18000:],
        "keywords": keywords_padded[18000:],
        "colors": colors_padded[18000:],
        "subtypes": subtypes_padded[18000:],
        #"main_type": main_type_padded
    },
    y=df["price"][18000:])
# Out:
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.0292 - mean_absolute_error: 1.5781
# [18.029186248779297, 1.5780930519104004]

# %%
df = load()

# %%
df.iloc[2021]
# Out:
# name                                                Boon Reflection
# cmc                                                             5.0
# oracle_text       if you would gain life you gain twice that muc...
# colors                                                          [4]
# keywords                                                         []
# produced_mana                                                     0
# rarity                                                            2
# power                                                          -1.0
# toughness                                                      -1.0
# legendary                                                         0
# subtype                                                          []
# price                                                         11.04
# Artifact                                                          0
# Creature                                                          0
# Enchantment                                                       1
# Instant                                                           0
# Land                                                              0
# Planeswalker                                                      0
# Sorcery                                                           0
# year                                                           2008
# is_x                                                              0
# pip_count                                                         1
# num_colors                                                        1
# oracle_length                                                    61
# length per cmc                                                 12.2
# Name: 2021, dtype: object

# %%
model2.predict({
    "numerical": scaled_data[2021:2022],
    "oracle_text": np.array([df["oracle_text"].values[2021]], dtype=object),
    "keywords": np.array([keywords_padded[2021]]),
    "colors": np.array([colors_padded[2021]]),
    "subtypes": np.array([subtypes_padded[2021]]),
})
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# array([[25.963308]], dtype=float32)

# %%
numerical["price"] = df["price"]

# %%
numerical.corr().sort_values(by="price", ascending=False)["price"]
# Out:
# price             1.000000
# rarity            0.258572
# legendary         0.117534
# Land              0.093359
# produced_mana     0.083089
# Artifact          0.058638
# oracle_length     0.050182
# Planeswalker      0.039558
# year              0.037574
# cmc               0.026806
# toughness         0.012695
# power             0.009655
# Enchantment       0.003491
# is_x             -0.007006
# length per cmc   -0.021276
# pip_count        -0.029423
# Creature         -0.035072
# Instant          -0.036775
# Sorcery          -0.040772
# num_colors       -0.067478
# Name: price, dtype: float64

# %% [markdown]
# Might have to drop everything below cmc unless i can figure out a way to make power and toughness more relevant

# %% [markdown]
# ### Changes:
#
# 1. Changed activation function on dense layers from relu -> tanh
# 2. tried adding new columns (num_subtypes, num_keywords) and removed them because low correlation
# 3. Added oracle_length/cmc to try and show that low cmc cards are often better and can be evaluated higher?
# 4. Changed optimizer from adam to adamax
# 5. Removed non-mathematic symbols from oracle_text
# 6. Changed main_type array column to one-hot encoded columns

# %% [markdown]
# #### Thinking of things:
#
# - Drop categories with poor correlation
# - Better categories? (Pow + Tough?)

# %% [markdown]
# ####  For Loop Running

# %%
x_train = {
        "numerical": scaled_data[:16000],
        "oracle_text": df["oracle_text"].values[:16000],
        "keywords": keywords_padded[:16000],
        "colors": colors_padded[:16000],
        "subtypes": subtypes_padded[:16000],
        #"main_type": main_type_padded
    }
y_train = df["price"][:16000]
x_test = {
        "numerical": scaled_data[16000:],
        "oracle_text": df["oracle_text"].values[16000:],
        "keywords": keywords_padded[16000:],
        "colors": colors_padded[16000:],
        "subtypes": subtypes_padded[16000:],
        #"main_type": main_type_padded
    }
y_test = df["price"][16000:]

# %%
def buildModel(testing):
    num_nrns = testing[0]
    activation = testing[1]
    batch_size = testing[2]
    if_drop = testing[3]
    optimizer = testing[4]
    x = keras.layers.Dense(num_nrns[0], activation=activation)(all_features)
    if if_drop[0]:
        x = keras.layers.Dropout(rate=if_drop[1])(all_features)
    for num in num_nrns[1:]:
        x = keras.layers.Dense(num, activation=activation)(x)
        x = keras.layers.Normalization()(x)
    output = keras.layers.Dense(1, activation="linear", name="price")(x)

    model = keras.Model(inputs=all_inputs, outputs=output)
    model.compile(optimizer=optimizer, loss=keras.losses.MeanSquaredError(), metrics=[keras.metrics.MeanAbsoluteError()])

    model.fit(x_train, y_train,
    epochs=testing[5],
    batch_size=batch_size,
    validation_split=0.25)
    return model.evaluate(x_test, y_test)

# %%
bad_grid_search = [[[64, 32, 16], "tanh", 32, [False], "adamax", 20], # base model
         [[64, 32, 16], "tanh", 64, [False], "adamax", 20],
         [[64, 32, 16], "tanh", 128, [False], "adamax",20],
         [[64, 32, 16], "relu", 32, [False], "adamax",20],
         [[256, 128, 64, 32, 16], "tanh", 32, [False], "adamax",20],
         [[128, 64, 32, 16, 8], "tanh", 32, [False], "adamax",20],
         [[64, 32, 16], "tanh", 32, [True, 0.2], "adamax",20],
         [[64, 32, 16], "tanh", 32, [True, 0.3], "adamax",20]
    ]

# %%
scores = []
for tests in enumerate(bad_grid_search):
    result = buildModel(tests)
    scores.append([tests,result])
# Out:
# Epoch 1/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 24.0013 - mean_absolute_error: 1.9356 - val_loss: 18.3057 - val_mean_absolute_error: 1.9015
# Epoch 2/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 21.8360 - mean_absolute_error: 1.8075 - val_loss: 17.5055 - val_mean_absolute_error: 1.7694
# Epoch 3/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 20.3591 - mean_absolute_error: 1.6278 - val_loss: 16.8571 - val_mean_absolute_error: 1.7007
# Epoch 4/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 19.2827 - mean_absolute_error: 1.4722 - val_loss: 16.6060 - val_mean_absolute_error: 1.6867
# Epoch 5/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 18.4677 - mean_absolute_error: 1.3988 - val_loss: 16.3400 - val_mean_absolute_error: 1.5373
# Epoch 6/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 17.7091 - mean_absolute_error: 1.3484 - val_loss: 16.1242 - val_mean_absolute_error: 1.4763
# Epoch 7/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 17.0043 - mean_absolute_error: 1.3083 - val_loss: 16.1199 - val_mean_absolute_error: 1.4318
# Epoch 8/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 16.4499 - mean_absolute_error: 1.2739 - val_loss: 15.9684 - val_mean_absolute_error: 1.5023
# Epoch 9/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 15.9882 - mean_absolute_error: 1.2538 - val_loss: 15.9835 - val_mean_absolute_error: 1.5272
# Epoch 10/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 15.6131 - mean_absolute_error: 1.2354 - val_loss: 16.1389 - val_mean_absolute_error: 1.5832
# Epoch 11/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 15.3342 - mean_absolute_error: 1.2260 - val_loss: 15.9220 - val_mean_absolute_error: 1.4492
# Epoch 12/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 14.9610 - mean_absolute_error: 1.2008 - val_loss: 15.9140 - val_mean_absolute_error: 1.4657
# Epoch 13/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 14.6989 - mean_absolute_error: 1.1957 - val_loss: 15.9436 - val_mean_absolute_error: 1.5112
# Epoch 14/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 14.5109 - mean_absolute_error: 1.1841 - val_loss: 16.1759 - val_mean_absolute_error: 1.5629
# Epoch 15/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 14.2788 - mean_absolute_error: 1.1745 - val_loss: 16.0801 - val_mean_absolute_error: 1.5499
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.2657 - mean_absolute_error: 1.6448
# Epoch 1/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 24.4280 - mean_absolute_error: 1.9643 - val_loss: 18.6151 - val_mean_absolute_error: 1.8562
# Epoch 2/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 22.3697 - mean_absolute_error: 1.8127 - val_loss: 17.8089 - val_mean_absolute_error: 1.7542
# Epoch 3/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 21.1732 - mean_absolute_error: 1.6613 - val_loss: 17.3110 - val_mean_absolute_error: 1.6762
# Epoch 4/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 20.2354 - mean_absolute_error: 1.5345 - val_loss: 16.9529 - val_mean_absolute_error: 1.5613
# Epoch 5/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 19.4143 - mean_absolute_error: 1.4426 - val_loss: 16.7036 - val_mean_absolute_error: 1.4981
# Epoch 6/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 18.7290 - mean_absolute_error: 1.3798 - val_loss: 16.4713 - val_mean_absolute_error: 1.5192
# Epoch 7/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 18.1319 - mean_absolute_error: 1.3336 - val_loss: 16.2940 - val_mean_absolute_error: 1.5005
# Epoch 8/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 17.5787 - mean_absolute_error: 1.3041 - val_loss: 16.2241 - val_mean_absolute_error: 1.5408
# Epoch 9/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 17.0004 - mean_absolute_error: 1.2678 - val_loss: 16.0474 - val_mean_absolute_error: 1.4411
# Epoch 10/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 16.5726 - mean_absolute_error: 1.2523 - val_loss: 15.9529 - val_mean_absolute_error: 1.4701
# Epoch 11/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 16.0821 - mean_absolute_error: 1.2299 - val_loss: 15.8711 - val_mean_absolute_error: 1.4977
# Epoch 12/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 15.7745 - mean_absolute_error: 1.2240 - val_loss: 15.9046 - val_mean_absolute_error: 1.4932
# Epoch 13/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 15.4014 - mean_absolute_error: 1.2023 - val_loss: 15.9100 - val_mean_absolute_error: 1.5081
# Epoch 14/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 15.1419 - mean_absolute_error: 1.1889 - val_loss: 16.0225 - val_mean_absolute_error: 1.5642
# Epoch 15/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 14.8385 - mean_absolute_error: 1.1873 - val_loss: 15.9678 - val_mean_absolute_error: 1.4981
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.5150 - mean_absolute_error: 1.5951
# Epoch 1/15
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 25.3167 - mean_absolute_error: 2.0445 - val_loss: 19.3519 - val_mean_absolute_error: 1.8980
# Epoch 2/15
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 23.4027 - mean_absolute_error: 1.9025 - val_loss: 18.4043 - val_mean_absolute_error: 1.8358
# Epoch 3/15
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 22.1660 - mean_absolute_error: 1.8148 - val_loss: 17.7569 - val_mean_absolute_error: 1.7995
# Epoch 4/15
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 21.0977 - mean_absolute_error: 1.7056 - val_loss: 17.2669 - val_mean_absolute_error: 1.7188
# Epoch 5/15
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 20.2040 - mean_absolute_error: 1.5936 - val_loss: 16.8969 - val_mean_absolute_error: 1.6201
# Epoch 6/15
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 19.3981 - mean_absolute_error: 1.4860 - val_loss: 16.6453 - val_mean_absolute_error: 1.5583
# Epoch 7/15
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 18.7058 - mean_absolute_error: 1.4082 - val_loss: 16.4524 - val_mean_absolute_error: 1.5342
# Epoch 8/15
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 18.0554 - mean_absolute_error: 1.3522 - val_loss: 16.3417 - val_mean_absolute_error: 1.5713
# Epoch 9/15
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 17.4815 - mean_absolute_error: 1.3120 - val_loss: 16.2028 - val_mean_absolute_error: 1.4756
# Epoch 10/15
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 17.0013 - mean_absolute_error: 1.2790 - val_loss: 16.1180 - val_mean_absolute_error: 1.4799
# Epoch 11/15
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 16.5616 - mean_absolute_error: 1.2540 - val_loss: 16.0977 - val_mean_absolute_error: 1.5161
# Epoch 12/15
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 16.2038 - mean_absolute_error: 1.2346 - val_loss: 16.1012 - val_mean_absolute_error: 1.5218
# Epoch 13/15
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 15.8896 - mean_absolute_error: 1.2223 - val_loss: 16.0243 - val_mean_absolute_error: 1.4289
# Epoch 14/15
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 15.6220 - mean_absolute_error: 1.2072 - val_loss: 16.0234 - val_mean_absolute_error: 1.5220
# Epoch 15/15
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 15.3875 - mean_absolute_error: 1.1955 - val_loss: 15.9689 - val_mean_absolute_error: 1.4787
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.4846 - mean_absolute_error: 1.5726
# Epoch 1/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 24.8717 - mean_absolute_error: 2.0106 - val_loss: 18.6155 - val_mean_absolute_error: 1.8530
# Epoch 2/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 21.8441 - mean_absolute_error: 1.9200 - val_loss: 17.3231 - val_mean_absolute_error: 1.9129
# Epoch 3/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 19.6971 - mean_absolute_error: 1.8694 - val_loss: 16.4947 - val_mean_absolute_error: 1.9045
# Epoch 4/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 17.7990 - mean_absolute_error: 1.7116 - val_loss: 16.2375 - val_mean_absolute_error: 1.9669
# Epoch 5/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 16.2238 - mean_absolute_error: 1.5705 - val_loss: 15.9669 - val_mean_absolute_error: 1.8936
# Epoch 6/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 14.7829 - mean_absolute_error: 1.4439 - val_loss: 15.5258 - val_mean_absolute_error: 1.8221
# Epoch 7/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 13.7849 - mean_absolute_error: 1.3621 - val_loss: 15.3913 - val_mean_absolute_error: 1.6548
# Epoch 8/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 12.9824 - mean_absolute_error: 1.2984 - val_loss: 15.4084 - val_mean_absolute_error: 1.6081
# Epoch 9/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 12.2329 - mean_absolute_error: 1.2532 - val_loss: 15.0551 - val_mean_absolute_error: 1.6318
# Epoch 10/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 11.9782 - mean_absolute_error: 1.2503 - val_loss: 15.7672 - val_mean_absolute_error: 1.6622
# Epoch 11/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 11.6198 - mean_absolute_error: 1.2198 - val_loss: 15.9706 - val_mean_absolute_error: 1.6503
# Epoch 12/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 11.2780 - mean_absolute_error: 1.2054 - val_loss: 16.3992 - val_mean_absolute_error: 1.6832
# Epoch 13/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 11.0024 - mean_absolute_error: 1.1950 - val_loss: 16.6294 - val_mean_absolute_error: 1.7673
# Epoch 14/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 10.9740 - mean_absolute_error: 1.2189 - val_loss: 15.9355 - val_mean_absolute_error: 1.6073
# Epoch 15/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 10.6499 - mean_absolute_error: 1.1885 - val_loss: 16.3223 - val_mean_absolute_error: 1.6126
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.7614 - mean_absolute_error: 1.6255
# Epoch 1/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 21.9805 - mean_absolute_error: 1.6645 - val_loss: 17.0516 - val_mean_absolute_error: 1.5937
# Epoch 2/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 19.2904 - mean_absolute_error: 1.3986 - val_loss: 16.6996 - val_mean_absolute_error: 1.5581
# Epoch 3/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 18.0494 - mean_absolute_error: 1.3331 - val_loss: 16.8222 - val_mean_absolute_error: 1.7114
# Epoch 4/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 17.3726 - mean_absolute_error: 1.3046 - val_loss: 16.2452 - val_mean_absolute_error: 1.4980
# Epoch 5/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 16.6270 - mean_absolute_error: 1.2611 - val_loss: 16.1605 - val_mean_absolute_error: 1.4789
# Epoch 6/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 16.1905 - mean_absolute_error: 1.2459 - val_loss: 16.3237 - val_mean_absolute_error: 1.5824
# Epoch 7/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 15.8292 - mean_absolute_error: 1.2314 - val_loss: 16.1789 - val_mean_absolute_error: 1.5123
# Epoch 8/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 15.4745 - mean_absolute_error: 1.2102 - val_loss: 15.9838 - val_mean_absolute_error: 1.4530
# Epoch 9/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 15.1738 - mean_absolute_error: 1.2067 - val_loss: 16.2705 - val_mean_absolute_error: 1.7083
# Epoch 10/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 14.9383 - mean_absolute_error: 1.2001 - val_loss: 16.0742 - val_mean_absolute_error: 1.4745
# Epoch 11/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 14.5832 - mean_absolute_error: 1.1783 - val_loss: 15.9862 - val_mean_absolute_error: 1.4867
# Epoch 12/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 14.3853 - mean_absolute_error: 1.1767 - val_loss: 16.0604 - val_mean_absolute_error: 1.4931
# Epoch 13/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 14.0969 - mean_absolute_error: 1.1619 - val_loss: 15.8531 - val_mean_absolute_error: 1.5387
# Epoch 14/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 13.8968 - mean_absolute_error: 1.1547 - val_loss: 16.1483 - val_mean_absolute_error: 1.6308
# Epoch 15/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 13.7689 - mean_absolute_error: 1.1682 - val_loss: 16.1958 - val_mean_absolute_error: 1.5039
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.3849 - mean_absolute_error: 1.5959
# Epoch 1/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 23.3506 - mean_absolute_error: 1.7276 - val_loss: 17.9603 - val_mean_absolute_error: 1.6002
# Epoch 2/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 21.1355 - mean_absolute_error: 1.4661 - val_loss: 17.4445 - val_mean_absolute_error: 1.4971
# Epoch 3/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 20.1508 - mean_absolute_error: 1.3984 - val_loss: 17.2247 - val_mean_absolute_error: 1.4713
# Epoch 4/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 19.4099 - mean_absolute_error: 1.3414 - val_loss: 17.0104 - val_mean_absolute_error: 1.4697
# Epoch 5/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 18.8940 - mean_absolute_error: 1.3232 - val_loss: 16.8141 - val_mean_absolute_error: 1.4764
# Epoch 6/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 18.5043 - mean_absolute_error: 1.3029 - val_loss: 16.8182 - val_mean_absolute_error: 1.4182
# Epoch 7/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 18.0369 - mean_absolute_error: 1.2739 - val_loss: 16.6004 - val_mean_absolute_error: 1.4448
# Epoch 8/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 17.6208 - mean_absolute_error: 1.2499 - val_loss: 16.6175 - val_mean_absolute_error: 1.5646
# Epoch 9/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 17.3440 - mean_absolute_error: 1.2489 - val_loss: 16.4163 - val_mean_absolute_error: 1.4946
# Epoch 10/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 16.9654 - mean_absolute_error: 1.2288 - val_loss: 16.4842 - val_mean_absolute_error: 1.4839
# Epoch 11/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 16.6513 - mean_absolute_error: 1.2111 - val_loss: 16.2669 - val_mean_absolute_error: 1.4867
# Epoch 12/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 16.3587 - mean_absolute_error: 1.2046 - val_loss: 16.4711 - val_mean_absolute_error: 1.5307
# Epoch 13/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 16.0367 - mean_absolute_error: 1.1908 - val_loss: 16.4958 - val_mean_absolute_error: 1.6248
# Epoch 14/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 15.8200 - mean_absolute_error: 1.1862 - val_loss: 16.3864 - val_mean_absolute_error: 1.5339
# Epoch 15/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 15.6195 - mean_absolute_error: 1.1876 - val_loss: 16.3929 - val_mean_absolute_error: 1.5856
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.6601 - mean_absolute_error: 1.6740
# Epoch 1/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 23.5419 - mean_absolute_error: 1.8606 - val_loss: 18.0105 - val_mean_absolute_error: 1.8251
# Epoch 2/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 21.1019 - mean_absolute_error: 1.6429 - val_loss: 17.2238 - val_mean_absolute_error: 1.5734
# Epoch 3/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 19.7410 - mean_absolute_error: 1.4600 - val_loss: 16.7539 - val_mean_absolute_error: 1.5630
# Epoch 4/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 18.6519 - mean_absolute_error: 1.3458 - val_loss: 16.5244 - val_mean_absolute_error: 1.5587
# Epoch 5/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 17.7171 - mean_absolute_error: 1.2913 - val_loss: 16.3094 - val_mean_absolute_error: 1.5065
# Epoch 6/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 16.9914 - mean_absolute_error: 1.2604 - val_loss: 16.2258 - val_mean_absolute_error: 1.4542
# Epoch 7/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 16.4229 - mean_absolute_error: 1.2344 - val_loss: 16.2168 - val_mean_absolute_error: 1.5476
# Epoch 8/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 15.8927 - mean_absolute_error: 1.2162 - val_loss: 16.1811 - val_mean_absolute_error: 1.5500
# Epoch 9/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 15.3861 - mean_absolute_error: 1.1954 - val_loss: 16.1689 - val_mean_absolute_error: 1.5577
# Epoch 10/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 15.0201 - mean_absolute_error: 1.1830 - val_loss: 16.4449 - val_mean_absolute_error: 1.5980
# Epoch 11/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 14.7239 - mean_absolute_error: 1.1746 - val_loss: 16.1826 - val_mean_absolute_error: 1.5446
# Epoch 12/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 14.3698 - mean_absolute_error: 1.1601 - val_loss: 16.3127 - val_mean_absolute_error: 1.5643
# Epoch 13/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 14.1142 - mean_absolute_error: 1.1563 - val_loss: 16.1787 - val_mean_absolute_error: 1.5259
# Epoch 14/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 13.8592 - mean_absolute_error: 1.1433 - val_loss: 16.4229 - val_mean_absolute_error: 1.5830
# Epoch 15/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 13.7035 - mean_absolute_error: 1.1394 - val_loss: 16.3100 - val_mean_absolute_error: 1.5303
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.4290 - mean_absolute_error: 1.6170
# Epoch 1/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 23.9549 - mean_absolute_error: 1.8633 - val_loss: 18.2724 - val_mean_absolute_error: 1.7451
# Epoch 2/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 21.5049 - mean_absolute_error: 1.6377 - val_loss: 17.4118 - val_mean_absolute_error: 1.5658
# Epoch 3/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 20.0923 - mean_absolute_error: 1.4697 - val_loss: 16.8941 - val_mean_absolute_error: 1.5401
# Epoch 4/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 18.9350 - mean_absolute_error: 1.3669 - val_loss: 16.6176 - val_mean_absolute_error: 1.5042
# Epoch 5/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 18.1034 - mean_absolute_error: 1.3049 - val_loss: 16.4462 - val_mean_absolute_error: 1.5139
# Epoch 6/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 17.2967 - mean_absolute_error: 1.2647 - val_loss: 16.3012 - val_mean_absolute_error: 1.4902
# Epoch 7/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 16.6122 - mean_absolute_error: 1.2349 - val_loss: 16.1586 - val_mean_absolute_error: 1.5039
# Epoch 8/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 16.0216 - mean_absolute_error: 1.2092 - val_loss: 16.2416 - val_mean_absolute_error: 1.5432
# Epoch 9/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 15.5238 - mean_absolute_error: 1.1808 - val_loss: 16.1654 - val_mean_absolute_error: 1.4907
# Epoch 10/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 15.1187 - mean_absolute_error: 1.1726 - val_loss: 16.2690 - val_mean_absolute_error: 1.5594
# Epoch 11/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 14.7986 - mean_absolute_error: 1.1605 - val_loss: 16.0615 - val_mean_absolute_error: 1.5116
# Epoch 12/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 14.4051 - mean_absolute_error: 1.1488 - val_loss: 16.3406 - val_mean_absolute_error: 1.5581
# Epoch 13/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 14.1167 - mean_absolute_error: 1.1352 - val_loss: 16.2888 - val_mean_absolute_error: 1.5296
# Epoch 14/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 13.8798 - mean_absolute_error: 1.1320 - val_loss: 16.2327 - val_mean_absolute_error: 1.5124
# Epoch 15/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 13.6917 - mean_absolute_error: 1.1224 - val_loss: 16.1544 - val_mean_absolute_error: 1.5083
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.2108 - mean_absolute_error: 1.5884

# %%
scores
# Out:
# [[0, [21.26566505432129, 1.6448439359664917]],
#  [1, [21.5150146484375, 1.5950630903244019]],
#  [2, [21.484586715698242, 1.5725528001785278]],
#  [3, [18.76144790649414, 1.6255497932434082]],
#  [4, [21.38492202758789, 1.5958555936813354]],
#  [5, [21.660072326660156, 1.6740405559539795]],
#  [6, [21.42899513244629, 1.6170096397399902]],
#  [7, [21.21075439453125, 1.5883523225784302]]]

# %% [markdown]
# Best: [[64, 32, 16], "tanh", 128, [False], "adamax"]

# %%
bad_grid_search = [[[64, 32, 16], "tanh", 128, [False], "adamax",20],
    [[64, 32, 16], "tanh", 128, [True, 0.3], "adamax",20],
    [[64, 32, 16], "tanh", 128, [True, 0.4], "adamax",20],
    [[128, 64, 32], "tanh", 128, [True, 0.3], "adamax",20],
    [[128, 64, 32], "tanh", 128, [False], "adamax",20],
    [[512, 256, 32], "tanh", 128, [False], "adamax",20],
    [[64, 32, 16], "tanh", 128, [False], keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999),20],
    [[64, 32, 16], "tanh", 128, [False], keras.optimizers.Adam(learning_rate=0.005, beta_1=0.9, beta_2=0.999),20],
    [[64, 32, 16], "tanh", 128, [False], keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999),20]
    ]

scores = []
for tests in bad_grid_search:
    result = buildModel(tests)
    scores.append([tests, result])
# Out:
# Epoch 1/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 24.8248 - mean_absolute_error: 1.9834 - val_loss: 18.9123 - val_mean_absolute_error: 1.9131
# Epoch 2/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 22.6983 - mean_absolute_error: 1.8401 - val_loss: 17.9671 - val_mean_absolute_error: 1.8519
# Epoch 3/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 21.3851 - mean_absolute_error: 1.7478 - val_loss: 17.4954 - val_mean_absolute_error: 1.6873
# Epoch 4/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 20.3519 - mean_absolute_error: 1.6143 - val_loss: 16.9864 - val_mean_absolute_error: 1.6524
# Epoch 5/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 19.4754 - mean_absolute_error: 1.5062 - val_loss: 16.7028 - val_mean_absolute_error: 1.5904
# Epoch 6/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 18.7031 - mean_absolute_error: 1.4045 - val_loss: 16.4927 - val_mean_absolute_error: 1.5175
# Epoch 7/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 18.1121 - mean_absolute_error: 1.3361 - val_loss: 16.3936 - val_mean_absolute_error: 1.4575
# Epoch 8/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 17.5568 - mean_absolute_error: 1.2868 - val_loss: 16.2578 - val_mean_absolute_error: 1.4635
# Epoch 9/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 17.0621 - mean_absolute_error: 1.2554 - val_loss: 16.2163 - val_mean_absolute_error: 1.4968
# Epoch 10/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 16.6329 - mean_absolute_error: 1.2374 - val_loss: 16.2838 - val_mean_absolute_error: 1.5532
# Epoch 11/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 16.2351 - mean_absolute_error: 1.2146 - val_loss: 16.1237 - val_mean_absolute_error: 1.4777
# Epoch 12/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 15.8693 - mean_absolute_error: 1.1925 - val_loss: 16.2613 - val_mean_absolute_error: 1.5531
# Epoch 13/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 15.5415 - mean_absolute_error: 1.1842 - val_loss: 16.1134 - val_mean_absolute_error: 1.4849
# Epoch 14/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 15.2204 - mean_absolute_error: 1.1695 - val_loss: 16.1091 - val_mean_absolute_error: 1.5038
# Epoch 15/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 14.9513 - mean_absolute_error: 1.1539 - val_loss: 16.1287 - val_mean_absolute_error: 1.5315
# Epoch 16/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 14.7232 - mean_absolute_error: 1.1509 - val_loss: 16.1321 - val_mean_absolute_error: 1.5007
# Epoch 17/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 14.5222 - mean_absolute_error: 1.1470 - val_loss: 16.1325 - val_mean_absolute_error: 1.5087
# Epoch 18/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 14.3793 - mean_absolute_error: 1.1444 - val_loss: 16.1304 - val_mean_absolute_error: 1.4602
# Epoch 19/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 14.2172 - mean_absolute_error: 1.1374 - val_loss: 16.3085 - val_mean_absolute_error: 1.5548
# Epoch 20/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 13.9681 - mean_absolute_error: 1.1213 - val_loss: 16.3651 - val_mean_absolute_error: 1.5712
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.7963 - mean_absolute_error: 1.6607
# Epoch 1/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 25.7301 - mean_absolute_error: 2.0959 - val_loss: 19.9167 - val_mean_absolute_error: 2.0616
# Epoch 2/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 24.3566 - mean_absolute_error: 2.0114 - val_loss: 18.9919 - val_mean_absolute_error: 1.8415
# Epoch 3/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 23.4508 - mean_absolute_error: 1.9557 - val_loss: 18.4608 - val_mean_absolute_error: 1.8662
# Epoch 4/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 22.8424 - mean_absolute_error: 1.9535 - val_loss: 18.2291 - val_mean_absolute_error: 1.9388
# Epoch 5/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 22.3788 - mean_absolute_error: 1.9706 - val_loss: 18.0666 - val_mean_absolute_error: 1.8755
# Epoch 6/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 21.9547 - mean_absolute_error: 1.9376 - val_loss: 17.9487 - val_mean_absolute_error: 1.9647
# Epoch 7/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 21.6487 - mean_absolute_error: 1.9376 - val_loss: 17.7713 - val_mean_absolute_error: 1.8980
# Epoch 8/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 21.1618 - mean_absolute_error: 1.8822 - val_loss: 17.5703 - val_mean_absolute_error: 1.8985
# Epoch 9/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 20.8175 - mean_absolute_error: 1.8519 - val_loss: 17.3716 - val_mean_absolute_error: 1.8066
# Epoch 10/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 20.3745 - mean_absolute_error: 1.8003 - val_loss: 17.1753 - val_mean_absolute_error: 1.7790
# Epoch 11/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 20.0721 - mean_absolute_error: 1.7674 - val_loss: 16.9485 - val_mean_absolute_error: 1.7618
# Epoch 12/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 19.6920 - mean_absolute_error: 1.7255 - val_loss: 16.8190 - val_mean_absolute_error: 1.6780
# Epoch 13/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 19.2059 - mean_absolute_error: 1.6483 - val_loss: 16.6137 - val_mean_absolute_error: 1.6948
# Epoch 14/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 18.8987 - mean_absolute_error: 1.6176 - val_loss: 16.4953 - val_mean_absolute_error: 1.6252
# Epoch 15/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 18.5949 - mean_absolute_error: 1.5796 - val_loss: 16.4289 - val_mean_absolute_error: 1.5501
# Epoch 16/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 18.2012 - mean_absolute_error: 1.5274 - val_loss: 16.3083 - val_mean_absolute_error: 1.5944
# Epoch 17/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 17.9855 - mean_absolute_error: 1.5127 - val_loss: 16.2251 - val_mean_absolute_error: 1.5824
# Epoch 18/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 17.6723 - mean_absolute_error: 1.4999 - val_loss: 16.2008 - val_mean_absolute_error: 1.5786
# Epoch 19/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 17.4400 - mean_absolute_error: 1.4805 - val_loss: 16.1638 - val_mean_absolute_error: 1.5176
# Epoch 20/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 17.2188 - mean_absolute_error: 1.4519 - val_loss: 16.0958 - val_mean_absolute_error: 1.5856
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.9421 - mean_absolute_error: 1.6714
# Epoch 1/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 25.4580 - mean_absolute_error: 2.0439 - val_loss: 19.7174 - val_mean_absolute_error: 1.9816
# Epoch 2/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 24.1557 - mean_absolute_error: 1.9791 - val_loss: 18.9780 - val_mean_absolute_error: 1.9914
# Epoch 3/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 23.3673 - mean_absolute_error: 1.9518 - val_loss: 18.4851 - val_mean_absolute_error: 1.9013
# Epoch 4/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 22.8321 - mean_absolute_error: 1.9565 - val_loss: 18.3025 - val_mean_absolute_error: 1.9423
# Epoch 5/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 22.3318 - mean_absolute_error: 1.9475 - val_loss: 18.1754 - val_mean_absolute_error: 1.8498
# Epoch 6/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 22.0195 - mean_absolute_error: 1.9378 - val_loss: 17.9850 - val_mean_absolute_error: 1.8561
# Epoch 7/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 21.6710 - mean_absolute_error: 1.9178 - val_loss: 17.7717 - val_mean_absolute_error: 1.8532
# Epoch 8/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 21.3365 - mean_absolute_error: 1.8655 - val_loss: 17.6056 - val_mean_absolute_error: 1.8670
# Epoch 9/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 20.7645 - mean_absolute_error: 1.8374 - val_loss: 17.4175 - val_mean_absolute_error: 1.7524
# Epoch 10/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 20.4249 - mean_absolute_error: 1.7671 - val_loss: 17.2173 - val_mean_absolute_error: 1.7801
# Epoch 11/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 20.1038 - mean_absolute_error: 1.7471 - val_loss: 17.0578 - val_mean_absolute_error: 1.6856
# Epoch 12/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 19.8008 - mean_absolute_error: 1.6910 - val_loss: 16.9277 - val_mean_absolute_error: 1.6824
# Epoch 13/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 19.4325 - mean_absolute_error: 1.6474 - val_loss: 16.8783 - val_mean_absolute_error: 1.5972
# Epoch 14/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 19.1510 - mean_absolute_error: 1.6091 - val_loss: 16.7231 - val_mean_absolute_error: 1.6760
# Epoch 15/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 18.9085 - mean_absolute_error: 1.5975 - val_loss: 16.6747 - val_mean_absolute_error: 1.6354
# Epoch 16/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 18.6665 - mean_absolute_error: 1.5714 - val_loss: 16.6209 - val_mean_absolute_error: 1.5787
# Epoch 17/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 18.3016 - mean_absolute_error: 1.5493 - val_loss: 16.5525 - val_mean_absolute_error: 1.6186
# Epoch 18/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 18.1156 - mean_absolute_error: 1.5331 - val_loss: 16.5087 - val_mean_absolute_error: 1.5922
# Epoch 19/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 17.7815 - mean_absolute_error: 1.5054 - val_loss: 16.4861 - val_mean_absolute_error: 1.5548
# Epoch 20/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 17.7170 - mean_absolute_error: 1.5001 - val_loss: 16.4559 - val_mean_absolute_error: 1.5818
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.2653 - mean_absolute_error: 1.6602
# Epoch 1/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 24.9192 - mean_absolute_error: 1.9795 - val_loss: 18.8633 - val_mean_absolute_error: 1.9807
# Epoch 2/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 22.9482 - mean_absolute_error: 1.9646 - val_loss: 18.0768 - val_mean_absolute_error: 1.8202
# Epoch 3/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 21.7963 - mean_absolute_error: 1.9487 - val_loss: 17.7873 - val_mean_absolute_error: 1.9522
# Epoch 4/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 21.0148 - mean_absolute_error: 1.9004 - val_loss: 17.4579 - val_mean_absolute_error: 1.8835
# Epoch 5/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 20.2571 - mean_absolute_error: 1.8501 - val_loss: 17.1909 - val_mean_absolute_error: 1.7810
# Epoch 6/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 19.5552 - mean_absolute_error: 1.7653 - val_loss: 16.7701 - val_mean_absolute_error: 1.7996
# Epoch 7/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 18.7601 - mean_absolute_error: 1.6758 - val_loss: 16.5001 - val_mean_absolute_error: 1.7122
# Epoch 8/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 18.1572 - mean_absolute_error: 1.5883 - val_loss: 16.3380 - val_mean_absolute_error: 1.6903
# Epoch 9/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 17.6080 - mean_absolute_error: 1.5372 - val_loss: 16.1755 - val_mean_absolute_error: 1.5972
# Epoch 10/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 16.9846 - mean_absolute_error: 1.4898 - val_loss: 16.0806 - val_mean_absolute_error: 1.6015
# Epoch 11/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 16.7643 - mean_absolute_error: 1.4633 - val_loss: 16.1307 - val_mean_absolute_error: 1.6346
# Epoch 12/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 16.3343 - mean_absolute_error: 1.4397 - val_loss: 16.0584 - val_mean_absolute_error: 1.5210
# Epoch 13/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 15.9741 - mean_absolute_error: 1.4098 - val_loss: 16.2013 - val_mean_absolute_error: 1.6489
# Epoch 14/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 15.8269 - mean_absolute_error: 1.3981 - val_loss: 16.2245 - val_mean_absolute_error: 1.6531
# Epoch 15/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 15.3906 - mean_absolute_error: 1.3767 - val_loss: 16.0665 - val_mean_absolute_error: 1.5944
# Epoch 16/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 15.1238 - mean_absolute_error: 1.3684 - val_loss: 16.1785 - val_mean_absolute_error: 1.6182
# Epoch 17/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 15.0657 - mean_absolute_error: 1.3680 - val_loss: 16.1816 - val_mean_absolute_error: 1.5850
# Epoch 18/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 14.7458 - mean_absolute_error: 1.3672 - val_loss: 16.3245 - val_mean_absolute_error: 1.6145
# Epoch 19/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 14.7930 - mean_absolute_error: 1.3561 - val_loss: 16.2714 - val_mean_absolute_error: 1.5870
# Epoch 20/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 14.5055 - mean_absolute_error: 1.3515 - val_loss: 16.3019 - val_mean_absolute_error: 1.6073
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.5862 - mean_absolute_error: 1.6721
# Epoch 1/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 23.5566 - mean_absolute_error: 1.9621 - val_loss: 18.0705 - val_mean_absolute_error: 1.9838
# Epoch 2/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 20.8546 - mean_absolute_error: 1.8369 - val_loss: 17.3092 - val_mean_absolute_error: 1.8180
# Epoch 3/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 18.9565 - mean_absolute_error: 1.6140 - val_loss: 16.4769 - val_mean_absolute_error: 1.6741
# Epoch 4/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 17.5897 - mean_absolute_error: 1.4291 - val_loss: 16.1555 - val_mean_absolute_error: 1.5920
# Epoch 5/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 16.6483 - mean_absolute_error: 1.3317 - val_loss: 16.0454 - val_mean_absolute_error: 1.5640
# Epoch 6/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 15.9871 - mean_absolute_error: 1.2749 - val_loss: 15.9807 - val_mean_absolute_error: 1.5203
# Epoch 7/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 15.4207 - mean_absolute_error: 1.2406 - val_loss: 16.0216 - val_mean_absolute_error: 1.4926
# Epoch 8/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 14.9609 - mean_absolute_error: 1.2110 - val_loss: 16.0225 - val_mean_absolute_error: 1.5223
# Epoch 9/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 14.5187 - mean_absolute_error: 1.1922 - val_loss: 16.1120 - val_mean_absolute_error: 1.5428
# Epoch 10/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 14.1668 - mean_absolute_error: 1.1803 - val_loss: 16.3217 - val_mean_absolute_error: 1.5982
# Epoch 11/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 13.8092 - mean_absolute_error: 1.1700 - val_loss: 16.4910 - val_mean_absolute_error: 1.6194
# Epoch 12/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 13.5590 - mean_absolute_error: 1.1610 - val_loss: 16.3263 - val_mean_absolute_error: 1.5708
# Epoch 13/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 13.2406 - mean_absolute_error: 1.1515 - val_loss: 16.3979 - val_mean_absolute_error: 1.5824
# Epoch 14/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 13.0763 - mean_absolute_error: 1.1500 - val_loss: 16.4467 - val_mean_absolute_error: 1.5762
# Epoch 15/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 12.8860 - mean_absolute_error: 1.1420 - val_loss: 16.9996 - val_mean_absolute_error: 1.6569
# Epoch 16/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 12.7072 - mean_absolute_error: 1.1313 - val_loss: 16.9886 - val_mean_absolute_error: 1.6518
# Epoch 17/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 12.5528 - mean_absolute_error: 1.1292 - val_loss: 16.5795 - val_mean_absolute_error: 1.5513
# Epoch 18/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 12.3389 - mean_absolute_error: 1.1180 - val_loss: 16.7953 - val_mean_absolute_error: 1.6185
# Epoch 19/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 12.2761 - mean_absolute_error: 1.1165 - val_loss: 16.6010 - val_mean_absolute_error: 1.5741
# Epoch 20/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 12.0812 - mean_absolute_error: 1.1150 - val_loss: 17.8477 - val_mean_absolute_error: 1.7362
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 22.6098 - mean_absolute_error: 1.7944
# Epoch 1/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - loss: 21.5769 - mean_absolute_error: 1.8568 - val_loss: 16.7945 - val_mean_absolute_error: 1.7673
# Epoch 2/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 18.2681 - mean_absolute_error: 1.3997 - val_loss: 16.3504 - val_mean_absolute_error: 1.4824
# Epoch 3/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 17.0828 - mean_absolute_error: 1.2847 - val_loss: 16.3003 - val_mean_absolute_error: 1.4772
# Epoch 4/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 16.3437 - mean_absolute_error: 1.2484 - val_loss: 16.2898 - val_mean_absolute_error: 1.5305
# Epoch 5/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 15.7072 - mean_absolute_error: 1.2136 - val_loss: 16.4626 - val_mean_absolute_error: 1.6164
# Epoch 6/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 15.1241 - mean_absolute_error: 1.1970 - val_loss: 16.2448 - val_mean_absolute_error: 1.5258
# Epoch 7/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 14.6290 - mean_absolute_error: 1.1732 - val_loss: 16.3361 - val_mean_absolute_error: 1.5336
# Epoch 8/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 14.2347 - mean_absolute_error: 1.1539 - val_loss: 16.9943 - val_mean_absolute_error: 1.6977
# Epoch 9/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 13.8508 - mean_absolute_error: 1.1473 - val_loss: 16.4876 - val_mean_absolute_error: 1.5696
# Epoch 10/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 13.5995 - mean_absolute_error: 1.1459 - val_loss: 16.6608 - val_mean_absolute_error: 1.5875
# Epoch 11/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 13.3076 - mean_absolute_error: 1.1248 - val_loss: 16.7459 - val_mean_absolute_error: 1.6079
# Epoch 12/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 13.0007 - mean_absolute_error: 1.1053 - val_loss: 16.5960 - val_mean_absolute_error: 1.5414
# Epoch 13/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 12.8610 - mean_absolute_error: 1.0980 - val_loss: 16.3981 - val_mean_absolute_error: 1.4879
# Epoch 14/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 12.6108 - mean_absolute_error: 1.0941 - val_loss: 17.0610 - val_mean_absolute_error: 1.6315
# Epoch 15/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 12.4866 - mean_absolute_error: 1.0920 - val_loss: 17.0469 - val_mean_absolute_error: 1.5988
# Epoch 16/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 12.2909 - mean_absolute_error: 1.0801 - val_loss: 16.6711 - val_mean_absolute_error: 1.5221
# Epoch 17/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 12.2422 - mean_absolute_error: 1.0802 - val_loss: 17.2599 - val_mean_absolute_error: 1.6865
# Epoch 18/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 12.1400 - mean_absolute_error: 1.0831 - val_loss: 16.3783 - val_mean_absolute_error: 1.5305
# Epoch 19/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 12.0156 - mean_absolute_error: 1.0720 - val_loss: 17.0983 - val_mean_absolute_error: 1.5838
# Epoch 20/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 11.7655 - mean_absolute_error: 1.0636 - val_loss: 16.3689 - val_mean_absolute_error: 1.4983
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 20.7539 - mean_absolute_error: 1.5533
# Epoch 1/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 24.5603 - mean_absolute_error: 2.0025 - val_loss: 18.3293 - val_mean_absolute_error: 1.9412
# Epoch 2/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 21.7938 - mean_absolute_error: 1.7358 - val_loss: 16.9587 - val_mean_absolute_error: 1.6419
# Epoch 3/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 19.6173 - mean_absolute_error: 1.5000 - val_loss: 17.1639 - val_mean_absolute_error: 1.3890
# Epoch 4/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 18.0451 - mean_absolute_error: 1.3907 - val_loss: 19.3200 - val_mean_absolute_error: 1.4178
# Epoch 5/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 17.8515 - mean_absolute_error: 1.4212 - val_loss: 15.9286 - val_mean_absolute_error: 1.5925
# Epoch 6/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 18.0027 - mean_absolute_error: 1.5035 - val_loss: 16.2222 - val_mean_absolute_error: 1.7399
# Epoch 7/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 16.1903 - mean_absolute_error: 1.3378 - val_loss: 15.3788 - val_mean_absolute_error: 1.5949
# Epoch 8/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 15.7050 - mean_absolute_error: 1.3143 - val_loss: 15.3739 - val_mean_absolute_error: 1.5192
# Epoch 9/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 15.4076 - mean_absolute_error: 1.3151 - val_loss: 15.6980 - val_mean_absolute_error: 1.4825
# Epoch 10/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 14.5243 - mean_absolute_error: 1.2574 - val_loss: 16.0487 - val_mean_absolute_error: 1.4737
# Epoch 11/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 14.1374 - mean_absolute_error: 1.2386 - val_loss: 15.9353 - val_mean_absolute_error: 1.4811
# Epoch 12/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 13.6818 - mean_absolute_error: 1.2077 - val_loss: 16.1486 - val_mean_absolute_error: 1.7124
# Epoch 13/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 15.7399 - mean_absolute_error: 1.3969 - val_loss: 18.0799 - val_mean_absolute_error: 1.6541
# Epoch 14/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 15.0582 - mean_absolute_error: 1.4125 - val_loss: 15.6266 - val_mean_absolute_error: 1.4466
# Epoch 15/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 13.0846 - mean_absolute_error: 1.1855 - val_loss: 16.5912 - val_mean_absolute_error: 1.6534
# Epoch 16/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 14.2955 - mean_absolute_error: 1.2897 - val_loss: 16.5837 - val_mean_absolute_error: 1.6397
# Epoch 17/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 12.9010 - mean_absolute_error: 1.2119 - val_loss: 16.6172 - val_mean_absolute_error: 1.7224
# Epoch 18/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 12.4403 - mean_absolute_error: 1.1850 - val_loss: 15.7399 - val_mean_absolute_error: 1.4113
# Epoch 19/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 13.6850 - mean_absolute_error: 1.3019 - val_loss: 16.3626 - val_mean_absolute_error: 1.6453
# Epoch 20/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 12.6503 - mean_absolute_error: 1.2210 - val_loss: 16.3044 - val_mean_absolute_error: 1.5963
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.6087 - mean_absolute_error: 1.6331
# Epoch 1/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 23.6714 - mean_absolute_error: 1.9624 - val_loss: 18.7972 - val_mean_absolute_error: 1.5019
# Epoch 2/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 20.1972 - mean_absolute_error: 1.6266 - val_loss: 17.1924 - val_mean_absolute_error: 1.9730
# Epoch 3/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 20.5275 - mean_absolute_error: 1.7444 - val_loss: 16.3867 - val_mean_absolute_error: 1.9751
# Epoch 4/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 19.8257 - mean_absolute_error: 1.7356 - val_loss: 17.3586 - val_mean_absolute_error: 1.7890
# Epoch 5/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 19.0203 - mean_absolute_error: 1.6976 - val_loss: 16.1088 - val_mean_absolute_error: 1.7506
# Epoch 6/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 17.1772 - mean_absolute_error: 1.5326 - val_loss: 15.8500 - val_mean_absolute_error: 1.4791
# Epoch 7/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 16.0726 - mean_absolute_error: 1.4471 - val_loss: 20.7167 - val_mean_absolute_error: 2.4326
# Epoch 8/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 16.9093 - mean_absolute_error: 1.5629 - val_loss: 18.1197 - val_mean_absolute_error: 1.9357
# Epoch 9/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 16.2533 - mean_absolute_error: 1.5195 - val_loss: 16.2760 - val_mean_absolute_error: 1.9341
# Epoch 10/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 18.4884 - mean_absolute_error: 1.6876 - val_loss: 16.6640 - val_mean_absolute_error: 1.8822
# Epoch 11/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 14.6425 - mean_absolute_error: 1.4773 - val_loss: 33.5826 - val_mean_absolute_error: 3.3763
# Epoch 12/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 19.5007 - mean_absolute_error: 1.7373 - val_loss: 16.3893 - val_mean_absolute_error: 1.5835
# Epoch 13/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 14.9689 - mean_absolute_error: 1.5295 - val_loss: 15.8084 - val_mean_absolute_error: 1.4017
# Epoch 14/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 17.0064 - mean_absolute_error: 1.5897 - val_loss: 17.2635 - val_mean_absolute_error: 1.5248
# Epoch 15/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 14.5868 - mean_absolute_error: 1.5116 - val_loss: 16.2639 - val_mean_absolute_error: 1.9269
# Epoch 16/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 13.7719 - mean_absolute_error: 1.4545 - val_loss: 16.5071 - val_mean_absolute_error: 1.5273
# Epoch 17/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 14.2586 - mean_absolute_error: 1.4792 - val_loss: 14.4580 - val_mean_absolute_error: 1.5379
# Epoch 18/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 14.1086 - mean_absolute_error: 1.4482 - val_loss: 14.5572 - val_mean_absolute_error: 1.7053
# Epoch 19/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 14.5654 - mean_absolute_error: 1.4725 - val_loss: 16.5487 - val_mean_absolute_error: 1.6260
# Epoch 20/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 14.0768 - mean_absolute_error: 1.4641 - val_loss: 17.7908 - val_mean_absolute_error: 1.7814
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 22.3895 - mean_absolute_error: 1.7747
# Epoch 1/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 26.0104 - mean_absolute_error: 1.9867 - val_loss: 20.2926 - val_mean_absolute_error: 1.9710
# Epoch 2/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 24.4892 - mean_absolute_error: 1.9482 - val_loss: 19.3832 - val_mean_absolute_error: 1.8026
# Epoch 3/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 23.2691 - mean_absolute_error: 1.8118 - val_loss: 18.8342 - val_mean_absolute_error: 1.7095
# Epoch 4/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 22.4272 - mean_absolute_error: 1.7438 - val_loss: 18.4412 - val_mean_absolute_error: 1.8114
# Epoch 5/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 21.8335 - mean_absolute_error: 1.7256 - val_loss: 18.1946 - val_mean_absolute_error: 1.7393
# Epoch 6/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 21.3465 - mean_absolute_error: 1.6802 - val_loss: 17.9802 - val_mean_absolute_error: 1.6921
# Epoch 7/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 20.9356 - mean_absolute_error: 1.6364 - val_loss: 17.7333 - val_mean_absolute_error: 1.7152
# Epoch 8/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 20.5416 - mean_absolute_error: 1.5946 - val_loss: 17.5385 - val_mean_absolute_error: 1.6972
# Epoch 9/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 20.2044 - mean_absolute_error: 1.5542 - val_loss: 17.3771 - val_mean_absolute_error: 1.6468
# Epoch 10/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 19.9142 - mean_absolute_error: 1.5231 - val_loss: 17.2317 - val_mean_absolute_error: 1.6069
# Epoch 11/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 19.6347 - mean_absolute_error: 1.4905 - val_loss: 17.1224 - val_mean_absolute_error: 1.5616
# Epoch 12/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 19.3834 - mean_absolute_error: 1.4707 - val_loss: 16.9991 - val_mean_absolute_error: 1.5551
# Epoch 13/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 19.1654 - mean_absolute_error: 1.4499 - val_loss: 16.9354 - val_mean_absolute_error: 1.5189
# Epoch 14/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 18.9755 - mean_absolute_error: 1.4349 - val_loss: 16.8175 - val_mean_absolute_error: 1.5236
# Epoch 15/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 18.7877 - mean_absolute_error: 1.4170 - val_loss: 16.7962 - val_mean_absolute_error: 1.4837
# Epoch 16/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 18.5939 - mean_absolute_error: 1.4078 - val_loss: 16.6812 - val_mean_absolute_error: 1.5051
# Epoch 17/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 18.4361 - mean_absolute_error: 1.3946 - val_loss: 16.6002 - val_mean_absolute_error: 1.5188
# Epoch 18/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 18.2833 - mean_absolute_error: 1.3800 - val_loss: 16.5386 - val_mean_absolute_error: 1.5617
# Epoch 19/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 18.1143 - mean_absolute_error: 1.3755 - val_loss: 16.4865 - val_mean_absolute_error: 1.5392
# Epoch 20/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 17.9703 - mean_absolute_error: 1.3634 - val_loss: 16.4639 - val_mean_absolute_error: 1.4910
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.3890 - mean_absolute_error: 1.5364

# %%
scores
# Out:
# [[[[64, 32, 16], 'tanh', 128, [False], 'adamax'],
#   [21.796321868896484, 1.6607264280319214]],
#  [[[64, 32, 16], 'tanh', 128, [True, 0.3], 'adamax'],
#   [20.942089080810547, 1.6713695526123047]],
#  [[[64, 32, 16], 'tanh', 128, [True, 0.4], 'adamax'],
#   [21.265302658081055, 1.660178303718567]],
#  [[[128, 64, 32], 'tanh', 128, [True, 0.3], 'adamax'],
#   [20.586200714111328, 1.6721023321151733]],
#  [[[128, 64, 32], 'tanh', 128, [False], 'adamax'],
#   [22.609840393066406, 1.7944376468658447]],
#  [[[512, 256, 32], 'tanh', 128, [False], 'adamax'],
#   [20.753948211669922, 1.5533264875411987]],
#  [[[64, 32, 16],
#    'tanh',
#    128,
#    [False],
#    <keras.src.optimizers.adam.Adam at 0x20b0f67dc10>],
#   [20.608652114868164, 1.6331120729446411]],
#  [[[64, 32, 16],
#    'tanh',
#    128,
#    [False],
#    <keras.src.optimizers.adam.Adam at 0x20b0f66dc70>],
#   [22.389524459838867, 1.7746586799621582]],
#  [[[64, 32, 16],
#    'tanh',
#    128,
#    [False],
#    <keras.src.optimizers.adam.Adam at 0x20b0f67fbc0>],
#   [21.389019012451172, 1.5364429950714111]]]

# %%
scores.sort(key=lambda x: x[1][1])

# %%
scores[0]
# Out:
# [[[64, 32, 16],
#   'tanh',
#   128,
#   [False],
#   <keras.src.optimizers.adam.Adam at 0x20b0f67fbc0>],
#  [21.389019012451172, 1.5364429950714111]]

# %%
scores[0][0][4].get_config()
# Out:
# {'name': 'adam',
#  'learning_rate': 9.999999747378752e-05,
#  'weight_decay': None,
#  'clipnorm': None,
#  'global_clipnorm': None,
#  'clipvalue': None,
#  'use_ema': False,
#  'ema_momentum': 0.99,
#  'ema_overwrite_frequency': None,
#  'loss_scale_factor': None,
#  'gradient_accumulation_steps': None,
#  'beta_1': 0.9,
#  'beta_2': 0.999,
#  'epsilon': 1e-07,
#  'amsgrad': False}

# %% [markdown]
# Best: [[64, 32, 16],
#   'tanh',
#   128,
#   [False],
#   keras.optimizers.Adam(learning_rate=0.0001)]

# %%
def buildModelUpdated(testing):
    num_nrns = testing[0]
    activation = testing[1]
    batch_size = testing[2]
    if_drop = testing[3]
    optimizer = testing[4]
    x = keras.layers.Dense(num_nrns[0], activation=activation)(all_features)
    if if_drop[0]:
        x = keras.layers.Dropout(rate=if_drop[1])(all_features)
    for num in num_nrns[1:]:
        x = keras.layers.Dense(num, activation=activation)(x)
        x = keras.layers.Normalization()(x)
    output = keras.layers.Dense(1, activation="linear", name="price")(x)

    early_stopping_cb = keras.callbacks.EarlyStopping(patience=25, start_from_epoch=20, monitor="val_loss", mode='min')
    #model_checkpoint_cb = keras.callbacks.ModelCheckpoint(f"models\\best_model", save_best_only=True)
    run_index = 1 # increment every time you train the model
    run_logdir = os.path.join(os.curdir, "logs", "run_{:03d}".format(run_index))
    tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)
    callbacks = [early_stopping_cb, 
                #model_checkpoint_cb,
               tensorboard_cb]

    model = keras.Model(inputs=all_inputs, outputs=output)
    model.compile(optimizer=optimizer, loss=keras.losses.MeanSquaredError(), metrics=[keras.metrics.MeanAbsoluteError()])

    model.fit(x_train, y_train,
    epochs=testing[5],
    batch_size=batch_size,
    validation_split=0.25,
    callbacks=callbacks)

    return model, model.evaluate(x_test, y_test)

# %%
model = buildModelUpdated([[64, 32, 16],'tanh',128,[False],keras.optimizers.Adam(learning_rate=0.0001),75])
# Out:
# Epoch 1/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 25.9893 - mean_absolute_error: 2.0447 - val_loss: 20.3734 - val_mean_absolute_error: 2.0298
# Epoch 2/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 24.4228 - mean_absolute_error: 1.9745 - val_loss: 19.4856 - val_mean_absolute_error: 1.8084
# Epoch 3/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 23.2118 - mean_absolute_error: 1.8400 - val_loss: 18.9083 - val_mean_absolute_error: 1.7703
# Epoch 4/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 22.3780 - mean_absolute_error: 1.7927 - val_loss: 18.5876 - val_mean_absolute_error: 1.7665
# Epoch 5/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 21.8055 - mean_absolute_error: 1.7662 - val_loss: 18.2785 - val_mean_absolute_error: 1.7736
# Epoch 6/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 21.3395 - mean_absolute_error: 1.7147 - val_loss: 18.0293 - val_mean_absolute_error: 1.7639
# Epoch 7/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 20.9124 - mean_absolute_error: 1.6699 - val_loss: 17.7967 - val_mean_absolute_error: 1.7187
# Epoch 8/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 20.5263 - mean_absolute_error: 1.6219 - val_loss: 17.5865 - val_mean_absolute_error: 1.6921
# Epoch 9/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 20.1988 - mean_absolute_error: 1.5747 - val_loss: 17.4197 - val_mean_absolute_error: 1.6604
# Epoch 10/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 19.8966 - mean_absolute_error: 1.5439 - val_loss: 17.2629 - val_mean_absolute_error: 1.6191
# Epoch 11/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 19.6289 - mean_absolute_error: 1.5042 - val_loss: 17.1204 - val_mean_absolute_error: 1.6241
# Epoch 12/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 19.3814 - mean_absolute_error: 1.4741 - val_loss: 17.0660 - val_mean_absolute_error: 1.5326
# Epoch 13/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 19.1542 - mean_absolute_error: 1.4518 - val_loss: 16.9018 - val_mean_absolute_error: 1.5731
# Epoch 14/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 18.9513 - mean_absolute_error: 1.4272 - val_loss: 16.8369 - val_mean_absolute_error: 1.6058
# Epoch 15/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 18.7437 - mean_absolute_error: 1.4045 - val_loss: 16.7524 - val_mean_absolute_error: 1.6055
# Epoch 16/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 18.5686 - mean_absolute_error: 1.3948 - val_loss: 16.6804 - val_mean_absolute_error: 1.4955
# Epoch 17/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 18.3768 - mean_absolute_error: 1.3755 - val_loss: 16.5905 - val_mean_absolute_error: 1.5270
# Epoch 18/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 18.2350 - mean_absolute_error: 1.3679 - val_loss: 16.5404 - val_mean_absolute_error: 1.5112
# Epoch 19/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 18.0620 - mean_absolute_error: 1.3566 - val_loss: 16.4822 - val_mean_absolute_error: 1.5358
# Epoch 20/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 17.9108 - mean_absolute_error: 1.3504 - val_loss: 16.4322 - val_mean_absolute_error: 1.5411
# Epoch 21/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 17.7720 - mean_absolute_error: 1.3398 - val_loss: 16.5180 - val_mean_absolute_error: 1.6188
# Epoch 22/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 17.6557 - mean_absolute_error: 1.3358 - val_loss: 16.3415 - val_mean_absolute_error: 1.4977
# Epoch 23/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 17.5115 - mean_absolute_error: 1.3212 - val_loss: 16.2902 - val_mean_absolute_error: 1.5098
# Epoch 24/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 17.3888 - mean_absolute_error: 1.3244 - val_loss: 16.3071 - val_mean_absolute_error: 1.4578
# Epoch 25/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 17.2909 - mean_absolute_error: 1.3136 - val_loss: 16.2282 - val_mean_absolute_error: 1.5104
# Epoch 26/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 17.1578 - mean_absolute_error: 1.3122 - val_loss: 16.1832 - val_mean_absolute_error: 1.5032
# Epoch 27/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 17.0280 - mean_absolute_error: 1.3083 - val_loss: 16.1790 - val_mean_absolute_error: 1.5377
# Epoch 28/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 16.9229 - mean_absolute_error: 1.3020 - val_loss: 16.1314 - val_mean_absolute_error: 1.5022
# Epoch 29/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 16.8074 - mean_absolute_error: 1.2967 - val_loss: 16.1110 - val_mean_absolute_error: 1.4980
# Epoch 30/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 16.7253 - mean_absolute_error: 1.2943 - val_loss: 16.0840 - val_mean_absolute_error: 1.5152
# Epoch 31/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 16.5682 - mean_absolute_error: 1.2864 - val_loss: 16.0953 - val_mean_absolute_error: 1.4782
# Epoch 32/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 16.4784 - mean_absolute_error: 1.2811 - val_loss: 16.0310 - val_mean_absolute_error: 1.4985
# Epoch 33/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 16.3714 - mean_absolute_error: 1.2738 - val_loss: 16.0565 - val_mean_absolute_error: 1.5659
# Epoch 34/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 16.2659 - mean_absolute_error: 1.2741 - val_loss: 16.0050 - val_mean_absolute_error: 1.5478
# Epoch 35/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 16.1531 - mean_absolute_error: 1.2642 - val_loss: 16.2356 - val_mean_absolute_error: 1.6471
# Epoch 36/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 16.0963 - mean_absolute_error: 1.2704 - val_loss: 15.9640 - val_mean_absolute_error: 1.5411
# Epoch 37/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 15.9588 - mean_absolute_error: 1.2578 - val_loss: 15.9612 - val_mean_absolute_error: 1.5306
# Epoch 38/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 15.8551 - mean_absolute_error: 1.2551 - val_loss: 15.9531 - val_mean_absolute_error: 1.4592
# Epoch 39/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 15.8190 - mean_absolute_error: 1.2527 - val_loss: 16.1017 - val_mean_absolute_error: 1.6054
# Epoch 40/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 15.6937 - mean_absolute_error: 1.2459 - val_loss: 15.9102 - val_mean_absolute_error: 1.5051
# Epoch 41/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 15.5913 - mean_absolute_error: 1.2440 - val_loss: 15.9041 - val_mean_absolute_error: 1.5030
# Epoch 42/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 15.4907 - mean_absolute_error: 1.2387 - val_loss: 15.9861 - val_mean_absolute_error: 1.5557
# Epoch 43/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 15.3822 - mean_absolute_error: 1.2251 - val_loss: 15.9423 - val_mean_absolute_error: 1.5089
# Epoch 44/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 15.3306 - mean_absolute_error: 1.2259 - val_loss: 15.9014 - val_mean_absolute_error: 1.5297
# Epoch 45/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 15.2302 - mean_absolute_error: 1.2231 - val_loss: 15.8880 - val_mean_absolute_error: 1.5145
# Epoch 46/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 15.1404 - mean_absolute_error: 1.2178 - val_loss: 15.8978 - val_mean_absolute_error: 1.5258
# Epoch 47/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 15.0611 - mean_absolute_error: 1.2122 - val_loss: 15.8817 - val_mean_absolute_error: 1.4383
# Epoch 48/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 14.9634 - mean_absolute_error: 1.2058 - val_loss: 15.8252 - val_mean_absolute_error: 1.4953
# Epoch 49/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 14.9033 - mean_absolute_error: 1.2082 - val_loss: 15.8624 - val_mean_absolute_error: 1.4786
# Epoch 50/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 14.8386 - mean_absolute_error: 1.2030 - val_loss: 15.8518 - val_mean_absolute_error: 1.4582
# Epoch 51/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 14.7305 - mean_absolute_error: 1.1924 - val_loss: 15.8811 - val_mean_absolute_error: 1.5551
# Epoch 52/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 14.6518 - mean_absolute_error: 1.1911 - val_loss: 15.9131 - val_mean_absolute_error: 1.5879
# Epoch 53/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - loss: 14.6069 - mean_absolute_error: 1.1990 - val_loss: 15.9780 - val_mean_absolute_error: 1.5391
# Epoch 54/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - loss: 14.5023 - mean_absolute_error: 1.1775 - val_loss: 15.8448 - val_mean_absolute_error: 1.5038
# Epoch 55/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 14.4278 - mean_absolute_error: 1.1817 - val_loss: 15.8193 - val_mean_absolute_error: 1.4593
# Epoch 56/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 14.3571 - mean_absolute_error: 1.1756 - val_loss: 15.9206 - val_mean_absolute_error: 1.5299
# Epoch 57/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 14.2848 - mean_absolute_error: 1.1706 - val_loss: 15.8475 - val_mean_absolute_error: 1.5042
# Epoch 58/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 14.2411 - mean_absolute_error: 1.1665 - val_loss: 15.9281 - val_mean_absolute_error: 1.5921
# Epoch 59/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 14.1579 - mean_absolute_error: 1.1732 - val_loss: 15.8619 - val_mean_absolute_error: 1.4970
# Epoch 60/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 14.0805 - mean_absolute_error: 1.1624 - val_loss: 15.8277 - val_mean_absolute_error: 1.4231
# Epoch 61/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 13.9829 - mean_absolute_error: 1.1517 - val_loss: 15.8306 - val_mean_absolute_error: 1.4757
# Epoch 62/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 13.9423 - mean_absolute_error: 1.1502 - val_loss: 15.8322 - val_mean_absolute_error: 1.5113
# Epoch 63/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 13.8506 - mean_absolute_error: 1.1564 - val_loss: 15.9321 - val_mean_absolute_error: 1.5155
# Epoch 64/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 13.7987 - mean_absolute_error: 1.1463 - val_loss: 15.9375 - val_mean_absolute_error: 1.5227
# Epoch 65/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 13.7529 - mean_absolute_error: 1.1485 - val_loss: 15.9806 - val_mean_absolute_error: 1.5039
# Epoch 66/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 13.6993 - mean_absolute_error: 1.1438 - val_loss: 16.1476 - val_mean_absolute_error: 1.5796
# Epoch 67/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 13.6671 - mean_absolute_error: 1.1505 - val_loss: 15.9018 - val_mean_absolute_error: 1.5059
# Epoch 68/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 13.5720 - mean_absolute_error: 1.1365 - val_loss: 15.9500 - val_mean_absolute_error: 1.4595
# Epoch 69/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 13.4851 - mean_absolute_error: 1.1291 - val_loss: 15.9414 - val_mean_absolute_error: 1.5354
# Epoch 70/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 13.4448 - mean_absolute_error: 1.1368 - val_loss: 16.2800 - val_mean_absolute_error: 1.6121
# Epoch 71/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 13.3646 - mean_absolute_error: 1.1285 - val_loss: 16.0981 - val_mean_absolute_error: 1.5312
# Epoch 72/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 13.2847 - mean_absolute_error: 1.1248 - val_loss: 15.8571 - val_mean_absolute_error: 1.4296
# Epoch 73/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 13.2501 - mean_absolute_error: 1.1244 - val_loss: 16.1911 - val_mean_absolute_error: 1.5648
# Epoch 74/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 13.1819 - mean_absolute_error: 1.1175 - val_loss: 16.0412 - val_mean_absolute_error: 1.5441
# Epoch 75/75
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 13.1923 - mean_absolute_error: 1.1260 - val_loss: 16.1422 - val_mean_absolute_error: 1.5304
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.6470 - mean_absolute_error: 1.5888

# %%
model[0].save("models\\best_model.keras")
print(model[1])
# Out:
# [20.646961212158203, 1.5887808799743652]
